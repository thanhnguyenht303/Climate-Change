# %%
from google.colab import drive
drive.mount("/content/drive")
import shutil
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import cv2
import math
import os
import numpy as np
import pandas as pd
from numpy.ma.core import ceil
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors
import matplotlib.colors as colors
from sklearn.decomposition import PCA
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, GlobalMaxPooling2D, Dense, Flatten, Dropout, MaxPooling2D, LSTM, Lambda, Conv1D, GlobalMaxPooling1D
from keras.callbacks import TensorBoard, EarlyStopping
from keras.utils import to_categorical

# %%
pressure_training_data_path = "/content/drive/MyDrive/First2YearRawAndNormData/CESMZ200/MinMaxNormWithLabel"
CL_path = pressure_training_data_path + "/CL"
COH_path = pressure_training_data_path + "/COH"
COL_path = pressure_training_data_path + "/COL"
NROI_path = pressure_training_data_path + "/NROI"

# %%
pressure_CL_files = [f for f in os.listdir(CL_path) if f.endswith('.csv')]
pressure_COH_files = [f for f in os.listdir(COH_path) if f.endswith('.csv')]
pressure_COL_files = [f for f in os.listdir(COL_path) if f.endswith('.csv')]
pressure_NROI_files = [f for f in os.listdir(NROI_path) if f.endswith('.csv')]

# %%
pressure_array = []
for file in pressure_CL_files:
    dataframe = pd.read_csv(os.path.join(CL_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    pressure_array.append(dataframe)

for file in pressure_COH_files:
    dataframe = pd.read_csv(os.path.join(COH_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    pressure_array.append(dataframe)

for file in pressure_COL_files:
    dataframe = pd.read_csv(os.path.join(COL_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    pressure_array.append(dataframe)

for file in pressure_NROI_files:
    dataframe = pd.read_csv(os.path.join(NROI_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    pressure_array.append(dataframe)

# %%
pressure_training_df = pd.DataFrame(pressure_array)
Y = []
for i in range(len(pressure_CL_files)):
  Y.append(0)

for i in range(len(pressure_COH_files)):
  Y.append(1)

for i in range(len(pressure_COL_files)):
  Y.append(2)

for i in range(len(pressure_NROI_files)):
  Y.append(3)

Y = pd.DataFrame(Y)

# %%
wind_training_data_path = "/content/drive/MyDrive/First2YearRawAndNormData/CESMU200/MinMaxNormWithLabel"
wind_CL_path = wind_training_data_path + "/CL"
wind_COH_path = wind_training_data_path + "/COH"
wind_COL_path = wind_training_data_path + "/COL"
wind_NROI_path = wind_training_data_path + "/NROI"

# %%
CL_wind_files = [f for f in os.listdir(wind_CL_path) if f.endswith(".csv")]
COH_wind_files = [f for f in os.listdir(wind_COH_path) if f.endswith(".csv")]
COL_wind_files = [f for f in os.listdir(wind_COL_path) if f.endswith(".csv")]
NROI_wind_files = [f for f in os.listdir(wind_NROI_path) if f.endswith(".csv")]

# %%
wind_array = []
for file in CL_wind_files:
    dataframe = pd.read_csv(os.path.join(CL_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    wind_array.append(dataframe)

for file in COH_wind_files:
    dataframe = pd.read_csv(os.path.join(COH_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    wind_array.append(dataframe)

for file in COL_wind_files:
    dataframe = pd.read_csv(os.path.join(COL_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    wind_array.append(dataframe)

for file in NROI_wind_files:
    dataframe = pd.read_csv(os.path.join(NROI_path, file), header=None)
    dataframe = dataframe.to_numpy().flatten()
    wind_array.append(dataframe)

# %%
wind_training_df = pd.DataFrame(wind_array)

# %%
#Combine the data
df_array = np.stack((np.array(pressure_training_df), np.array(wind_training_df)), axis = 2)

#Reshape the data
(h, w, c) = df_array.shape
reshape_df_array = df_array.reshape(h, w*c)
training_df = pd.DataFrame(reshape_df_array)

# %%
training_df["Class"] = Y
training_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.475692  0.459692  0.473846  0.454769  0.471385  0.449846  0.468923
# 1    0.464615  0.488000  0.463385  0.491692  0.462769  0.494769  0.460923
# 2    0.248615  0.569231  0.243692  0.564923  0.240000  0.560615  0.237538
# 3    0.552000  0.515077  0.544000  0.517538  0.536615  0.519385  0.529846
# 4    0.248615  0.552000  0.243692  0.544000  0.240000  0.536615  0.237538
# ..        ...       ...       ...       ...       ...       ...       ...
# 732  0.865846  0.844923  0.877538  0.857231  0.886769  0.872615  0.896615
# 733  0.912615  0.946462  0.915692  0.944615  0.923692  0.944615  0.929846
# 734  0.946462  0.865846  0.944615  0.877538  0.944615  0.886769  0.942154
# 735  0.856000  0.942154  0.864000  0.947692  0.874462  0.950154  0.876923
# 736  0.935385  0.856000  0.940923  0.864000  0.942769  0.874462  0.942769
#
#             7         8         9  ...       441       442       443  \
# 0    0.444923  0.465846  0.440000  ...  0.345231  0.425846  0.350769
# 1    0.498462  0.460308  0.502769  ...  0.499077  0.424000  0.499077
# 2    0.556923  0.235692  0.553231  ...  0.525538  0.222769  0.528615
# 3    0.521846  0.524923  0.523692  ...  0.448615  0.451077  0.444308
# 4    0.529846  0.235692  0.524923  ...  0.444923  0.222769  0.451077
# ..        ...       ...       ...  ...       ...       ...       ...
# 732  0.886154  0.904615  0.890462  ...  0.887385  0.928615  0.889231
# 733  0.942154  0.932308  0.938462  ...  0.932308  0.926154  0.933538
# 734  0.896615  0.938462  0.904615  ...  0.924923  0.933538  0.928615
# 735  0.950154  0.873846  0.951385  ...  0.936000  0.935385  0.939077
# 736  0.876923  0.942769  0.873846  ...  0.936615  0.939692  0.935385
#
#           444       445       446       447       448       449  Class
# 0    0.429538  0.356923  0.435077  0.364308  0.443077  0.371692      0
# 1    0.437538  0.500923  0.454769  0.503385  0.475077  0.507692      0
# 2    0.232615  0.533538  0.246154  0.540308  0.264615  0.547692      0
# 3    0.461538  0.440615  0.475077  0.438154  0.492923  0.436923      0
# 4    0.232615  0.461538  0.246154  0.475077  0.264615  0.492923      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 732  0.932308  0.896000  0.934769  0.899077  0.936000  0.900308      3
# 733  0.926769  0.933538  0.927385  0.936000  0.928615  0.939077      3
# 734  0.933538  0.932308  0.936000  0.934769  0.939077  0.936000      3
# 735  0.933538  0.940923  0.931077  0.940923  0.927385  0.942769      3
# 736  0.940923  0.933538  0.944000  0.931077  0.946462  0.927385      3
#
# [737 rows x 451 columns]

# %%
data = pd.read_csv("/content/drive/MyDrive/Wind_Pressure_ROI_points/Wind_Pressure_ROI.csv", header = None)
data = data.drop(0)
data.rename(columns = {450: "Name", 451: "Day"}, inplace = True)
data
# Out:
# <ipython-input-13-f1c668c7c8eb>:1: DtypeWarning: Columns (451) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Wind_Pressure_ROI_points/Wind_Pressure_ROI.csv", header = None)
#              0         1         2         3         4         5         6  \
# 1     0.904043  0.314050  0.904576  0.327869  0.904043  0.344262  0.900097
# 2     0.854847  0.471074  0.857352  0.475410  0.859717  0.483607  0.859649
# 3     0.886995  0.305785  0.881207  0.311475  0.876766  0.327869  0.872807
# 4     0.861179  0.454545  0.864167  0.475410  0.866050  0.500000  0.867446
# 5     0.915246  0.247934  0.914800  0.270492  0.915246  0.295082  0.915205
# ...        ...       ...       ...       ...       ...       ...       ...
# 3648  0.672187  0.355372  0.668452  0.360656  0.665855  0.377049  0.662768
# 3649  0.950804  0.404959  0.950341  0.418033  0.953726  0.434426  0.954191
# 3650  0.918169  0.471074  0.925998  0.500000  0.932294  0.532787  0.938596
# 3651  0.621042  0.264463  0.622201  0.270492  0.623965  0.286885  0.625731
# 3652  0.905991  0.438017  0.906524  0.459016  0.906965  0.483607  0.905458
#
#              7         8         9  ...       442       443       444  \
# 1     0.341667  0.896721  0.344262  ...  0.894383  0.284615  0.904945
# 2     0.491667  0.861968  0.483607  ...  0.858377  0.307692  0.862218
# 3     0.333333  0.872736  0.336066  ...  0.909265  0.292308  0.915506
# 4     0.508333  0.871268  0.516393  ...  0.872300  0.330769  0.875660
# 5     0.316667  0.919236  0.327869  ...  0.939990  0.300000  0.943831
# ...        ...       ...       ...  ...       ...       ...       ...
# 3648  0.375000  0.662261  0.377049  ...  0.722516  0.576923  0.730197
# 3649  0.441667  0.957416  0.442623  ...  0.934710  0.284615  0.939030
# 3650  0.550000  0.945179  0.549180  ...  0.935670  0.446154  0.935670
# 3651  0.291667  0.628977  0.295082  ...  0.674028  0.576923  0.683629
# 3652  0.500000  0.906510  0.516393  ...  0.903985  0.407692  0.915506
#
#            445       446       447       448       449                Name  \
# 1     0.284615  0.914904  0.281250  0.925676  0.285714   3449_c9_cp2_29_58
# 2     0.307692  0.867308  0.312500  0.874035  0.317460   3450_c8_cp2_98_50
# 3     0.300000  0.921154  0.304688  0.926641  0.301587   3450_c8_cp3_59_56
# 4     0.330769  0.881731  0.328125  0.889479  0.333333   3451_c8_cp2_99_50
# 5     0.300000  0.946154  0.296875  0.952220  0.293651   3452_c8_cp3_55_59
# ...        ...       ...       ...       ...       ...                 ...
# 3648  0.569231  0.738462  0.562500  0.747587  0.555556   1648_c3_cp2_15_28
# 3649  0.276923  0.941827  0.273438  0.946911  0.261905   1648_c9_cp3_65_62
# 3650  0.438462  0.936538  0.437500  0.937741  0.428571  1649_c11_cp1_61_51
# 3651  0.561538  0.694712  0.546875  0.707529  0.523810   1649_c3_cp2_16_25
# 3652  0.415385  0.925481  0.414062  0.935811  0.420635   1649_c8_cp2_34_50
#
#        Day
# 1     3449
# 2     3450
# 3     3450
# 4     3451
# 5     3452
# ...    ...
# 3648  1648
# 3649  1648
# 3650  1649
# 3651  1649
# 3652  1649
#
# [3652 rows x 452 columns]

# %%
data["Day"] = data["Day"].astype(int)
test_df = data[(data["Day"] >= 730) & (data["Day"] <= 1095)]
test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
test_df = test_df.drop_duplicates(subset = "ROI")
test_df = test_df[test_df["ROI"] != "738_73_20"]
test_df = test_df.sort_values(by = "Name")
test_df.reset_index(drop = True, inplace = True)
test_df
# Out:
# <ipython-input-14-20ac38e9c23a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
#             0         1         2         3         4         5         6  \
# 0    0.864588  0.380165  0.866602  0.393443  0.869459  0.418033  0.871832
# 1    0.894788  0.371901  0.890944  0.368852  0.886508  0.368852  0.881579
# 2    0.870434  0.776860  0.883155  0.803279  0.895762  0.827869  0.906920
# 3    0.934730  0.545455  0.930867  0.549180  0.926936  0.557377  0.922027
# 4    0.909888  0.603306  0.910906  0.614754  0.911349  0.622951  0.909357
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.930833  0.396694  0.935248  0.409836  0.939601  0.426230  0.937135
# 327  0.869459  0.438017  0.873418  0.459016  0.876279  0.475410  0.877193
# 328  0.759864  0.404959  0.772639  0.418033  0.783731  0.434426  0.791910
# 329  0.812957  0.338843  0.820837  0.336066  0.826595  0.319672  0.829435
# 330  0.866537  0.330579  0.870010  0.352459  0.872869  0.368852  0.875244
#
#             7         8         9  ...       443       444       445  \
# 0    0.425000  0.876163  0.434426  ...  0.423077  0.893903  0.407692
# 1    0.358333  0.878610  0.344262  ...  0.484615  0.863658  0.476923
# 2    0.841667  0.919726  0.827869  ...  0.361538  0.930869  0.369231
# 3    0.558333  0.920215  0.549180  ...  0.423077  0.914066  0.415385
# 4    0.633333  0.909447  0.622951  ...  0.461538  0.891503  0.461538
# ..        ...       ...       ...  ...       ...       ...       ...
# 326  0.433333  0.942242  0.434426  ...  0.361538  0.942391  0.361538
# 327  0.483333  0.879589  0.483607  ...  0.669231  0.902544  0.676923
# 328  0.433333  0.800783  0.418033  ...  0.176923  0.815651  0.169231
# 329  0.300000  0.835047  0.278689  ...  0.684615  0.898704  0.692308
# 330  0.375000  0.879099  0.377049  ...  0.492308  0.893903  0.492308
#
#           446       447       448       449                Name   Day  \
# 0    0.900000  0.390625  0.903958  0.380952  1001_c12_cp2_63_48  1001
# 1    0.871635  0.468750  0.880309  0.452381  1002_c11_cp2_41_44  1002
# 2    0.926923  0.367188  0.923263  0.373016  1002_c15_cp1_20_48  1002
# 3    0.917308  0.414062  0.920849  0.404762  1003_c11_cp2_38_48  1003
# 4    0.899038  0.460938  0.910232  0.460317  1004_c10_cp2_30_49  1004
# ..        ...       ...       ...       ...                 ...   ...
# 326  0.948077  0.367188  0.953185  0.365079   997_c12_cp2_62_59   997
# 327  0.911058  0.679688  0.919884  0.682540   998_c12_cp2_37_48   998
# 328  0.813462  0.156250  0.813224  0.142857  999_c11_cp2_102_34   999
# 329  0.909615  0.703125  0.921332  0.706349   999_c11_cp3_37_44   999
# 330  0.893269  0.492188  0.893340  0.492063   999_c14_cp1_53_37   999
#
#             ROI
# 0    1001_63_48
# 1    1002_41_44
# 2    1002_20_48
# 3    1003_38_48
# 4    1004_30_49
# ..          ...
# 326   997_62_59
# 327   998_37_48
# 328  999_102_34
# 329   999_37_44
# 330   999_53_37
#
# [331 rows x 453 columns]

# %%
#Define training and testing data
X_train = training_df.drop("Class", axis = 1)
Y_train = training_df["Class"]

X_test = test_df.drop(columns = ["Name", "Day", "ROI"])

# %% [markdown]
# #**SOM**

# %%
#Normalization
def minmax_scaler(data):
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(data)
    return scaled
#Euclidean distance
def e_distance(x, y):
    return distance.euclidean(x, y)

#Manhanttan distance
def m_distance(x, y):
    return distance.cityblock(x, y)

#Best Matching Unit search
def winning_neuron(data, t, som, num_rows, num_cols):
  winner = [0,0]
  shortest_distance = np.sqrt(data.shape[1]) # initialise with max distance
  input_data = data[t]
  for row in range(num_rows):
    for col in range(num_cols):
      distance = e_distance(som[row][col], data[t])
      if distance < shortest_distance:
        shortest_distance = distance
        winner = [row,col]
  return winner

#Learning rate and neighbourhood range calculation
def decay(step, max_steps,max_learning_rate,max_m_dsitance):
  coefficient = 1.0 - (np.float64(step)/max_steps)
  learning_rate = coefficient*max_learning_rate
  neighbourhood_range = ceil(coefficient * max_m_dsitance)
  return learning_rate, neighbourhood_range

# %%
num_rows = 15
num_cols = 15
max_m_dsitance = 7
max_learning_rate = 0.75
max_steps = 20000

# %%
#main function

train_x_norm = minmax_scaler(X_train) # normalisation
# initialising self-organising map
num_dims = train_x_norm.shape[1] # numnber of dimensions in the input data
#np.random.seed(40)
som = np.random.random_sample(size=(num_rows, num_cols, num_dims)) # map construction

# start training iterations
for step in range(max_steps):
  if (step+1) % 1000 == 0:
    print("Iteration: ", step+1) # print out the current iteration for every 1k
  learning_rate, neighbourhood_range = decay(step, max_steps,max_learning_rate,max_m_dsitance)

  t = np.random.randint(0,high=train_x_norm.shape[0]) # random index of traing data
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  for row in range(num_rows):
    for col in range(num_cols):
      if m_distance([row,col],winner) <= neighbourhood_range:
        som[row][col] += learning_rate*(train_x_norm[t]-som[row][col]) #update neighbour's weight

print("SOM training completed")
# Out:
# Iteration:  1000
# Iteration:  2000
# Iteration:  3000
# Iteration:  4000
# Iteration:  5000
# Iteration:  6000
# Iteration:  7000
# Iteration:  8000
# Iteration:  9000
# Iteration:  10000
# Iteration:  11000
# Iteration:  12000
# Iteration:  13000
# Iteration:  14000
# Iteration:  15000
# Iteration:  16000
# Iteration:  17000
# Iteration:  18000
# Iteration:  19000
# Iteration:  20000
# SOM training completed

# %%
label_data = np.array(Y_train)
map = np.empty(shape=(num_rows, num_cols), dtype=object)

for row in range(num_rows):
  for col in range(num_cols):
    map[row][col] = [] # empty list to store the label

for t in range(train_x_norm.shape[0]):
  if (t+1) % 1000 == 0:
    print("sample data: ", t+1)
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  map[winner[0]][winner[1]].append(label_data[t]) # label of winning neuron

# %%
map_table = {}
for i in range(len(map)):
    for j in range(len(map[0])):
        if len(map[i][j]) == 0:
            map_table[i, j] = [None]
        else:
            hash_table = {}
            for k in map[i][j]:
                if k in hash_table:
                    hash_table[k] += 1
                else:
                    hash_table[k] = 1
            for key, value in hash_table.items():
                percentage = [key, round((value / len(map[i][j])), 2)]
                if (i, j) not in map_table:
                    map_table[i, j] = []
                map_table[i, j].append(percentage)

# %%
# construct label map
label_map = np.zeros(shape=(num_rows, num_cols),dtype=np.int64)
for row in range(num_rows):
  for col in range(num_cols):
    label_list = map[row][col]
    if len(label_list)==0:
      label = 3
    else:
      label = max(label_list, key=label_list.count)
    label_map[row][col] = label

title = ('Iteration ' + str(max_steps))
cmap = colors.ListedColormap(['tab:green', 'tab:red', 'tab:orange', 'tab:blue'])
plt.imshow(label_map, cmap=cmap)
plt.colorbar()
plt.title(title)
plt.show()

# %%
# test data

# using the trained som, search the winning node of corresponding to the test data
# get the label of the winning node

data_frame = minmax_scaler(X_test) # normalisation

winner_labels = []
pre_labels = []

for t in range(data_frame.shape[0]):
  winner = winning_neuron(data_frame, t, som, num_rows, num_cols)
  row = winner[0]
  col = winner[1]
  pred = map_table[row, col]
  predicted = label_map[row][col]
  pre_labels.append(pred)
  winner_labels.append(predicted)

# %%
labels_df = pd.read_table("/content/3rd_year_Categorical_ROI.txt", sep = ":", header = None)
labels_df.rename(columns = {0: "Name", 1: "Class"}, inplace = True)
labels_df["Class"] = labels_df["Class"].str.strip()
labels_df = labels_df.sort_values(by = 'Name')
labels_df.reset_index(drop = True, inplace = True)
labels_df
# Out:
#                     Name Class
# 0    1001_c12_cp2_63_48   NROI
# 1    1002_c11_cp2_41_44    COL
# 2    1002_c15_cp1_20_48    COH
# 3    1003_c11_cp2_38_48    COL
# 4    1004_c10_cp2_30_49    COL
# ..                   ...   ...
# 326   997_c12_cp2_62_59   NROI
# 327   998_c12_cp2_37_48    COL
# 328  999_c11_cp2_102_34    COL
# 329   999_c11_cp3_37_44    COL
# 330   999_c14_cp1_53_37    COH
#
# [331 rows x 2 columns]

# %%
class_mapping = {'NROI': 3, 'COL': 2, 'COH': 1, 'CL': 0}
labels_df["Class"] = labels_df["Class"].replace(class_mapping)
labels_df
# Out:
#                     Name  Class
# 0    1001_c12_cp2_63_48       3
# 1    1002_c11_cp2_41_44       2
# 2    1002_c15_cp1_20_48       1
# 3    1003_c11_cp2_38_48       2
# 4    1004_c10_cp2_30_49       2
# ..                   ...    ...
# 326   997_c12_cp2_62_59       3
# 327   998_c12_cp2_37_48       2
# 328  999_c11_cp2_102_34       2
# 329   999_c11_cp3_37_44       2
# 330   999_c14_cp1_53_37       1
#
# [331 rows x 2 columns]

# %%
labels_df["Class"] = labels_df["Class"].astype(int)

# %%
SOM_acc = accuracy_score(np.array(labels_df["Class"]), np.array(winner_labels))
print("Accuracy: ", SOM_acc)
# Out:
# Accuracy:  0.4471299093655589

# %%
SOM_test_df = test_df.copy()
SOM_test_df["Class"] = winner_labels
SOM_test_df["Percentage"] = pre_labels
SOM_test_df
# Out:
# <ipython-input-68-1e4c382ae0b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SOM_test_df["Class"] = winner_labels
# <ipython-input-68-1e4c382ae0b6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SOM_test_df["Percentage"] = pre_labels
#             0         1         2         3         4         5         6  \
# 0    0.533366  0.578512  0.542843  0.598361  0.552362  0.614754  0.559942
# 1    0.551875  0.669421  0.559883  0.663934  0.567462  0.663934  0.573587
# 2    0.558208  0.809917  0.565239  0.811475  0.571359  0.827869  0.576998
# 3    0.127618  0.528926  0.127556  0.540984  0.127131  0.557377  0.127193
# 4    0.173405  0.380165  0.169912  0.401639  0.167073  0.426230  0.164230
# ..        ...       ...       ...       ...       ...       ...       ...
# 352  0.813444  0.380165  0.823272  0.385246  0.831953  0.393443  0.839181
# 353  0.500244  0.669421  0.506816  0.672131  0.513395  0.688525  0.519006
# 354  0.871408  0.396694  0.864167  0.426230  0.856308  0.459016  0.846004
# 355  0.874817  0.322314  0.870983  0.336066  0.867511  0.344262  0.863548
# 356  0.829031  0.404959  0.835930  0.418033  0.842669  0.434426  0.846491
#
#             7         8         9  ...       444       445       446  \
# 0    0.616667  0.568282  0.606557  ...  0.586654  0.253846  0.575481
# 1    0.658333  0.580029  0.639344  ...  0.600096  0.238462  0.596154
# 2    0.841667  0.583456  0.827869  ...  0.600096  0.300000  0.594712
# 3    0.566667  0.127264  0.557377  ...  0.142583  0.523077  0.144231
# 4    0.433333  0.161527  0.442623  ...  0.200672  0.492308  0.204808
# ..        ...       ...       ...  ...       ...       ...       ...
# 352  0.383333  0.847773  0.377049  ...  0.874700  0.323077  0.877885
# 353  0.700000  0.525698  0.696721  ...  0.551608  0.330769  0.547115
# 354  0.483333  0.837983  0.500000  ...  0.828613  0.376923  0.835577
# 355  0.350000  0.862457  0.352459  ...  0.845895  0.369231  0.849038
# 356  0.441667  0.852178  0.434426  ...  0.872780  0.276923  0.874038
#
#           447       448       449                Name   Day  Class  \
# 0    0.257812  0.563224  0.261905   730_c12_cp1_24_28   730      2
# 1    0.250000  0.591216  0.261905   731_c12_cp1_24_27   731      2
# 2    0.296875  0.587355  0.301587   732_c13_cp1_25_25   732      1
# 3    0.515625  0.146236  0.515873    733_c1_cp1_83_11   733      0
# 4    0.484375  0.208494  0.476190    736_c1_cp1_77_11   736      3
# ..        ...       ...       ...                 ...   ...    ...
# 352  0.320312  0.882722  0.317460  1055_c16_cp2_99_60  1055      1
# 353  0.343750  0.542471  0.357143  1069_c11_cp1_15_27  1069      2
# 354  0.382812  0.841699  0.380952  1087_c16_cp2_17_59  1087      2
# 355  0.367188  0.853282  0.373016  1090_c17_cp2_27_63  1090      1
# 356  0.273438  0.875965  0.277778  1093_c17_cp2_19_63  1093      1
#
#                Percentage
# 0              [[2, 1.0]]
# 1              [[2, 1.0]]
# 2    [[1, 0.5], [2, 0.5]]
# 3              [[0, 1.0]]
# 4                  [None]
# ..                    ...
# 352            [[1, 1.0]]
# 353            [[2, 1.0]]
# 354            [[2, 1.0]]
# 355            [[1, 1.0]]
# 356            [[1, 1.0]]
#
# [357 rows x 454 columns]

# %%
# Assuming your DataFrame is named "SOM_test_df"
SOM_test_df['Percentage'] = SOM_test_df['Percentage'].apply(lambda x: [] if x == [None] else x)

# Print the updated DataFrame
SOM_test_df
# Out:
# <ipython-input-69-4cd4b0dab110>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SOM_test_df['Percentage'] = SOM_test_df['Percentage'].apply(lambda x: [] if x == [None] else x)
#             0         1         2         3         4         5         6  \
# 0    0.533366  0.578512  0.542843  0.598361  0.552362  0.614754  0.559942
# 1    0.551875  0.669421  0.559883  0.663934  0.567462  0.663934  0.573587
# 2    0.558208  0.809917  0.565239  0.811475  0.571359  0.827869  0.576998
# 3    0.127618  0.528926  0.127556  0.540984  0.127131  0.557377  0.127193
# 4    0.173405  0.380165  0.169912  0.401639  0.167073  0.426230  0.164230
# ..        ...       ...       ...       ...       ...       ...       ...
# 352  0.813444  0.380165  0.823272  0.385246  0.831953  0.393443  0.839181
# 353  0.500244  0.669421  0.506816  0.672131  0.513395  0.688525  0.519006
# 354  0.871408  0.396694  0.864167  0.426230  0.856308  0.459016  0.846004
# 355  0.874817  0.322314  0.870983  0.336066  0.867511  0.344262  0.863548
# 356  0.829031  0.404959  0.835930  0.418033  0.842669  0.434426  0.846491
#
#             7         8         9  ...       444       445       446  \
# 0    0.616667  0.568282  0.606557  ...  0.586654  0.253846  0.575481
# 1    0.658333  0.580029  0.639344  ...  0.600096  0.238462  0.596154
# 2    0.841667  0.583456  0.827869  ...  0.600096  0.300000  0.594712
# 3    0.566667  0.127264  0.557377  ...  0.142583  0.523077  0.144231
# 4    0.433333  0.161527  0.442623  ...  0.200672  0.492308  0.204808
# ..        ...       ...       ...  ...       ...       ...       ...
# 352  0.383333  0.847773  0.377049  ...  0.874700  0.323077  0.877885
# 353  0.700000  0.525698  0.696721  ...  0.551608  0.330769  0.547115
# 354  0.483333  0.837983  0.500000  ...  0.828613  0.376923  0.835577
# 355  0.350000  0.862457  0.352459  ...  0.845895  0.369231  0.849038
# 356  0.441667  0.852178  0.434426  ...  0.872780  0.276923  0.874038
#
#           447       448       449                Name   Day  Class  \
# 0    0.257812  0.563224  0.261905   730_c12_cp1_24_28   730      2
# 1    0.250000  0.591216  0.261905   731_c12_cp1_24_27   731      2
# 2    0.296875  0.587355  0.301587   732_c13_cp1_25_25   732      1
# 3    0.515625  0.146236  0.515873    733_c1_cp1_83_11   733      0
# 4    0.484375  0.208494  0.476190    736_c1_cp1_77_11   736      3
# ..        ...       ...       ...                 ...   ...    ...
# 352  0.320312  0.882722  0.317460  1055_c16_cp2_99_60  1055      1
# 353  0.343750  0.542471  0.357143  1069_c11_cp1_15_27  1069      2
# 354  0.382812  0.841699  0.380952  1087_c16_cp2_17_59  1087      2
# 355  0.367188  0.853282  0.373016  1090_c17_cp2_27_63  1090      1
# 356  0.273438  0.875965  0.277778  1093_c17_cp2_19_63  1093      1
#
#                Percentage
# 0              [[2, 1.0]]
# 1              [[2, 1.0]]
# 2    [[1, 0.5], [2, 0.5]]
# 3              [[0, 1.0]]
# 4                      []
# ..                    ...
# 352            [[1, 1.0]]
# 353            [[2, 1.0]]
# 354            [[2, 1.0]]
# 355            [[1, 1.0]]
# 356            [[1, 1.0]]
#
# [357 rows x 454 columns]

# %%
def calculate_distance(x1, y1, x2, y2):
    delta_x = x2 - x1
    delta_y = y2 - y1
    distance = math.sqrt(delta_x**2 + delta_y**2)
    return distance

# %%
SOM_ROI = {}

data = SOM_test_df.to_numpy()
for item in data:
    part = item[450].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[452]
    percentage = item[453]
    if day in SOM_ROI:
        found_duplicate = False
        for ele in SOM_ROI[day]:
            if x == ele[0] and y == ele[1]:
                found_duplicate = True
                break
        if not found_duplicate:
            SOM_ROI[day].append([x, y, category, percentage])
    else:
        SOM_ROI[day] = [[x, y, category, percentage]]

# %%
One_SOM_ROI = {}
Many_SOM_ROI = {}

for key, value in SOM_ROI.items():
    if len(value) <= 1:
        One_SOM_ROI[key] = value
    else:
        Many_SOM_ROI[key] = value

# %%
Many_SOM = {}
for key, value in Many_SOM_ROI.items():
    Many_SOM[key] = [[value[0]]]
    max_len = 0
    for i in value:
        if i[3] is None:
            continue
        else:
            if max_len < len(i[3]):
                max_len = len(i[3])
    space = max_len * 9 + (max_len - 1) * 6 + 16
    i = 1
    while i < len(value):
        x1 = value[i][0]
        y1 = value[i][1]
        found_smaller = True
        for k in Many_SOM[key]:
            found_smaller = True
            for j in k:
                x2 = j[0]
                y2 = j[1]
                distance = calculate_distance(x1, y1, x2, y2)
                if distance < space:
                    found_smaller = False
                    break
            if found_smaller == True:
                k.append(value[i])
                break
        if found_smaller == False:
            Many_SOM[key].append([value[i]])
        i += 1

# %%
folder_name = "3rd_SOM_Categorical_Wind_Pressure_ROI_Image"
SOM_folder_path = "/content/drive/MyDrive/" + folder_name

# os.makedirs(SOM_folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
default_color = (0, 0, 0)
size = 1
text_color = (148, 91, 10)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in One_SOM_ROI:
        for point in One_SOM_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list.get(point[2], default_color)
            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
            cv2.drawContours(final_image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
            text = ""
            if point[3] is not None:
                text = ", ".join([f"{a}:{b}" for a, b in point[3]])
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.2
            line_thickness = 0
            position = ()
            lines = text.split(",")
            max_len * 12 + (max_len - 1) * 6 + 16
            if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                position = (x + 3, y - 2)
            else:
                position = (x - 11, y + 8)
            for i, line in enumerate(lines):
                line = line.strip()
                position = (position[0], position[1] + 6 * i)
                cv2.putText(final_image, line, position, font, font_scale, text_color, line_thickness)
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", final_image)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    f_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    height, width, _ = f_image.shape
    base_image = np.zeros((height, width, 3), dtype = np.uint8)
    base_image = cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB)

    if number in Many_SOM:
        for part in Many_SOM[number]:
            image = f_image.copy()
            for point in part:
                x = point[0]
                y = point[1]
                color = color_list[point[2]]
                vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
                cv2.drawContours(image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
                text = ""
                if point[3] is not None:
                    text = ", ".join([f"{a}:{b}" for a, b in point[3]])
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.2
                line_thickness = 0
                position = ()
                lines = text.split(",")
                max_len * 12 + (max_len - 1) * 6 + 16
                if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                    position = (x + 3, y - 2)
                else:
                    position = (x - 11, y + 8)
                for i, line in enumerate(lines):
                    line = line.strip()
                    position = (position[0], position[1] + 6 * i)
                    cv2.putText(image, line, position, font, font_scale, text_color, line_thickness)
            base_image = np.concatenate((base_image, image), axis = 1)
        base_image = base_image[:, width:, :]
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", base_image)

# %% [markdown]
# #**CNN**

# %%
# Select the columns to be stacked
scaled_pressure = X_test.iloc[:, :225].values
scaled_wind = X_test.iloc[:, 225:450].values

# %%
# Combine the data
merging_test_data = np.stack((scaled_pressure, scaled_wind), axis = 2)

# %%
#Reshape training and testing data
train_X = df_array.reshape(df_array.shape[0], 15, 15, 2)
test_X = merging_test_data.reshape(merging_test_data.shape[0], 15, 15, 2)

train_Y = to_categorical(Y_train, num_classes = 4)

# %%
#Define the model architecture
cnn_model = Sequential()
cnn_model.add(Conv2D(filters = 32, kernel_size = 3, activation = "relu", input_shape = (15, 15, 2)))
cnn_model.add(Conv2D(filters = 64, kernel_size = 3, activation = "relu"))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(Conv2D(filters = 128, kernel_size = 3, activation = "relu"))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(128, activation = "relu"))
cnn_model.add(Dense(64, activation = "relu"))
cnn_model.add(Dense(4, activation = "softmax"))

# %%
# Compile the model
cnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='loss', patience=30)
tensorboard_callback = TensorBoard(log_dir="./logs")

# Fit the model
cnn_model.fit(train_X, train_Y, epochs=1000, batch_size=32, callbacks=[tensorboard_callback, early_stopping])
# Out:
# Epoch 1/1000
# 24/24 [==============================] - 3s 47ms/step - loss: 1.2657 - accuracy: 0.4464
# Epoch 2/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 1.0772 - accuracy: 0.5645
# Epoch 3/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.9014 - accuracy: 0.5943
# Epoch 4/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.8252 - accuracy: 0.6174
# Epoch 5/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7785 - accuracy: 0.6526
# Epoch 6/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.8703 - accuracy: 0.6065
# Epoch 7/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7672 - accuracy: 0.6445
# Epoch 8/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7207 - accuracy: 0.6757
# Epoch 9/1000
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6805 - accuracy: 0.6988
# Epoch 10/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.8180 - accuracy: 0.6119
# Epoch 11/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.6702 - accuracy: 0.7151
# Epoch 12/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7512 - accuracy: 0.6676
# Epoch 13/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.6784 - accuracy: 0.6988
# Epoch 14/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 1.0740 - accuracy: 0.5468
# Epoch 15/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.8018 - accuracy: 0.5984
# Epoch 16/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6803 - accuracy: 0.6947
# Epoch 17/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7924 - accuracy: 0.6431
# Epoch 18/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.7435 - accuracy: 0.6649
# Epoch 19/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.8959 - accuracy: 0.5889
# Epoch 20/1000
# 24/24 [==============================] - 1s 48ms/step - loss: 0.7633 - accuracy: 0.6119
# Epoch 21/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6736 - accuracy: 0.7015
# Epoch 22/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6390 - accuracy: 0.7191
# Epoch 23/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 0.6739 - accuracy: 0.7069
# Epoch 24/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6317 - accuracy: 0.7286
# Epoch 25/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6764 - accuracy: 0.7042
# Epoch 26/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7326 - accuracy: 0.6621
# Epoch 27/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6397 - accuracy: 0.7232
# Epoch 28/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.5946 - accuracy: 0.7436
# Epoch 29/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.6120 - accuracy: 0.7395
# Epoch 30/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7994 - accuracy: 0.6309
# Epoch 31/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7057 - accuracy: 0.6676
# Epoch 32/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7063 - accuracy: 0.6866
# Epoch 33/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.6103 - accuracy: 0.7408
# Epoch 34/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5825 - accuracy: 0.7476
# Epoch 35/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.7280 - accuracy: 0.6852
# Epoch 36/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5925 - accuracy: 0.7517
# Epoch 37/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.8311 - accuracy: 0.6242
# Epoch 38/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6332 - accuracy: 0.7246
# Epoch 39/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6733 - accuracy: 0.7001
# Epoch 40/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.5871 - accuracy: 0.7531
# Epoch 41/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.5560 - accuracy: 0.7612
# Epoch 42/1000
# 24/24 [==============================] - 1s 48ms/step - loss: 0.5446 - accuracy: 0.7585
# Epoch 43/1000
# 24/24 [==============================] - 1s 32ms/step - loss: 0.5318 - accuracy: 0.7720
# Epoch 44/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5286 - accuracy: 0.7924
# Epoch 45/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.4843 - accuracy: 0.8019
# Epoch 46/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.4478 - accuracy: 0.8114
# Epoch 47/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5028 - accuracy: 0.7910
# Epoch 48/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4066 - accuracy: 0.8453
# Epoch 49/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3495 - accuracy: 0.8697
# Epoch 50/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5155 - accuracy: 0.7856
# Epoch 51/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5225 - accuracy: 0.7558
# Epoch 52/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4082 - accuracy: 0.8263
# Epoch 53/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3145 - accuracy: 0.8901
# Epoch 54/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3120 - accuracy: 0.8792
# Epoch 55/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3983 - accuracy: 0.8250
# Epoch 56/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.3282 - accuracy: 0.8725
# Epoch 57/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.3308 - accuracy: 0.8602
# Epoch 58/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4211 - accuracy: 0.8318
# Epoch 59/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.2920 - accuracy: 0.8806
# Epoch 60/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.3312 - accuracy: 0.8684
# Epoch 61/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.3354 - accuracy: 0.8562
# Epoch 62/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2933 - accuracy: 0.8752
# Epoch 63/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.3357 - accuracy: 0.8697
# Epoch 64/1000
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3519 - accuracy: 0.8725
# Epoch 65/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2787 - accuracy: 0.8779
# Epoch 66/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.2651 - accuracy: 0.8955
# Epoch 67/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2778 - accuracy: 0.8847
# Epoch 68/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3432 - accuracy: 0.8467
# Epoch 69/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2466 - accuracy: 0.9064
# Epoch 70/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.2470 - accuracy: 0.8969
# Epoch 71/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3102 - accuracy: 0.8847
# Epoch 72/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3094 - accuracy: 0.8711
# Epoch 73/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.3930 - accuracy: 0.8236
# Epoch 74/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2629 - accuracy: 0.8969
# Epoch 75/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 1.3437 - accuracy: 0.6364
# Epoch 76/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5700 - accuracy: 0.7639
# Epoch 77/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.3715 - accuracy: 0.8562
# Epoch 78/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.3156 - accuracy: 0.8657
# Epoch 79/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2942 - accuracy: 0.8820
# Epoch 80/1000
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2765 - accuracy: 0.8847
# Epoch 81/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2864 - accuracy: 0.8887
# Epoch 82/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2407 - accuracy: 0.9077
# Epoch 83/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3384 - accuracy: 0.8602
# Epoch 84/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.8394 - accuracy: 0.6852
# Epoch 85/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.4775 - accuracy: 0.8141
# Epoch 86/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3204 - accuracy: 0.8820
# Epoch 87/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2596 - accuracy: 0.9037
# Epoch 88/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2636 - accuracy: 0.9009
# Epoch 89/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.3450 - accuracy: 0.8643
# Epoch 90/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4604 - accuracy: 0.8114
# Epoch 91/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3120 - accuracy: 0.8847
# Epoch 92/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2403 - accuracy: 0.9104
# Epoch 93/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2227 - accuracy: 0.9104
# Epoch 94/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2556 - accuracy: 0.8860
# Epoch 95/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.2220 - accuracy: 0.9050
# Epoch 96/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2102 - accuracy: 0.9172
# Epoch 97/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2290 - accuracy: 0.9023
# Epoch 98/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2183 - accuracy: 0.9159
# Epoch 99/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2577 - accuracy: 0.8928
# Epoch 100/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2201 - accuracy: 0.9064
# Epoch 101/1000
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3015 - accuracy: 0.8887
# Epoch 102/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2377 - accuracy: 0.9037
# Epoch 103/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2182 - accuracy: 0.9064
# Epoch 104/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2298 - accuracy: 0.9023
# Epoch 105/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2429 - accuracy: 0.8901
# Epoch 106/1000
# 24/24 [==============================] - 1s 38ms/step - loss: 0.2177 - accuracy: 0.9023
# Epoch 107/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2039 - accuracy: 0.9172
# Epoch 108/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2387 - accuracy: 0.9104
# Epoch 109/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2155 - accuracy: 0.9172
# Epoch 110/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2132 - accuracy: 0.9050
# Epoch 111/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2159 - accuracy: 0.9009
# Epoch 112/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3354 - accuracy: 0.8467
# Epoch 113/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2258 - accuracy: 0.9050
# Epoch 114/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2243 - accuracy: 0.9050
# Epoch 115/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3798 - accuracy: 0.8562
# Epoch 116/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2162 - accuracy: 0.9172
# Epoch 117/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2037 - accuracy: 0.9132
# Epoch 118/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2051 - accuracy: 0.9240
# Epoch 119/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1951 - accuracy: 0.9267
# Epoch 120/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1932 - accuracy: 0.9254
# Epoch 121/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2102 - accuracy: 0.9064
# Epoch 122/1000
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2306 - accuracy: 0.9023
# Epoch 123/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2236 - accuracy: 0.9091
# Epoch 124/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3041 - accuracy: 0.8684
# Epoch 125/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2284 - accuracy: 0.9159
# Epoch 126/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2045 - accuracy: 0.9240
# Epoch 127/1000
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2040 - accuracy: 0.9132
# Epoch 128/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2207 - accuracy: 0.9009
# Epoch 129/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1980 - accuracy: 0.9254
# Epoch 130/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1892 - accuracy: 0.9186
# Epoch 131/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1913 - accuracy: 0.9186
# Epoch 132/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2412 - accuracy: 0.8969
# Epoch 133/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2144 - accuracy: 0.9172
# Epoch 134/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1984 - accuracy: 0.9199
# Epoch 135/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2076 - accuracy: 0.9172
# Epoch 136/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1998 - accuracy: 0.9213
# Epoch 137/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1862 - accuracy: 0.9213
# Epoch 138/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1914 - accuracy: 0.9308
# Epoch 139/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2647 - accuracy: 0.8969
# Epoch 140/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1967 - accuracy: 0.9186
# Epoch 141/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5787 - accuracy: 0.7666
# Epoch 142/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.3267 - accuracy: 0.8643
# Epoch 143/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.2622 - accuracy: 0.8942
# Epoch 144/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2084 - accuracy: 0.9104
# Epoch 145/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2509 - accuracy: 0.8928
# Epoch 146/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2043 - accuracy: 0.9145
# Epoch 147/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2131 - accuracy: 0.9213
# Epoch 148/1000
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2024 - accuracy: 0.9240
# Epoch 149/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2400 - accuracy: 0.9037
# Epoch 150/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2270 - accuracy: 0.9104
# Epoch 151/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2035 - accuracy: 0.9132
# Epoch 152/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2246 - accuracy: 0.9199
# Epoch 153/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2025 - accuracy: 0.9159
# Epoch 154/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1840 - accuracy: 0.9322
# Epoch 155/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2896 - accuracy: 0.8915
# Epoch 156/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2047 - accuracy: 0.9132
# Epoch 157/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1932 - accuracy: 0.9186
# Epoch 158/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1812 - accuracy: 0.9240
# Epoch 159/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4143 - accuracy: 0.8535
# Epoch 160/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2070 - accuracy: 0.9172
# Epoch 161/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4232 - accuracy: 0.8277
# Epoch 162/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2533 - accuracy: 0.8901
# Epoch 163/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2535 - accuracy: 0.8874
# Epoch 164/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2129 - accuracy: 0.9077
# Epoch 165/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2181 - accuracy: 0.9050
# Epoch 166/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2080 - accuracy: 0.9172
# Epoch 167/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2039 - accuracy: 0.9254
# Epoch 168/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2143 - accuracy: 0.9172
# Epoch 169/1000
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2072 - accuracy: 0.9118
# Epoch 170/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1925 - accuracy: 0.9104
# Epoch 171/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1828 - accuracy: 0.9254
# Epoch 172/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2031 - accuracy: 0.9213
# Epoch 173/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1867 - accuracy: 0.9240
# Epoch 174/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1839 - accuracy: 0.9199
# Epoch 175/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1988 - accuracy: 0.9132
# Epoch 176/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1845 - accuracy: 0.9267
# Epoch 177/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2283 - accuracy: 0.9077
# Epoch 178/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1852 - accuracy: 0.9227
# Epoch 179/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1933 - accuracy: 0.9145
# Epoch 180/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2179 - accuracy: 0.9172
# Epoch 181/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3558 - accuracy: 0.8806
# Epoch 182/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.2312 - accuracy: 0.9077
# Epoch 183/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2007 - accuracy: 0.9213
# Epoch 184/1000
# 24/24 [==============================] - 1s 33ms/step - loss: 0.1845 - accuracy: 0.9322
# Epoch 185/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1773 - accuracy: 0.9213
# Epoch 186/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1872 - accuracy: 0.9254
# Epoch 187/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1832 - accuracy: 0.9294
# Epoch 188/1000
# 24/24 [==============================] - 1s 47ms/step - loss: 0.7516 - accuracy: 0.7558
# Epoch 189/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2909 - accuracy: 0.8779
# Epoch 190/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.2399 - accuracy: 0.9037
# Epoch 191/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2211 - accuracy: 0.9145
# Epoch 192/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1887 - accuracy: 0.9281
# Epoch 193/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2192 - accuracy: 0.9118
# Epoch 194/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2088 - accuracy: 0.9118
# Epoch 195/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1873 - accuracy: 0.9322
# Epoch 196/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1883 - accuracy: 0.9186
# Epoch 197/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1838 - accuracy: 0.9227
# Epoch 198/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1803 - accuracy: 0.9335
# Epoch 199/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1729 - accuracy: 0.9294
# Epoch 200/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.4277 - accuracy: 0.8372
# Epoch 201/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2230 - accuracy: 0.9064
# Epoch 202/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1789 - accuracy: 0.9227
# Epoch 203/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2078 - accuracy: 0.9159
# Epoch 204/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1680 - accuracy: 0.9240
# Epoch 205/1000
# 24/24 [==============================] - 1s 38ms/step - loss: 0.1847 - accuracy: 0.9294
# Epoch 206/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.3820 - accuracy: 0.8643
# Epoch 207/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2481 - accuracy: 0.8969
# Epoch 208/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1919 - accuracy: 0.9199
# Epoch 209/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1985 - accuracy: 0.9186
# Epoch 210/1000
# 24/24 [==============================] - 1s 42ms/step - loss: 0.1968 - accuracy: 0.9213
# Epoch 211/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2370 - accuracy: 0.9145
# Epoch 212/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2055 - accuracy: 0.9132
# Epoch 213/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1808 - accuracy: 0.9267
# Epoch 214/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1718 - accuracy: 0.9349
# Epoch 215/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1777 - accuracy: 0.9267
# Epoch 216/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1684 - accuracy: 0.9362
# Epoch 217/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1788 - accuracy: 0.9254
# Epoch 218/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1674 - accuracy: 0.9308
# Epoch 219/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1679 - accuracy: 0.9294
# Epoch 220/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1725 - accuracy: 0.9254
# Epoch 221/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1678 - accuracy: 0.9322
# Epoch 222/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1651 - accuracy: 0.9349
# Epoch 223/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1705 - accuracy: 0.9308
# Epoch 224/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1848 - accuracy: 0.9254
# Epoch 225/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1926 - accuracy: 0.9104
# Epoch 226/1000
# 24/24 [==============================] - 1s 39ms/step - loss: 0.1846 - accuracy: 0.9267
# Epoch 227/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1746 - accuracy: 0.9267
# Epoch 228/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1616 - accuracy: 0.9389
# Epoch 229/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1700 - accuracy: 0.9376
# Epoch 230/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1602 - accuracy: 0.9267
# Epoch 231/1000
# 24/24 [==============================] - 1s 40ms/step - loss: 0.1703 - accuracy: 0.9308
# Epoch 232/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1608 - accuracy: 0.9335
# Epoch 233/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1666 - accuracy: 0.9308
# Epoch 234/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1592 - accuracy: 0.9322
# Epoch 235/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1825 - accuracy: 0.9254
# Epoch 236/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1678 - accuracy: 0.9281
# Epoch 237/1000
# 24/24 [==============================] - 1s 41ms/step - loss: 0.1789 - accuracy: 0.9186
# Epoch 238/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.2185 - accuracy: 0.9050
# Epoch 239/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2072 - accuracy: 0.9159
# Epoch 240/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1694 - accuracy: 0.9240
# Epoch 241/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1622 - accuracy: 0.9362
# Epoch 242/1000
# 24/24 [==============================] - 1s 37ms/step - loss: 0.1629 - accuracy: 0.9335
# Epoch 243/1000
# 24/24 [==============================] - 1s 30ms/step - loss: 0.2360 - accuracy: 0.8996
# Epoch 244/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2124 - accuracy: 0.9132
# Epoch 245/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2074 - accuracy: 0.9118
# Epoch 246/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1649 - accuracy: 0.9281
# Epoch 247/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1738 - accuracy: 0.9349
# Epoch 248/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.1723 - accuracy: 0.9227
# Epoch 249/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1633 - accuracy: 0.9294
# Epoch 250/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1608 - accuracy: 0.9349
# Epoch 251/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1872 - accuracy: 0.9227
# Epoch 252/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1736 - accuracy: 0.9254
# Epoch 253/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1571 - accuracy: 0.9308
# Epoch 254/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1863 - accuracy: 0.9186
# Epoch 255/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1679 - accuracy: 0.9294
# Epoch 256/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1782 - accuracy: 0.9281
# Epoch 257/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1810 - accuracy: 0.9281
# Epoch 258/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1672 - accuracy: 0.9294
# Epoch 259/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1621 - accuracy: 0.9335
# Epoch 260/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1586 - accuracy: 0.9362
# Epoch 261/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2060 - accuracy: 0.9145
# Epoch 262/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1749 - accuracy: 0.9349
# Epoch 263/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2083 - accuracy: 0.9118
# Epoch 264/1000
# 24/24 [==============================] - 1s 35ms/step - loss: 0.1592 - accuracy: 0.9349
# Epoch 265/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.1657 - accuracy: 0.9308
# Epoch 266/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1532 - accuracy: 0.9376
# Epoch 267/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.1713 - accuracy: 0.9213
# Epoch 268/1000
# 24/24 [==============================] - 1s 47ms/step - loss: 0.1695 - accuracy: 0.9294
# Epoch 269/1000
# 24/24 [==============================] - 1s 38ms/step - loss: 0.1889 - accuracy: 0.9145
# Epoch 270/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2227 - accuracy: 0.9145
# Epoch 271/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1669 - accuracy: 0.9281
# Epoch 272/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1663 - accuracy: 0.9294
# Epoch 273/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1600 - accuracy: 0.9362
# Epoch 274/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1763 - accuracy: 0.9172
# Epoch 275/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1490 - accuracy: 0.9403
# Epoch 276/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1531 - accuracy: 0.9376
# Epoch 277/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1432 - accuracy: 0.9417
# Epoch 278/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1563 - accuracy: 0.9389
# Epoch 279/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1643 - accuracy: 0.9294
# Epoch 280/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1977 - accuracy: 0.9159
# Epoch 281/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1730 - accuracy: 0.9322
# Epoch 282/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1743 - accuracy: 0.9227
# Epoch 283/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1893 - accuracy: 0.9186
# Epoch 284/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1662 - accuracy: 0.9362
# Epoch 285/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.1537 - accuracy: 0.9308
# Epoch 286/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1622 - accuracy: 0.9281
# Epoch 287/1000
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1526 - accuracy: 0.9389
# Epoch 288/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1716 - accuracy: 0.9254
# Epoch 289/1000
# 24/24 [==============================] - 1s 43ms/step - loss: 0.1879 - accuracy: 0.9213
# Epoch 290/1000
# 24/24 [==============================] - 1s 35ms/step - loss: 0.1592 - accuracy: 0.9322
# Epoch 291/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1709 - accuracy: 0.9362
# Epoch 292/1000
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1867 - accuracy: 0.9199
# Epoch 293/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1691 - accuracy: 0.9335
# Epoch 294/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1757 - accuracy: 0.9240
# Epoch 295/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1599 - accuracy: 0.9349
# Epoch 296/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.1693 - accuracy: 0.9322
# Epoch 297/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.7748 - accuracy: 0.7734
# Epoch 298/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2823 - accuracy: 0.9064
# Epoch 299/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2162 - accuracy: 0.9132
# Epoch 300/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2840 - accuracy: 0.9037
# Epoch 301/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2132 - accuracy: 0.9199
# Epoch 302/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2108 - accuracy: 0.9064
# Epoch 303/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2285 - accuracy: 0.8969
# Epoch 304/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2149 - accuracy: 0.9132
# Epoch 305/1000
# 24/24 [==============================] - 1s 35ms/step - loss: 0.2085 - accuracy: 0.9199
# Epoch 306/1000
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2041 - accuracy: 0.9118
# Epoch 307/1000
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2075 - accuracy: 0.9118

# %%
y_pred = cnn_model.predict(test_X).argmax(axis=1)
# Out:
# 11/11 [==============================] - 0s 8ms/step

# %%
CNN_acc = accuracy_score(np.array(labels_df["Class"]), y_pred)
print("Accuracy: ", CNN_acc)
# Out:
# Accuracy:  0.39274924471299094

# %%
cnn_testing_df = test_df.copy()
cnn_testing_df["Class"] = y_pred
cnn_testing_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.864588  0.380165  0.866602  0.393443  0.869459  0.418033  0.871832
# 1    0.894788  0.371901  0.890944  0.368852  0.886508  0.368852  0.881579
# 2    0.870434  0.776860  0.883155  0.803279  0.895762  0.827869  0.906920
# 3    0.934730  0.545455  0.930867  0.549180  0.926936  0.557377  0.922027
# 4    0.909888  0.603306  0.910906  0.614754  0.911349  0.622951  0.909357
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.930833  0.396694  0.935248  0.409836  0.939601  0.426230  0.937135
# 327  0.869459  0.438017  0.873418  0.459016  0.876279  0.475410  0.877193
# 328  0.759864  0.404959  0.772639  0.418033  0.783731  0.434426  0.791910
# 329  0.812957  0.338843  0.820837  0.336066  0.826595  0.319672  0.829435
# 330  0.866537  0.330579  0.870010  0.352459  0.872869  0.368852  0.875244
#
#             7         8         9  ...       444       445       446  \
# 0    0.425000  0.876163  0.434426  ...  0.893903  0.407692  0.900000
# 1    0.358333  0.878610  0.344262  ...  0.863658  0.476923  0.871635
# 2    0.841667  0.919726  0.827869  ...  0.930869  0.369231  0.926923
# 3    0.558333  0.920215  0.549180  ...  0.914066  0.415385  0.917308
# 4    0.633333  0.909447  0.622951  ...  0.891503  0.461538  0.899038
# ..        ...       ...       ...  ...       ...       ...       ...
# 326  0.433333  0.942242  0.434426  ...  0.942391  0.361538  0.948077
# 327  0.483333  0.879589  0.483607  ...  0.902544  0.676923  0.911058
# 328  0.433333  0.800783  0.418033  ...  0.815651  0.169231  0.813462
# 329  0.300000  0.835047  0.278689  ...  0.898704  0.692308  0.909615
# 330  0.375000  0.879099  0.377049  ...  0.893903  0.492308  0.893269
#
#           447       448       449                Name   Day         ROI  Class
# 0    0.390625  0.903958  0.380952  1001_c12_cp2_63_48  1001  1001_63_48      1
# 1    0.468750  0.880309  0.452381  1002_c11_cp2_41_44  1002  1002_41_44      2
# 2    0.367188  0.923263  0.373016  1002_c15_cp1_20_48  1002  1002_20_48      1
# 3    0.414062  0.920849  0.404762  1003_c11_cp2_38_48  1003  1003_38_48      2
# 4    0.460938  0.910232  0.460317  1004_c10_cp2_30_49  1004  1004_30_49      2
# ..        ...       ...       ...                 ...   ...         ...    ...
# 326  0.367188  0.953185  0.365079   997_c12_cp2_62_59   997   997_62_59      1
# 327  0.679688  0.919884  0.682540   998_c12_cp2_37_48   998   998_37_48      1
# 328  0.156250  0.813224  0.142857  999_c11_cp2_102_34   999  999_102_34      1
# 329  0.703125  0.921332  0.706349   999_c11_cp3_37_44   999   999_37_44      1
# 330  0.492188  0.893340  0.492063   999_c14_cp1_53_37   999   999_53_37      1
#
# [331 rows x 454 columns]

# %%
CNN_ROI = {}
data = cnn_testing_df.to_numpy()
for item in data:
    part = item[450].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[452]
    if day in CNN_ROI:
        CNN_ROI[day].append([x, y, category])
    else:
        CNN_ROI[day] = [[x, y, category]]

# %%
folder_name = "3rd_CNN_Categorical_Wind_Pressure_ROI_Image"
folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_img = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in CNN_ROI:
        for point in CNN_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list[point[2]]

            size = 2

            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])

            cv2.drawContours(final_img, [vertices.reshape((-1, 1, 2))], -1, color, thickness = cv2.FILLED)

        cv2.imwrite(folder_path + "/day" + str(number) + ".png", final_img)

# %%
#Accuracy
# SOM Accuracy
print("SOM accuracy: ", SOM_acc)

# SOM Accuracy
print("CNN accuracy: ", CNN_acc)
# Out:
# SOM accuracy:  0.4471299093655589
# CNN accuracy:  0.39274924471299094
