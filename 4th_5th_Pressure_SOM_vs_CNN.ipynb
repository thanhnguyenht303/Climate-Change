# %%
from google.colab import drive
drive.mount("/content/drive")
import shutil
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import cv2
import math
import os
import numpy as np
import pandas as pd
from numpy.ma.core import ceil
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors
import matplotlib.colors as colors
from sklearn.decomposition import PCA
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, GlobalMaxPooling2D, Dense, Flatten, Dropout, MaxPooling2D, LSTM, Lambda, Conv1D, GlobalMaxPooling1D
from keras.callbacks import TensorBoard, EarlyStopping
from keras.utils import to_categorical

# %%
data_path = "/content/drive/MyDrive/Location_Season_Data/"

# %%
train_df = pd.read_csv(data_path + "Location_Season_Pressure_first_3_year_ROI.csv")
train_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.475692  0.473846  0.471385  0.468923  0.465846  0.462769  0.460308
# 1     0.464615  0.463385  0.462769  0.460923  0.460308  0.457846  0.455385
# 2     0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# 3     0.552000  0.544000  0.536615  0.529846  0.524923  0.521846  0.520000
# 4     0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# ...        ...       ...       ...       ...       ...       ...       ...
# 1063  0.930833  0.935248  0.939601  0.937135  0.942242  0.940599  0.940394
# 1064  0.869459  0.873418  0.876279  0.877193  0.879589  0.879725  0.879310
# 1065  0.759864  0.772639  0.783731  0.791910  0.800783  0.806087  0.810837
# 1066  0.812957  0.820837  0.826595  0.829435  0.835047  0.838979  0.843350
# 1067  0.866537  0.870010  0.872869  0.875244  0.879099  0.882671  0.881773
#
#              7         8         9  ...       223       224  225  226  227  \
# 0     0.456615  0.453538  0.450462  ...  0.435077  0.443077    1    1    1
# 1     0.452923  0.451077  0.450462  ...  0.454769  0.475077    1    0    1
# 2     0.235692  0.237538  0.240615  ...  0.246154  0.264615    1    0    0
# 3     0.519385  0.520615  0.523077  ...  0.475077  0.492923    1    1    1
# 4     0.235692  0.237538  0.240615  ...  0.246154  0.264615    1    0    0
# ...        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 1063  0.935167  0.934217  0.936547  ...  0.948077  0.953185    1    0    1
# 1064  0.874263  0.870889  0.869159  ...  0.911058  0.919884    1    0    1
# 1065  0.810413  0.810015  0.810133  ...  0.813462  0.813224    1    1    1
# 1066  0.843320  0.844379  0.848008  ...  0.909615  0.921332    1    0    1
# 1067  0.877210  0.869907  0.864240  ...  0.893269  0.893340    1    0    1
#
#       228  season                Name  Day  Class
# 0       0       2   116_c7_cp2_100_32  116      0
# 1       0       2    125_c3_cp2_49_32  125      0
# 2       0       2    120_c1_cp2_31_29  120      0
# 3       0       2    127_c3_cp3_96_38  127      0
# 4       0       2    120_c2_cp2_31_29  120      0
# ...   ...     ...                 ...  ...    ...
# 1063    1       3   997_c12_cp2_62_59  997      3
# 1064    1       3   998_c12_cp2_37_48  998      2
# 1065    0       3  999_c11_cp2_102_34  999      2
# 1066    0       3   999_c11_cp3_37_44  999      2
# 1067    0       3   999_c14_cp1_53_37  999      1
#
# [1068 rows x 233 columns]

# %%
all_df = pd.read_csv(data_path + "Location_Season_Pressure_ROI.csv")
all_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.904043  0.904576  0.904043  0.900097  0.896721  0.889053  0.882266
# 1     0.854847  0.857352  0.859717  0.859649  0.861968  0.862052  0.863054
# 2     0.886995  0.881207  0.876766  0.872807  0.872736  0.872361  0.873892
# 3     0.861179  0.864167  0.866050  0.867446  0.871268  0.871870  0.872906
# 4     0.915246  0.914800  0.915246  0.915205  0.919236  0.921453  0.923645
# ...        ...       ...       ...       ...       ...       ...       ...
# 3647  0.672187  0.668452  0.665855  0.662768  0.662261  0.660285  0.659113
# 3648  0.950804  0.950341  0.953726  0.954191  0.957416  0.957781  0.958621
# 3649  0.918169  0.925998  0.932294  0.938596  0.945179  0.951399  0.954680
# 3650  0.621042  0.622201  0.623965  0.625731  0.628977  0.630830  0.632020
# 3651  0.905991  0.906524  0.906965  0.905458  0.906510  0.904271  0.901478
#
#              7         8         9  ...       222       223       224  225  \
# 0     0.870825  0.863525  0.860797  ...  0.904945  0.914904  0.925676    1
# 1     0.859037  0.858125  0.859321  ...  0.862218  0.867308  0.874035    1
# 2     0.870334  0.865488  0.862273  ...  0.915506  0.921154  0.926641    1
# 3     0.868861  0.866470  0.865224  ...  0.875660  0.881731  0.889479    1
# 4     0.920432  0.918999  0.919823  ...  0.943831  0.946154  0.952220    1
# ...        ...       ...       ...  ...       ...       ...       ...  ...
# 3647  0.653242  0.648012  0.644368  ...  0.730197  0.738462  0.747587    1
# 3648  0.953340  0.949435  0.946877  ...  0.939030  0.941827  0.946911    1
# 3649  0.954322  0.950417  0.948352  ...  0.935670  0.936538  0.937741    1
# 3650  0.629666  0.628375  0.628136  ...  0.683629  0.694712  0.707529    1
# 3651  0.891454  0.882180  0.875061  ...  0.915506  0.925481  0.935811    1
#
#       226  227  228  season                Name   Day
# 0       0    0    1       2   3449_c9_cp2_29_58  3449
# 1       1    1    1       2   3450_c8_cp2_98_50  3450
# 2       0    1    1       2   3450_c8_cp3_59_56  3450
# 3       1    1    1       2   3451_c8_cp2_99_50  3451
# 4       0    1    1       2   3452_c8_cp3_55_59  3452
# ...   ...  ...  ...     ...                 ...   ...
# 3647    0    0    0       3   1648_c3_cp2_15_28  1648
# 3648    0    1    1       3   1648_c9_cp3_65_62  1648
# 3649    0    1    1       3  1649_c11_cp1_61_51  1649
# 3650    0    0    0       3   1649_c3_cp2_16_25  1649
# 3651    0    0    1       3   1649_c8_cp2_34_50  1649
#
# [3652 rows x 232 columns]

# %%
test_df = all_df[(all_df["Day"] >= 1096) & (all_df["Day"] <= 1825)]
test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
test_df = test_df.drop_duplicates(subset = "ROI")
test_df = test_df.sort_values(by = "Name")
test_df.reset_index(drop = True, inplace = True)
test_df
# Out:
# <ipython-input-6-eeb1e0cc003e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.333496  0.334632  0.336745  0.339697  0.342170  0.343842
# 1    0.148076  0.148004  0.148563  0.148635  0.148801  0.147766  0.146798
# 2    0.550901  0.551120  0.550414  0.549220  0.549682  0.547865  0.545320
# 3    0.077935  0.074489  0.071603  0.068713  0.066079  0.062347  0.059113
# 4    0.087189  0.083252  0.078909  0.074561  0.070485  0.065783  0.061084
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.176241  0.175353  0.173489  0.172296  0.169858  0.167488
# 675  0.145153  0.142648  0.140283  0.137914  0.134606  0.131566  0.128571
# 676  0.143205  0.144109  0.145641  0.146686  0.148311  0.149730  0.150739
# 677  0.191914  0.188413  0.185095  0.182261  0.180127  0.178203  0.176847
# 678  0.154895  0.149464  0.145153  0.141326  0.138522  0.135493  0.133990
#
#             7         8         9  ...       223       224  225  226  227  \
# 0    0.344303  0.344134  0.344319  ...  0.425962  0.433398    1    0    1
# 1    0.144401  0.141384  0.138219  ...  0.083654  0.075290    0    1    1
# 2    0.539784  0.534119  0.529759  ...  0.638942  0.653475    1    0    1
# 3    0.055010  0.051055  0.046237  ...  0.113462  0.118726    0    0    1
# 4    0.056483  0.051546  0.046237  ...  0.072596  0.076737    0    1    1
# ..        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 674  0.164047  0.160530  0.157403  ...  0.219712  0.225869    0    0    1
# 675  0.125737  0.122730  0.120512  ...  0.150481  0.152510    0    0    1
# 676  0.151768  0.153657  0.156419  ...  0.162500  0.169884    0    1    1
# 677  0.175344  0.172803  0.170684  ...  0.162500  0.168919    0    1    1
# 678  0.131139  0.129602  0.128382  ...  0.156250  0.162162    0    1    1
#
#      228  season                Name   Day          ROI
# 0      0       1   1099_c8_cp2_53_25  1099   1099_53_25
# 1      0       1  1106_c2_cp2_100_11  1106  1106_100_11
# 2      0       1  1111_c10_cp2_53_37  1111   1111_53_37
# 3      0       1   1121_c1_cp1_72_15  1121   1121_72_15
# 4      0       1   1123_c1_cp1_76_16  1123   1123_76_16
# ..   ...     ...                 ...   ...          ...
# 674    0       4   1815_c1_cp1_71_15  1815   1815_71_15
# 675    0       4   1816_c1_cp1_69_19  1816   1816_69_19
# 676    0       4   1817_c1_cp1_82_23  1817   1817_82_23
# 677    0       4   1818_c1_cp1_89_22  1818   1818_89_22
# 678    0       4   1819_c1_cp1_92_21  1819   1819_92_21
#
# [679 rows x 233 columns]

# %%
X_train = train_df.drop(columns = ["225", "226", "227", "228", "season", "Name", "Day", "Class"])
Y_train = train_df["Class"]

X_test = test_df.drop(columns = ["225", "226", "227", "228", "season", "Name", "Day", "ROI"])

# %% [markdown]
# # **SOM**

# %%
#Normalization
def minmax_scaler(data):
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(data)
    return scaled
#Euclidean distance
def e_distance(x, y):
    return distance.euclidean(x, y)

#Manhanttan distance
def m_distance(x, y):
    return distance.cityblock(x, y)

#Best Matching Unit search
def winning_neuron(data, t, som, num_rows, num_cols):
  winner = [0,0]
  shortest_distance = np.sqrt(data.shape[1]) # initialise with max distance
  input_data = data[t]
  for row in range(num_rows):
    for col in range(num_cols):
      distance = e_distance(som[row][col], data[t])
      if distance < shortest_distance:
        shortest_distance = distance
        winner = [row,col]
  return winner

#Learning rate and neighbourhood range calculation
def decay(step, max_steps,max_learning_rate,max_m_dsitance):
  coefficient = 1.0 - (np.float64(step)/max_steps)
  learning_rate = coefficient*max_learning_rate
  neighbourhood_range = ceil(coefficient * max_m_dsitance)
  return learning_rate, neighbourhood_range

# %%
num_rows = 33
num_cols = 33
max_m_dsitance = 7
max_learning_rate = 0.75
max_steps = 150000

# %%
#main function

train_x_norm = minmax_scaler(X_train) # normalisation
# initialising self-organising map
num_dims = train_x_norm.shape[1] # numnber of dimensions in the input data
#np.random.seed(40)
som = np.random.random_sample(size=(num_rows, num_cols, num_dims)) # map construction

# start training iterations
for step in range(max_steps):
  if (step+1) % 1000 == 0:
    print("Iteration: ", step+1) # print out the current iteration for every 1k
  learning_rate, neighbourhood_range = decay(step, max_steps,max_learning_rate,max_m_dsitance)

  t = np.random.randint(0,high=train_x_norm.shape[0]) # random index of traing data
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  for row in range(num_rows):
    for col in range(num_cols):
      if m_distance([row,col],winner) <= neighbourhood_range:
        som[row][col] += learning_rate*(train_x_norm[t]-som[row][col]) #update neighbour's weight

print("SOM training completed")
# Out:
# Iteration:  1000
# Iteration:  2000
# Iteration:  3000
# Iteration:  4000
# Iteration:  5000
# Iteration:  6000
# Iteration:  7000
# Iteration:  8000
# Iteration:  9000
# Iteration:  10000
# Iteration:  11000
# Iteration:  12000
# Iteration:  13000
# Iteration:  14000
# Iteration:  15000
# Iteration:  16000
# Iteration:  17000
# Iteration:  18000
# Iteration:  19000
# Iteration:  20000
# Iteration:  21000
# Iteration:  22000
# Iteration:  23000
# Iteration:  24000
# Iteration:  25000
# Iteration:  26000
# Iteration:  27000
# Iteration:  28000
# Iteration:  29000
# Iteration:  30000
# Iteration:  31000
# Iteration:  32000
# Iteration:  33000
# Iteration:  34000
# Iteration:  35000
# Iteration:  36000
# Iteration:  37000
# Iteration:  38000
# Iteration:  39000
# Iteration:  40000
# Iteration:  41000
# Iteration:  42000
# Iteration:  43000
# Iteration:  44000
# Iteration:  45000
# Iteration:  46000
# Iteration:  47000
# Iteration:  48000
# Iteration:  49000
# Iteration:  50000
# Iteration:  51000
# Iteration:  52000
# Iteration:  53000
# Iteration:  54000
# Iteration:  55000
# Iteration:  56000
# Iteration:  57000
# Iteration:  58000
# Iteration:  59000
# Iteration:  60000
# Iteration:  61000
# Iteration:  62000
# Iteration:  63000
# Iteration:  64000
# Iteration:  65000
# Iteration:  66000
# Iteration:  67000
# Iteration:  68000
# Iteration:  69000
# Iteration:  70000
# Iteration:  71000
# Iteration:  72000
# Iteration:  73000
# Iteration:  74000
# Iteration:  75000
# Iteration:  76000
# Iteration:  77000
# Iteration:  78000
# Iteration:  79000
# Iteration:  80000
# Iteration:  81000
# Iteration:  82000
# Iteration:  83000
# Iteration:  84000
# Iteration:  85000
# Iteration:  86000
# Iteration:  87000
# Iteration:  88000
# Iteration:  89000
# Iteration:  90000
# Iteration:  91000
# Iteration:  92000
# Iteration:  93000
# Iteration:  94000
# Iteration:  95000
# Iteration:  96000
# Iteration:  97000
# Iteration:  98000
# Iteration:  99000
# Iteration:  100000
# Iteration:  101000
# Iteration:  102000
# Iteration:  103000
# Iteration:  104000
# Iteration:  105000
# Iteration:  106000
# Iteration:  107000
# Iteration:  108000
# Iteration:  109000
# Iteration:  110000
# Iteration:  111000
# Iteration:  112000
# Iteration:  113000
# Iteration:  114000
# Iteration:  115000
# Iteration:  116000
# Iteration:  117000
# Iteration:  118000
# Iteration:  119000
# Iteration:  120000
# Iteration:  121000
# Iteration:  122000
# Iteration:  123000
# Iteration:  124000
# Iteration:  125000
# Iteration:  126000
# Iteration:  127000
# Iteration:  128000
# Iteration:  129000
# Iteration:  130000
# Iteration:  131000
# Iteration:  132000
# Iteration:  133000
# Iteration:  134000
# Iteration:  135000
# Iteration:  136000
# Iteration:  137000
# Iteration:  138000
# Iteration:  139000
# Iteration:  140000
# Iteration:  141000
# Iteration:  142000
# Iteration:  143000
# Iteration:  144000
# Iteration:  145000
# Iteration:  146000
# Iteration:  147000
# Iteration:  148000
# Iteration:  149000
# Iteration:  150000
# SOM training completed

# %%
label_data = np.array(Y_train)
map = np.empty(shape=(num_rows, num_cols), dtype=object)

for row in range(num_rows):
  for col in range(num_cols):
    map[row][col] = [] # empty list to store the label

for t in range(train_x_norm.shape[0]):
  if (t+1) % 1000 == 0:
    print("sample data: ", t+1)
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  map[winner[0]][winner[1]].append(label_data[t]) # label of winning neuron
# Out:
# sample data:  1000

# %%
map_table = {}
for i in range(len(map)):
    for j in range(len(map[0])):
        if len(map[i][j]) == 0:
            map_table[i, j] = [None]
        else:
            hash_table = {}
            for k in map[i][j]:
                if k in hash_table:
                    hash_table[k] += 1
                else:
                    hash_table[k] = 1
            for key, value in hash_table.items():
                percentage = [key, round((value / len(map[i][j])), 2)]
                if (i, j) not in map_table:
                    map_table[i, j] = []
                map_table[i, j].append(percentage)

# %%
# construct label map
label_map = np.zeros(shape=(num_rows, num_cols),dtype=np.int64)
for row in range(num_rows):
  for col in range(num_cols):
    label_list = map[row][col]
    if len(label_list)==0:
      label = 3
    else:
      label = max(label_list, key=label_list.count)
    label_map[row][col] = label

title = ('Iteration ' + str(max_steps))
cmap = colors.ListedColormap(['tab:green', 'tab:red', 'tab:orange', 'tab:blue'])
plt.imshow(label_map, cmap=cmap)
plt.colorbar()
plt.title(title)
plt.show()

# %%
# test data

# using the trained som, search the winning node of corresponding to the test data
# get the label of the winning node

data_frame = minmax_scaler(X_test) # normalisation

winner_labels = []
pre_labels = []

for t in range(data_frame.shape[0]):
  winner = winning_neuron(data_frame, t, som, num_rows, num_cols)
  row = winner[0]
  col = winner[1]
  pred = map_table[row, col]
  predicted = label_map[row][col]
  pre_labels.append(pred)
  winner_labels.append(predicted)

# %%
SOM_test_df = test_df.copy()
SOM_test_df["Class"] = winner_labels
SOM_test_df["Percentage"] = pre_labels
SOM_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.333496  0.334632  0.336745  0.339697  0.342170  0.343842
# 1    0.148076  0.148004  0.148563  0.148635  0.148801  0.147766  0.146798
# 2    0.550901  0.551120  0.550414  0.549220  0.549682  0.547865  0.545320
# 3    0.077935  0.074489  0.071603  0.068713  0.066079  0.062347  0.059113
# 4    0.087189  0.083252  0.078909  0.074561  0.070485  0.065783  0.061084
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.176241  0.175353  0.173489  0.172296  0.169858  0.167488
# 675  0.145153  0.142648  0.140283  0.137914  0.134606  0.131566  0.128571
# 676  0.143205  0.144109  0.145641  0.146686  0.148311  0.149730  0.150739
# 677  0.191914  0.188413  0.185095  0.182261  0.180127  0.178203  0.176847
# 678  0.154895  0.149464  0.145153  0.141326  0.138522  0.135493  0.133990
#
#             7         8         9  ...  225  226  227  228  season  \
# 0    0.344303  0.344134  0.344319  ...    1    0    1    0       1
# 1    0.144401  0.141384  0.138219  ...    0    1    1    0       1
# 2    0.539784  0.534119  0.529759  ...    1    0    1    0       1
# 3    0.055010  0.051055  0.046237  ...    0    0    1    0       1
# 4    0.056483  0.051546  0.046237  ...    0    1    1    0       1
# ..        ...       ...       ...  ...  ...  ...  ...  ...     ...
# 674  0.164047  0.160530  0.157403  ...    0    0    1    0       4
# 675  0.125737  0.122730  0.120512  ...    0    0    1    0       4
# 676  0.151768  0.153657  0.156419  ...    0    1    1    0       4
# 677  0.175344  0.172803  0.170684  ...    0    1    1    0       4
# 678  0.131139  0.129602  0.128382  ...    0    1    1    0       4
#
#                    Name   Day          ROI  Class  Percentage
# 0     1099_c8_cp2_53_25  1099   1099_53_25      1  [[1, 1.0]]
# 1    1106_c2_cp2_100_11  1106  1106_100_11      0  [[0, 1.0]]
# 2    1111_c10_cp2_53_37  1111   1111_53_37      0  [[0, 1.0]]
# 3     1121_c1_cp1_72_15  1121   1121_72_15      0  [[0, 1.0]]
# 4     1123_c1_cp1_76_16  1123   1123_76_16      0  [[0, 1.0]]
# ..                  ...   ...          ...    ...         ...
# 674   1815_c1_cp1_71_15  1815   1815_71_15      0  [[0, 1.0]]
# 675   1816_c1_cp1_69_19  1816   1816_69_19      0  [[0, 1.0]]
# 676   1817_c1_cp1_82_23  1817   1817_82_23      0  [[0, 1.0]]
# 677   1818_c1_cp1_89_22  1818   1818_89_22      0  [[0, 1.0]]
# 678   1819_c1_cp1_92_21  1819   1819_92_21      3      [None]
#
# [679 rows x 235 columns]

# %%
# Assuming your DataFrame is named "SOM_test_df"
SOM_test_df['Percentage'] = SOM_test_df['Percentage'].apply(lambda x: [] if x == [None] else x)

# Print the updated DataFrame
SOM_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.333496  0.334632  0.336745  0.339697  0.342170  0.343842
# 1    0.148076  0.148004  0.148563  0.148635  0.148801  0.147766  0.146798
# 2    0.550901  0.551120  0.550414  0.549220  0.549682  0.547865  0.545320
# 3    0.077935  0.074489  0.071603  0.068713  0.066079  0.062347  0.059113
# 4    0.087189  0.083252  0.078909  0.074561  0.070485  0.065783  0.061084
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.176241  0.175353  0.173489  0.172296  0.169858  0.167488
# 675  0.145153  0.142648  0.140283  0.137914  0.134606  0.131566  0.128571
# 676  0.143205  0.144109  0.145641  0.146686  0.148311  0.149730  0.150739
# 677  0.191914  0.188413  0.185095  0.182261  0.180127  0.178203  0.176847
# 678  0.154895  0.149464  0.145153  0.141326  0.138522  0.135493  0.133990
#
#             7         8         9  ...  225  226  227  228  season  \
# 0    0.344303  0.344134  0.344319  ...    1    0    1    0       1
# 1    0.144401  0.141384  0.138219  ...    0    1    1    0       1
# 2    0.539784  0.534119  0.529759  ...    1    0    1    0       1
# 3    0.055010  0.051055  0.046237  ...    0    0    1    0       1
# 4    0.056483  0.051546  0.046237  ...    0    1    1    0       1
# ..        ...       ...       ...  ...  ...  ...  ...  ...     ...
# 674  0.164047  0.160530  0.157403  ...    0    0    1    0       4
# 675  0.125737  0.122730  0.120512  ...    0    0    1    0       4
# 676  0.151768  0.153657  0.156419  ...    0    1    1    0       4
# 677  0.175344  0.172803  0.170684  ...    0    1    1    0       4
# 678  0.131139  0.129602  0.128382  ...    0    1    1    0       4
#
#                    Name   Day          ROI  Class  Percentage
# 0     1099_c8_cp2_53_25  1099   1099_53_25      1  [[1, 1.0]]
# 1    1106_c2_cp2_100_11  1106  1106_100_11      0  [[0, 1.0]]
# 2    1111_c10_cp2_53_37  1111   1111_53_37      0  [[0, 1.0]]
# 3     1121_c1_cp1_72_15  1121   1121_72_15      0  [[0, 1.0]]
# 4     1123_c1_cp1_76_16  1123   1123_76_16      0  [[0, 1.0]]
# ..                  ...   ...          ...    ...         ...
# 674   1815_c1_cp1_71_15  1815   1815_71_15      0  [[0, 1.0]]
# 675   1816_c1_cp1_69_19  1816   1816_69_19      0  [[0, 1.0]]
# 676   1817_c1_cp1_82_23  1817   1817_82_23      0  [[0, 1.0]]
# 677   1818_c1_cp1_89_22  1818   1818_89_22      0  [[0, 1.0]]
# 678   1819_c1_cp1_92_21  1819   1819_92_21      3          []
#
# [679 rows x 235 columns]

# %%
def calculate_distance(x1, y1, x2, y2):
    delta_x = x2 - x1
    delta_y = y2 - y1
    distance = math.sqrt(delta_x**2 + delta_y**2)
    return distance

# %%
SOM_ROI = {}

data = SOM_test_df.to_numpy()
for item in data:
    part = item[230].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[233]
    percentage = item[234]
    if day in SOM_ROI:
        found_duplicate = False
        for ele in SOM_ROI[day]:
            if x == ele[0] and y == ele[1]:
                found_duplicate = True
                break
        if not found_duplicate:
            SOM_ROI[day].append([x, y, category, percentage])
    else:
        SOM_ROI[day] = [[x, y, category, percentage]]

# %%
One_SOM_ROI = {}
Many_SOM_ROI = {}

for key, value in SOM_ROI.items():
    if len(value) <= 1:
        One_SOM_ROI[key] = value
    else:
        Many_SOM_ROI[key] = value

# %%
Many_SOM = {}
for key, value in Many_SOM_ROI.items():
    Many_SOM[key] = [[value[0]]]
    max_len = 0
    for i in value:
        if i[3] is None:
            continue
        else:
            if max_len < len(i[3]):
                max_len = len(i[3])
    space = max_len * 9 + (max_len - 1) * 6 + 16
    i = 1
    while i < len(value):
        x1 = value[i][0]
        y1 = value[i][1]
        found_smaller = True
        for k in Many_SOM[key]:
            found_smaller = True
            for j in k:
                x2 = j[0]
                y2 = j[1]
                distance = calculate_distance(x1, y1, x2, y2)
                if distance < space:
                    found_smaller = False
                    break
            if found_smaller == True:
                k.append(value[i])
                break
        if found_smaller == False:
            Many_SOM[key].append([value[i]])
        i += 1

# %%
folder_name = "4th_5th_SOM_Categorical_Pressure_ROI_Image"
SOM_folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(SOM_folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
default_color = (0, 0, 0)
size = 1
text_color = (148, 91, 10)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in One_SOM_ROI:
        for point in One_SOM_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list.get(point[2], default_color)
            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
            cv2.drawContours(final_image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
            text = ""
            if point[3] is not None:
                text = ", ".join([f"{a}:{b}" for a, b in point[3]])
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.2
            line_thickness = 0
            position = ()
            lines = text.split(",")
            max_len * 12 + (max_len - 1) * 6 + 16
            if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                position = (x + 3, y - 2)
            else:
                position = (x - 11, y + 8)
            for i, line in enumerate(lines):
                line = line.strip()
                position = (position[0], position[1] + 6 * i)
                cv2.putText(final_image, line, position, font, font_scale, text_color, line_thickness)
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", final_image)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    f_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    height, width, _ = f_image.shape
    base_image = np.zeros((height, width, 3), dtype = np.uint8)
    base_image = cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB)

    if number in Many_SOM:
        for part in Many_SOM[number]:
            image = f_image.copy()
            for point in part:
                x = point[0]
                y = point[1]
                color = color_list[point[2]]
                vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
                cv2.drawContours(image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
                text = ""
                if point[3] is not None:
                    text = ", ".join([f"{a}:{b}" for a, b in point[3]])
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.2
                line_thickness = 0
                position = ()
                lines = text.split(",")
                max_len * 12 + (max_len - 1) * 6 + 16
                if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                    position = (x + 3, y - 2)
                else:
                    position = (x - 11, y + 8)
                for i, line in enumerate(lines):
                    line = line.strip()
                    position = (position[0], position[1] + 6 * i)
                    cv2.putText(image, line, position, font, font_scale, text_color, line_thickness)
            base_image = np.concatenate((base_image, image), axis = 1)
        base_image = base_image[:, width:, :]
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", base_image)

# %% [markdown]
# # **CNN**

# %%
#Reshape training and testing data
train_X = X_train.to_numpy().reshape(X_train.shape[0],15,15,1).astype("float32")

train_Y = Y_train.to_numpy()

test_X = np.array(X_test).reshape(X_test.shape[0], 15, 15, 1)

train_Y = tf.keras.utils.to_categorical(train_Y)

# %%
#Define the model architecture
model = Sequential()
model.add(Conv2D(filters =16, kernel_size = 3, activation = "relu", input_shape = (15, 15, 1)))
model.add(Conv2D(filters = 32, kernel_size = 3, activation = "relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters = 64, kernel_size = 3, activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(64, activation = "relu"))
model.add(Dense(32, activation = "relu"))
model.add(Dense(4, activation = "softmax"))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='loss', patience=30)
tensorboard_callback = TensorBoard(log_dir="./logs")

# Fit the model
model.fit(train_X, train_Y, epochs=1000, batch_size=16, callbacks=[tensorboard_callback, early_stopping])
# Out:
# Epoch 1/1000
# 67/67 [==============================] - 3s 15ms/step - loss: 1.3108 - accuracy: 0.4185
# Epoch 2/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 1.0444 - accuracy: 0.5009
# Epoch 3/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.9452 - accuracy: 0.5440
# Epoch 4/1000
# 67/67 [==============================] - 1s 12ms/step - loss: 0.9254 - accuracy: 0.5571
# Epoch 5/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.9316 - accuracy: 0.5552
# Epoch 6/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8729 - accuracy: 0.5908
# Epoch 7/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8943 - accuracy: 0.5684
# Epoch 8/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8743 - accuracy: 0.5852
# Epoch 9/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8663 - accuracy: 0.5833
# Epoch 10/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8729 - accuracy: 0.5983
# Epoch 11/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8689 - accuracy: 0.5908
# Epoch 12/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8478 - accuracy: 0.5964
# Epoch 13/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8254 - accuracy: 0.6124
# Epoch 14/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8183 - accuracy: 0.6067
# Epoch 15/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.8346 - accuracy: 0.6114
# Epoch 16/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.7773 - accuracy: 0.6376
# Epoch 17/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.7707 - accuracy: 0.6330
# Epoch 18/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.7037 - accuracy: 0.6966
# Epoch 19/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.6513 - accuracy: 0.7182
# Epoch 20/1000
# 67/67 [==============================] - 1s 11ms/step - loss: 0.6199 - accuracy: 0.7172
# Epoch 21/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.6097 - accuracy: 0.7378
# Epoch 22/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.6182 - accuracy: 0.7116
# Epoch 23/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.5661 - accuracy: 0.7425
# Epoch 24/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.5661 - accuracy: 0.7444
# Epoch 25/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.5910 - accuracy: 0.7163
# Epoch 26/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5128 - accuracy: 0.7612
# Epoch 27/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5632 - accuracy: 0.7388
# Epoch 28/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5358 - accuracy: 0.7528
# Epoch 29/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5102 - accuracy: 0.7566
# Epoch 30/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5361 - accuracy: 0.7537
# Epoch 31/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4901 - accuracy: 0.7800
# Epoch 32/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.6425 - accuracy: 0.6985
# Epoch 33/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5138 - accuracy: 0.7762
# Epoch 34/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5115 - accuracy: 0.7594
# Epoch 35/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5166 - accuracy: 0.7631
# Epoch 36/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5070 - accuracy: 0.7622
# Epoch 37/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5085 - accuracy: 0.7575
# Epoch 38/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4888 - accuracy: 0.7949
# Epoch 39/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5113 - accuracy: 0.7715
# Epoch 40/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5046 - accuracy: 0.7762
# Epoch 41/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4725 - accuracy: 0.7875
# Epoch 42/1000
# 67/67 [==============================] - 1s 11ms/step - loss: 0.5342 - accuracy: 0.7509
# Epoch 43/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.5092 - accuracy: 0.7734
# Epoch 44/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4894 - accuracy: 0.7781
# Epoch 45/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.5140 - accuracy: 0.7631
# Epoch 46/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4686 - accuracy: 0.8015
# Epoch 47/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.5085 - accuracy: 0.7715
# Epoch 48/1000
# 67/67 [==============================] - 1s 10ms/step - loss: 0.4728 - accuracy: 0.8015
# Epoch 49/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4565 - accuracy: 0.8118
# Epoch 50/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5010 - accuracy: 0.7678
# Epoch 51/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4699 - accuracy: 0.8071
# Epoch 52/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4872 - accuracy: 0.7949
# Epoch 53/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5274 - accuracy: 0.7781
# Epoch 54/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4764 - accuracy: 0.7949
# Epoch 55/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.5495 - accuracy: 0.7500
# Epoch 56/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4706 - accuracy: 0.7912
# Epoch 57/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4574 - accuracy: 0.7949
# Epoch 58/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4656 - accuracy: 0.8015
# Epoch 59/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4486 - accuracy: 0.8165
# Epoch 60/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4828 - accuracy: 0.7968
# Epoch 61/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4544 - accuracy: 0.8090
# Epoch 62/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4481 - accuracy: 0.8081
# Epoch 63/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4800 - accuracy: 0.7884
# Epoch 64/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4519 - accuracy: 0.8127
# Epoch 65/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4411 - accuracy: 0.8212
# Epoch 66/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4558 - accuracy: 0.8052
# Epoch 67/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4508 - accuracy: 0.8258
# Epoch 68/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4485 - accuracy: 0.8090
# Epoch 69/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4237 - accuracy: 0.8240
# Epoch 70/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4333 - accuracy: 0.8258
# Epoch 71/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4214 - accuracy: 0.8287
# Epoch 72/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4144 - accuracy: 0.8287
# Epoch 73/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4572 - accuracy: 0.8109
# Epoch 74/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4636 - accuracy: 0.7921
# Epoch 75/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4247 - accuracy: 0.8174
# Epoch 76/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4393 - accuracy: 0.8202
# Epoch 77/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4208 - accuracy: 0.8258
# Epoch 78/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4457 - accuracy: 0.8062
# Epoch 79/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4323 - accuracy: 0.8137
# Epoch 80/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4240 - accuracy: 0.8249
# Epoch 81/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4293 - accuracy: 0.8184
# Epoch 82/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4143 - accuracy: 0.8333
# Epoch 83/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4532 - accuracy: 0.8221
# Epoch 84/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4521 - accuracy: 0.8081
# Epoch 85/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4131 - accuracy: 0.8268
# Epoch 86/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4318 - accuracy: 0.8137
# Epoch 87/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4304 - accuracy: 0.8212
# Epoch 88/1000
# 67/67 [==============================] - 1s 12ms/step - loss: 0.4119 - accuracy: 0.8305
# Epoch 89/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4070 - accuracy: 0.8333
# Epoch 90/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4417 - accuracy: 0.8296
# Epoch 91/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4141 - accuracy: 0.8371
# Epoch 92/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4211 - accuracy: 0.8371
# Epoch 93/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4140 - accuracy: 0.8324
# Epoch 94/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4005 - accuracy: 0.8352
# Epoch 95/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4055 - accuracy: 0.8333
# Epoch 96/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4159 - accuracy: 0.8324
# Epoch 97/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4055 - accuracy: 0.8361
# Epoch 98/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4072 - accuracy: 0.8436
# Epoch 99/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4417 - accuracy: 0.8109
# Epoch 100/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4224 - accuracy: 0.8277
# Epoch 101/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4091 - accuracy: 0.8305
# Epoch 102/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4230 - accuracy: 0.8277
# Epoch 103/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3937 - accuracy: 0.8464
# Epoch 104/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4095 - accuracy: 0.8408
# Epoch 105/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4081 - accuracy: 0.8352
# Epoch 106/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4085 - accuracy: 0.8399
# Epoch 107/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4018 - accuracy: 0.8371
# Epoch 108/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3996 - accuracy: 0.8399
# Epoch 109/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4077 - accuracy: 0.8230
# Epoch 110/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4001 - accuracy: 0.8361
# Epoch 111/1000
# 67/67 [==============================] - 1s 10ms/step - loss: 0.4041 - accuracy: 0.8436
# Epoch 112/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3908 - accuracy: 0.8427
# Epoch 113/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3845 - accuracy: 0.8446
# Epoch 114/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4110 - accuracy: 0.8408
# Epoch 115/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4043 - accuracy: 0.8371
# Epoch 116/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3939 - accuracy: 0.8474
# Epoch 117/1000
# 67/67 [==============================] - 1s 10ms/step - loss: 0.4026 - accuracy: 0.8390
# Epoch 118/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3986 - accuracy: 0.8427
# Epoch 119/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3913 - accuracy: 0.8511
# Epoch 120/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4011 - accuracy: 0.8296
# Epoch 121/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4277 - accuracy: 0.8193
# Epoch 122/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4271 - accuracy: 0.8249
# Epoch 123/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4132 - accuracy: 0.8436
# Epoch 124/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3971 - accuracy: 0.8446
# Epoch 125/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4037 - accuracy: 0.8390
# Epoch 126/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4385 - accuracy: 0.8258
# Epoch 127/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3940 - accuracy: 0.8464
# Epoch 128/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4053 - accuracy: 0.8324
# Epoch 129/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4049 - accuracy: 0.8343
# Epoch 130/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4242 - accuracy: 0.8333
# Epoch 131/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4089 - accuracy: 0.8436
# Epoch 132/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3991 - accuracy: 0.8446
# Epoch 133/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4001 - accuracy: 0.8530
# Epoch 134/1000
# 67/67 [==============================] - 1s 11ms/step - loss: 0.3792 - accuracy: 0.8474
# Epoch 135/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3892 - accuracy: 0.8446
# Epoch 136/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4175 - accuracy: 0.8258
# Epoch 137/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3949 - accuracy: 0.8399
# Epoch 138/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4051 - accuracy: 0.8305
# Epoch 139/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4070 - accuracy: 0.8361
# Epoch 140/1000
# 67/67 [==============================] - 1s 10ms/step - loss: 0.3919 - accuracy: 0.8530
# Epoch 141/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3791 - accuracy: 0.8464
# Epoch 142/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3813 - accuracy: 0.8474
# Epoch 143/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4227 - accuracy: 0.8324
# Epoch 144/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4156 - accuracy: 0.8371
# Epoch 145/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3946 - accuracy: 0.8502
# Epoch 146/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3908 - accuracy: 0.8418
# Epoch 147/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3800 - accuracy: 0.8474
# Epoch 148/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3946 - accuracy: 0.8436
# Epoch 149/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3908 - accuracy: 0.8436
# Epoch 150/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3802 - accuracy: 0.8502
# Epoch 151/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3770 - accuracy: 0.8511
# Epoch 152/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4015 - accuracy: 0.8427
# Epoch 153/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3800 - accuracy: 0.8474
# Epoch 154/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3772 - accuracy: 0.8577
# Epoch 155/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4120 - accuracy: 0.8436
# Epoch 156/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3880 - accuracy: 0.8464
# Epoch 157/1000
# 67/67 [==============================] - 1s 12ms/step - loss: 0.3875 - accuracy: 0.8352
# Epoch 158/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3879 - accuracy: 0.8502
# Epoch 159/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4016 - accuracy: 0.8380
# Epoch 160/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4103 - accuracy: 0.8352
# Epoch 161/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.4044 - accuracy: 0.8399
# Epoch 162/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4125 - accuracy: 0.8493
# Epoch 163/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3840 - accuracy: 0.8502
# Epoch 164/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3954 - accuracy: 0.8455
# Epoch 165/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4110 - accuracy: 0.8343
# Epoch 166/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3797 - accuracy: 0.8567
# Epoch 167/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3769 - accuracy: 0.8427
# Epoch 168/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3745 - accuracy: 0.8530
# Epoch 169/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3822 - accuracy: 0.8436
# Epoch 170/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3861 - accuracy: 0.8493
# Epoch 171/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4057 - accuracy: 0.8315
# Epoch 172/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.4045 - accuracy: 0.8361
# Epoch 173/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3832 - accuracy: 0.8483
# Epoch 174/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3851 - accuracy: 0.8464
# Epoch 175/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3751 - accuracy: 0.8549
# Epoch 176/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3935 - accuracy: 0.8483
# Epoch 177/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3678 - accuracy: 0.8539
# Epoch 178/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3931 - accuracy: 0.8418
# Epoch 179/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3658 - accuracy: 0.8539
# Epoch 180/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3804 - accuracy: 0.8530
# Epoch 181/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3728 - accuracy: 0.8558
# Epoch 182/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3963 - accuracy: 0.8427
# Epoch 183/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3959 - accuracy: 0.8521
# Epoch 184/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4188 - accuracy: 0.8315
# Epoch 185/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3947 - accuracy: 0.8427
# Epoch 186/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3893 - accuracy: 0.8455
# Epoch 187/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3802 - accuracy: 0.8427
# Epoch 188/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3698 - accuracy: 0.8530
# Epoch 189/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3872 - accuracy: 0.8521
# Epoch 190/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3903 - accuracy: 0.8464
# Epoch 191/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3809 - accuracy: 0.8502
# Epoch 192/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3847 - accuracy: 0.8474
# Epoch 193/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3852 - accuracy: 0.8455
# Epoch 194/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3856 - accuracy: 0.8483
# Epoch 195/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3833 - accuracy: 0.8446
# Epoch 196/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4062 - accuracy: 0.8380
# Epoch 197/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3982 - accuracy: 0.8305
# Epoch 198/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3876 - accuracy: 0.8549
# Epoch 199/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3850 - accuracy: 0.8502
# Epoch 200/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3915 - accuracy: 0.8436
# Epoch 201/1000
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3723 - accuracy: 0.8558
# Epoch 202/1000
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3752 - accuracy: 0.8530
# Epoch 203/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3861 - accuracy: 0.8493
# Epoch 204/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3958 - accuracy: 0.8530
# Epoch 205/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3957 - accuracy: 0.8455
# Epoch 206/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3992 - accuracy: 0.8390
# Epoch 207/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3862 - accuracy: 0.8427
# Epoch 208/1000
# 67/67 [==============================] - 1s 13ms/step - loss: 0.3784 - accuracy: 0.8539
# Epoch 209/1000
# 67/67 [==============================] - 1s 11ms/step - loss: 0.3894 - accuracy: 0.8558

# %%
y_pred = model.predict(test_X).argmax(axis=1)
# Out:
# 22/22 [==============================] - 0s 6ms/step

# %%
cnn_test_df = test_df.copy()
cnn_test_df["Class"] = y_pred
cnn_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.333496  0.334632  0.336745  0.339697  0.342170  0.343842
# 1    0.148076  0.148004  0.148563  0.148635  0.148801  0.147766  0.146798
# 2    0.550901  0.551120  0.550414  0.549220  0.549682  0.547865  0.545320
# 3    0.077935  0.074489  0.071603  0.068713  0.066079  0.062347  0.059113
# 4    0.087189  0.083252  0.078909  0.074561  0.070485  0.065783  0.061084
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.176241  0.175353  0.173489  0.172296  0.169858  0.167488
# 675  0.145153  0.142648  0.140283  0.137914  0.134606  0.131566  0.128571
# 676  0.143205  0.144109  0.145641  0.146686  0.148311  0.149730  0.150739
# 677  0.191914  0.188413  0.185095  0.182261  0.180127  0.178203  0.176847
# 678  0.154895  0.149464  0.145153  0.141326  0.138522  0.135493  0.133990
#
#             7         8         9  ...       224  225  226  227  228  season  \
# 0    0.344303  0.344134  0.344319  ...  0.433398    1    0    1    0       1
# 1    0.144401  0.141384  0.138219  ...  0.075290    0    1    1    0       1
# 2    0.539784  0.534119  0.529759  ...  0.653475    1    0    1    0       1
# 3    0.055010  0.051055  0.046237  ...  0.118726    0    0    1    0       1
# 4    0.056483  0.051546  0.046237  ...  0.076737    0    1    1    0       1
# ..        ...       ...       ...  ...       ...  ...  ...  ...  ...     ...
# 674  0.164047  0.160530  0.157403  ...  0.225869    0    0    1    0       4
# 675  0.125737  0.122730  0.120512  ...  0.152510    0    0    1    0       4
# 676  0.151768  0.153657  0.156419  ...  0.169884    0    1    1    0       4
# 677  0.175344  0.172803  0.170684  ...  0.168919    0    1    1    0       4
# 678  0.131139  0.129602  0.128382  ...  0.162162    0    1    1    0       4
#
#                    Name   Day          ROI  Class
# 0     1099_c8_cp2_53_25  1099   1099_53_25      2
# 1    1106_c2_cp2_100_11  1106  1106_100_11      0
# 2    1111_c10_cp2_53_37  1111   1111_53_37      2
# 3     1121_c1_cp1_72_15  1121   1121_72_15      0
# 4     1123_c1_cp1_76_16  1123   1123_76_16      0
# ..                  ...   ...          ...    ...
# 674   1815_c1_cp1_71_15  1815   1815_71_15      0
# 675   1816_c1_cp1_69_19  1816   1816_69_19      0
# 676   1817_c1_cp1_82_23  1817   1817_82_23      0
# 677   1818_c1_cp1_89_22  1818   1818_89_22      0
# 678   1819_c1_cp1_92_21  1819   1819_92_21      0
#
# [679 rows x 234 columns]

# %%
CNN_ROI = {}
data = cnn_test_df.to_numpy()
for item in data:
    part = item[230].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[233]
    if day in CNN_ROI:
        CNN_ROI[day].append([x, y, category])
    else:
        CNN_ROI[day] = [[x, y, category]]

# %%
folder_name = "4th_5th_CNN_Categorical_Pressure_ROI_Image"
folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_img = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in CNN_ROI:
        for point in CNN_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list[point[2]]

            size = 2

            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])

            cv2.drawContours(final_img, [vertices.reshape((-1, 1, 2))], -1, color, thickness = cv2.FILLED)

        cv2.imwrite(folder_path + "/day" + str(number) + ".png", final_img)
