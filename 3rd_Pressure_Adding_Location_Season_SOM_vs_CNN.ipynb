# %%
from google.colab import drive
drive.mount("/content/drive")
import shutil
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import cv2
import math
import os
import numpy as np
import pandas as pd
from numpy.ma.core import ceil
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors
import matplotlib.colors as colors
from sklearn.decomposition import PCA
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, GlobalMaxPooling2D, Dense, Flatten, Dropout, MaxPooling2D, LSTM, Lambda, Conv1D, GlobalMaxPooling1D
from keras.callbacks import TensorBoard, EarlyStopping
from keras.utils import to_categorical

# %%
train_df = pd.read_csv("/content/drive/MyDrive/Location_Season_Data/Location_Season_Pressure_Training_ROI.csv", header = None)
train_df = train_df.drop(0)
train_df.rename(columns = {229: "Season", 230: "Name", 231:"Day", 232:"Class"}, inplace = True)
train_df
# Out:
#             0         1         2         3         4         5         6  \
# 1    0.475692  0.473846  0.471385  0.468923  0.465846  0.462769  0.460308
# 2    0.464615  0.463385  0.462769  0.460923  0.460308  0.457846  0.455385
# 3    0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# 4    0.552000  0.544000  0.536615  0.529846  0.524923  0.521846  0.520000
# 5    0.248615  0.243692  0.240000  0.237538  0.235692  0.234462  0.234462
# ..        ...       ...       ...       ...       ...       ...       ...
# 733  0.865846  0.877538  0.886769  0.896615  0.904615  0.910769  0.917538
# 734  0.912615  0.915692  0.923692  0.929846  0.932308  0.935385  0.936615
# 735  0.946462  0.944615  0.944615  0.942154  0.938462  0.932308  0.929231
# 736  0.856000  0.864000  0.874462  0.876923  0.873846  0.864000  0.868923
# 737  0.935385  0.940923  0.942769  0.942769  0.942769  0.945231  0.945846
#
#             7         8         9  ...       223       224  225  226  227  \
# 1    0.456615  0.453538  0.450462  ...  0.435077  0.443077    1    1    1
# 2    0.452923  0.451077  0.450462  ...  0.454769  0.475077    1    0    1
# 3    0.235692  0.237538  0.240615  ...  0.246154  0.264615    1    0    0
# 4    0.519385  0.520615  0.523077  ...  0.475077  0.492923    1    1    1
# 5    0.235692  0.237538  0.240615  ...  0.246154  0.264615    1    0    0
# ..        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 733  0.920615  0.923692  0.926769  ...  0.934769  0.936000    1    1    1
# 734  0.937231  0.937231  0.936615  ...  0.927385  0.928615    1    1    1
# 735  0.933538  0.936615  0.936000  ...  0.936000  0.939077    1    1    1
# 736  0.872615  0.880615  0.889846  ...  0.931077  0.927385    1    1    1
# 737  0.944000  0.942154  0.938462  ...  0.944000  0.946462    1    0    1
#
#      228  Season                  Name  Day  Class
# 1      0       2  Day116_c7_cp2_100_32  116      0
# 2      0       2   Day125_c3_cp2_49_32  125      0
# 3      0       2   Day120_c1_cp2_31_29  120      0
# 4      0       2   Day127_c3_cp3_96_38  127      0
# 5      0       2   Day120_c2_cp2_31_29  120      0
# ..   ...     ...                   ...  ...    ...
# 733    1       3  Day634_c11_cp3_86_58  634      3
# 734    1       4  Day643_c12_cp2_96_62  643      3
# 735    1       3  Day620_c11_cp2_86_60  620      3
# 736    1       4  Day694_c17_cp2_86_63  694      3
# 737    1       3  Day616_c10_cp2_67_57  616      3
#
# [737 rows x 233 columns]

# %%
test_df = pd.read_csv("/content/drive/MyDrive/Location_Season_Data/Location_Season_Pressure_ROI.csv", header = None)
test_df = test_df.drop(0)
test_df.rename(columns = {229: "Season", 230: "Name", 231:"Day"}, inplace = True)
test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
test_df
# Out:
#              0         1         2         3         4         5         6  \
# 1     0.904043  0.904576  0.904043  0.900097  0.896721  0.889053  0.882266
# 2     0.854847  0.857352  0.859717  0.859649  0.861968  0.862052  0.863054
# 3     0.886995  0.881207  0.876766  0.872807  0.872736  0.872361  0.873892
# 4     0.861179  0.864167  0.866050  0.867446  0.871268  0.871870  0.872906
# 5     0.915246  0.914800  0.915246  0.915205  0.919236  0.921453  0.923645
# ...        ...       ...       ...       ...       ...       ...       ...
# 3648  0.672187  0.668452  0.665855  0.662768  0.662261  0.660285  0.659113
# 3649  0.950804  0.950341  0.953726  0.954191  0.957416  0.957781  0.958621
# 3650  0.918169  0.925998  0.932294  0.938596  0.945179  0.951399  0.954680
# 3651  0.621042  0.622201  0.623965  0.625731  0.628977  0.630830  0.632020
# 3652  0.905991  0.906524  0.906965  0.905458  0.906510  0.904271  0.901478
#
#              7         8         9  ...       223       224  225  226  227  \
# 1     0.870825  0.863525  0.860797  ...  0.914904  0.925676    1    0    0
# 2     0.859037  0.858125  0.859321  ...  0.867308  0.874035    1    1    1
# 3     0.870334  0.865488  0.862273  ...  0.921154  0.926641    1    0    1
# 4     0.868861  0.866470  0.865224  ...  0.881731  0.889479    1    1    1
# 5     0.920432  0.918999  0.919823  ...  0.946154  0.952220    1    0    1
# ...        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 3648  0.653242  0.648012  0.644368  ...  0.738462  0.747587    1    0    0
# 3649  0.953340  0.949435  0.946877  ...  0.941827  0.946911    1    0    1
# 3650  0.954322  0.950417  0.948352  ...  0.936538  0.937741    1    0    1
# 3651  0.629666  0.628375  0.628136  ...  0.694712  0.707529    1    0    0
# 3652  0.891454  0.882180  0.875061  ...  0.925481  0.935811    1    0    0
#
#       228  Season                Name   Day         ROI
# 1       1       2   3449_c9_cp2_29_58  3449  3449_29_58
# 2       1       2   3450_c8_cp2_98_50  3450  3450_98_50
# 3       1       2   3450_c8_cp3_59_56  3450  3450_59_56
# 4       1       2   3451_c8_cp2_99_50  3451  3451_99_50
# 5       1       2   3452_c8_cp3_55_59  3452  3452_55_59
# ...   ...     ...                 ...   ...         ...
# 3648    0       3   1648_c3_cp2_15_28  1648  1648_15_28
# 3649    1       3   1648_c9_cp3_65_62  1648  1648_65_62
# 3650    1       3  1649_c11_cp1_61_51  1649  1649_61_51
# 3651    0       3   1649_c3_cp2_16_25  1649  1649_16_25
# 3652    1       3   1649_c8_cp2_34_50  1649  1649_34_50
#
# [3652 rows x 233 columns]

# %%
test_df["Day"] = test_df["Day"].astype(int)
test_data = test_df[(test_df["Day"] >= 730) & (test_df["Day"] <= 1095)]
test_data = test_data.drop_duplicates(subset = "ROI")
test_data = test_data[test_data["ROI"] != "738_73_20"]
test_data = test_data.sort_values(by = "Name")
test_data.reset_index(drop = True, inplace = True)
test_data
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.864588  0.866602  0.869459  0.871832  0.876163  0.879234  0.880788
# 1    0.894788  0.890944  0.886508  0.881579  0.878610  0.873343  0.867980
# 2    0.870434  0.883155  0.895762  0.906920  0.919726  0.929799  0.939409
# 3    0.934730  0.930867  0.926936  0.922027  0.920215  0.916053  0.912315
# 4    0.909888  0.910906  0.911349  0.909357  0.909447  0.907707  0.906404
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.930833  0.935248  0.939601  0.937135  0.942242  0.940599  0.940394
# 327  0.869459  0.873418  0.876279  0.877193  0.879589  0.879725  0.879310
# 328  0.759864  0.772639  0.783731  0.791910  0.800783  0.806087  0.810837
# 329  0.812957  0.820837  0.826595  0.829435  0.835047  0.838979  0.843350
# 330  0.866537  0.870010  0.872869  0.875244  0.879099  0.882671  0.881773
#
#             7         8         9  ...       223       224  225  226  227  \
# 0    0.876719  0.873343  0.870635  ...  0.900000  0.903958    1    0    1
# 1    0.857073  0.847324  0.840630  ...  0.871635  0.880309    1    0    1
# 2    0.941552  0.944035  0.946877  ...  0.926923  0.923263    1    0    0
# 3    0.903242  0.896416  0.892277  ...  0.917308  0.920849    1    0    1
# 4    0.899804  0.895434  0.894245  ...  0.899038  0.910232    1    0    0
# ..        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 326  0.935167  0.934217  0.936547  ...  0.948077  0.953185    1    0    1
# 327  0.874263  0.870889  0.869159  ...  0.911058  0.919884    1    0    1
# 328  0.810413  0.810015  0.810133  ...  0.813462  0.813224    1    1    1
# 329  0.843320  0.844379  0.848008  ...  0.909615  0.921332    1    0    1
# 330  0.877210  0.869907  0.864240  ...  0.893269  0.893340    1    0    1
#
#      228  Season                Name   Day         ROI
# 0      1       4  1001_c12_cp2_63_48  1001  1001_63_48
# 1      0       4  1002_c11_cp2_41_44  1002  1002_41_44
# 2      1       4  1002_c15_cp1_20_48  1002  1002_20_48
# 3      1       4  1003_c11_cp2_38_48  1003  1003_38_48
# 4      1       4  1004_c10_cp2_30_49  1004  1004_30_49
# ..   ...     ...                 ...   ...         ...
# 326    1       3   997_c12_cp2_62_59   997   997_62_59
# 327    1       3   998_c12_cp2_37_48   998   998_37_48
# 328    0       3  999_c11_cp2_102_34   999  999_102_34
# 329    0       3   999_c11_cp3_37_44   999   999_37_44
# 330    0       3   999_c14_cp1_53_37   999   999_53_37
#
# [331 rows x 233 columns]

# %%
#Define training and testing data
X_train = train_df.drop(columns = ["Name", "Day", "Class"])
X_train["Season"] = X_train["Season"].astype(int)
X_train.rename(columns = {"Season": 229}, inplace = True)
Y_train = train_df["Class"]

X_test = test_data.drop(columns = ["Name", "Day", "ROI"])
X_test["Season"] = X_test["Season"].astype(int)
X_test.rename(columns = {"Season": 229}, inplace = True)

# %% [markdown]
# # **SOM**

# %%
#Normalization
def minmax_scaler(data):
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(data)
    return scaled
#Euclidean distance
def e_distance(x, y):
    return distance.euclidean(x, y)

#Manhanttan distance
def m_distance(x, y):
    return distance.cityblock(x, y)

#Best Matching Unit search
def winning_neuron(data, t, som, num_rows, num_cols):
  winner = [0,0]
  shortest_distance = np.sqrt(data.shape[1]) # initialise with max distance
  input_data = data[t]
  for row in range(num_rows):
    for col in range(num_cols):
      distance = e_distance(som[row][col], data[t])
      if distance < shortest_distance:
        shortest_distance = distance
        winner = [row,col]
  return winner

#Learning rate and neighbourhood range calculation
def decay(step, max_steps,max_learning_rate,max_m_dsitance):
  coefficient = 1.0 - (np.float64(step)/max_steps)
  learning_rate = coefficient*max_learning_rate
  neighbourhood_range = ceil(coefficient * max_m_dsitance)
  return learning_rate, neighbourhood_range

# %%
num_rows = 15
num_cols = 15
max_m_dsitance = 7
max_learning_rate = 0.75
max_steps = 20000

# %%
#main function

train_x_norm = minmax_scaler(X_train) # normalisation
# initialising self-organising map
num_dims = train_x_norm.shape[1] # numnber of dimensions in the input data
#np.random.seed(40)
som = np.random.random_sample(size=(num_rows, num_cols, num_dims)) # map construction

# start training iterations
for step in range(max_steps):
  if (step+1) % 1000 == 0:
    print("Iteration: ", step+1) # print out the current iteration for every 1k
  learning_rate, neighbourhood_range = decay(step, max_steps,max_learning_rate,max_m_dsitance)

  t = np.random.randint(0,high=train_x_norm.shape[0]) # random index of traing data
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  for row in range(num_rows):
    for col in range(num_cols):
      if m_distance([row,col],winner) <= neighbourhood_range:
        som[row][col] += learning_rate*(train_x_norm[t]-som[row][col]) #update neighbour's weight

print("SOM training completed")
# Out:
# Iteration:  1000
# Iteration:  2000
# Iteration:  3000
# Iteration:  4000
# Iteration:  5000
# Iteration:  6000
# Iteration:  7000
# Iteration:  8000
# Iteration:  9000
# Iteration:  10000
# Iteration:  11000
# Iteration:  12000
# Iteration:  13000
# Iteration:  14000
# Iteration:  15000
# Iteration:  16000
# Iteration:  17000
# Iteration:  18000
# Iteration:  19000
# Iteration:  20000
# SOM training completed

# %%
label_data = np.array(Y_train)
map = np.empty(shape=(num_rows, num_cols), dtype=object)

for row in range(num_rows):
  for col in range(num_cols):
    map[row][col] = [] # empty list to store the label

for t in range(train_x_norm.shape[0]):
  if (t+1) % 1000 == 0:
    print("sample data: ", t+1)
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  map[winner[0]][winner[1]].append(label_data[t]) # label of winning neuron

# %%
map_table = {}
for i in range(len(map)):
    for j in range(len(map[0])):
        if len(map[i][j]) == 0:
            map_table[i, j] = [None]
        else:
            hash_table = {}
            for k in map[i][j]:
                if k in hash_table:
                    hash_table[k] += 1
                else:
                    hash_table[k] = 1
            for key, value in hash_table.items():
                percentage = [key, round((value / len(map[i][j])), 2)]
                if (i, j) not in map_table:
                    map_table[i, j] = []
                map_table[i, j].append(percentage)

# %%
# construct label map
label_map = np.zeros(shape=(num_rows, num_cols),dtype=np.int64)
for row in range(num_rows):
  for col in range(num_cols):
    label_list = map[row][col]
    if len(label_list)==0:
      label = 3
    else:
      label = max(label_list, key=label_list.count)
    label_map[row][col] = label

title = ('Iteration ' + str(max_steps))
cmap = colors.ListedColormap(['tab:green', 'tab:red', 'tab:orange', 'tab:blue'])
plt.imshow(label_map, cmap=cmap)
plt.colorbar()
plt.title(title)
plt.show()

# %%
# test data

# using the trained som, search the winning node of corresponding to the test data
# get the label of the winning node

data_frame = minmax_scaler(X_test) # normalisation

winner_labels = []
pre_labels = []

for t in range(data_frame.shape[0]):
  winner = winning_neuron(data_frame, t, som, num_rows, num_cols)
  row = winner[0]
  col = winner[1]
  pred = map_table[row, col]
  predicted = label_map[row][col]
  pre_labels.append(pred)
  winner_labels.append(predicted)

# %%
labels_df = pd.read_table("/content/3rd_year_Categorical_ROI.txt", sep = ":", header = None)
labels_df.rename(columns = {0: "Name", 1: "Class"}, inplace = True)
labels_df["Class"] = labels_df["Class"].str.strip()
labels_df = labels_df.sort_values(by = 'Name')
labels_df.reset_index(drop = True, inplace = True)
labels_df
# Out:
#                     Name Class
# 0    1001_c12_cp2_63_48   NROI
# 1    1002_c11_cp2_41_44    COL
# 2    1002_c15_cp1_20_48    COH
# 3    1003_c11_cp2_38_48    COL
# 4    1004_c10_cp2_30_49    COL
# ..                   ...   ...
# 326   997_c12_cp2_62_59   NROI
# 327   998_c12_cp2_37_48    COL
# 328  999_c11_cp2_102_34    COL
# 329   999_c11_cp3_37_44    COL
# 330   999_c14_cp1_53_37    COH
#
# [331 rows x 2 columns]

# %%
class_mapping = {'NROI': 3, 'COL': 2, 'COH': 1, 'CL': 0}
labels_df["Class"] = labels_df["Class"].replace(class_mapping)
labels_df
# Out:
#                     Name  Class
# 0    1001_c12_cp2_63_48       3
# 1    1002_c11_cp2_41_44       2
# 2    1002_c15_cp1_20_48       1
# 3    1003_c11_cp2_38_48       2
# 4    1004_c10_cp2_30_49       2
# ..                   ...    ...
# 326   997_c12_cp2_62_59       3
# 327   998_c12_cp2_37_48       2
# 328  999_c11_cp2_102_34       2
# 329   999_c11_cp3_37_44       2
# 330   999_c14_cp1_53_37       1
#
# [331 rows x 2 columns]

# %%
labels_df["Class"] = labels_df["Class"].astype(int)

# %%
SOM_acc = accuracy_score(np.array(labels_df["Class"]), np.array(winner_labels))
print("Accuracy: ", SOM_acc)
# Out:
# Accuracy:  0.6253776435045317

# %%
SOM_test_df = test_data.copy()
SOM_test_df["Class"] = winner_labels
SOM_test_df["Percentage"] = pre_labels
SOM_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.864588  0.866602  0.869459  0.871832  0.876163  0.879234  0.880788
# 1    0.894788  0.890944  0.886508  0.881579  0.878610  0.873343  0.867980
# 2    0.870434  0.883155  0.895762  0.906920  0.919726  0.929799  0.939409
# 3    0.934730  0.930867  0.926936  0.922027  0.920215  0.916053  0.912315
# 4    0.909888  0.910906  0.911349  0.909357  0.909447  0.907707  0.906404
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.930833  0.935248  0.939601  0.937135  0.942242  0.940599  0.940394
# 327  0.869459  0.873418  0.876279  0.877193  0.879589  0.879725  0.879310
# 328  0.759864  0.772639  0.783731  0.791910  0.800783  0.806087  0.810837
# 329  0.812957  0.820837  0.826595  0.829435  0.835047  0.838979  0.843350
# 330  0.866537  0.870010  0.872869  0.875244  0.879099  0.882671  0.881773
#
#             7         8         9  ...  225  226  227  228  Season  \
# 0    0.876719  0.873343  0.870635  ...    1    0    1    1       4
# 1    0.857073  0.847324  0.840630  ...    1    0    1    0       4
# 2    0.941552  0.944035  0.946877  ...    1    0    0    1       4
# 3    0.903242  0.896416  0.892277  ...    1    0    1    1       4
# 4    0.899804  0.895434  0.894245  ...    1    0    0    1       4
# ..        ...       ...       ...  ...  ...  ...  ...  ...     ...
# 326  0.935167  0.934217  0.936547  ...    1    0    1    1       3
# 327  0.874263  0.870889  0.869159  ...    1    0    1    1       3
# 328  0.810413  0.810015  0.810133  ...    1    1    1    0       3
# 329  0.843320  0.844379  0.848008  ...    1    0    1    0       3
# 330  0.877210  0.869907  0.864240  ...    1    0    1    0       3
#
#                    Name   Day         ROI  Class  \
# 0    1001_c12_cp2_63_48  1001  1001_63_48      2
# 1    1002_c11_cp2_41_44  1002  1002_41_44      1
# 2    1002_c15_cp1_20_48  1002  1002_20_48      1
# 3    1003_c11_cp2_38_48  1003  1003_38_48      2
# 4    1004_c10_cp2_30_49  1004  1004_30_49      2
# ..                  ...   ...         ...    ...
# 326   997_c12_cp2_62_59   997   997_62_59      3
# 327   998_c12_cp2_37_48   998   998_37_48      2
# 328  999_c11_cp2_102_34   999  999_102_34      3
# 329   999_c11_cp3_37_44   999   999_37_44      0
# 330   999_c14_cp1_53_37   999   999_53_37      1
#
#                             Percentage
# 0                           [[2, 1.0]]
# 1                 [[1, 0.5], [2, 0.5]]
# 2    [[1, 0.71], [2, 0.14], [3, 0.14]]
# 3                           [[2, 1.0]]
# 4                           [[2, 1.0]]
# ..                                 ...
# 326     [[1, 0.1], [2, 0.2], [3, 0.7]]
# 327             [[1, 0.33], [2, 0.67]]
# 328                         [[3, 1.0]]
# 329               [[0, 0.5], [1, 0.5]]
# 330               [[1, 0.5], [2, 0.5]]
#
# [331 rows x 235 columns]

# %%
# Assuming your DataFrame is named "SOM_test_df"
SOM_test_df['Percentage'] = SOM_test_df['Percentage'].apply(lambda x: [] if x == [None] else x)

# Print the updated DataFrame
SOM_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.864588  0.866602  0.869459  0.871832  0.876163  0.879234  0.880788
# 1    0.894788  0.890944  0.886508  0.881579  0.878610  0.873343  0.867980
# 2    0.870434  0.883155  0.895762  0.906920  0.919726  0.929799  0.939409
# 3    0.934730  0.930867  0.926936  0.922027  0.920215  0.916053  0.912315
# 4    0.909888  0.910906  0.911349  0.909357  0.909447  0.907707  0.906404
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.930833  0.935248  0.939601  0.937135  0.942242  0.940599  0.940394
# 327  0.869459  0.873418  0.876279  0.877193  0.879589  0.879725  0.879310
# 328  0.759864  0.772639  0.783731  0.791910  0.800783  0.806087  0.810837
# 329  0.812957  0.820837  0.826595  0.829435  0.835047  0.838979  0.843350
# 330  0.866537  0.870010  0.872869  0.875244  0.879099  0.882671  0.881773
#
#             7         8         9  ...  225  226  227  228  Season  \
# 0    0.876719  0.873343  0.870635  ...    1    0    1    1       4
# 1    0.857073  0.847324  0.840630  ...    1    0    1    0       4
# 2    0.941552  0.944035  0.946877  ...    1    0    0    1       4
# 3    0.903242  0.896416  0.892277  ...    1    0    1    1       4
# 4    0.899804  0.895434  0.894245  ...    1    0    0    1       4
# ..        ...       ...       ...  ...  ...  ...  ...  ...     ...
# 326  0.935167  0.934217  0.936547  ...    1    0    1    1       3
# 327  0.874263  0.870889  0.869159  ...    1    0    1    1       3
# 328  0.810413  0.810015  0.810133  ...    1    1    1    0       3
# 329  0.843320  0.844379  0.848008  ...    1    0    1    0       3
# 330  0.877210  0.869907  0.864240  ...    1    0    1    0       3
#
#                    Name   Day         ROI  Class  \
# 0    1001_c12_cp2_63_48  1001  1001_63_48      2
# 1    1002_c11_cp2_41_44  1002  1002_41_44      1
# 2    1002_c15_cp1_20_48  1002  1002_20_48      1
# 3    1003_c11_cp2_38_48  1003  1003_38_48      2
# 4    1004_c10_cp2_30_49  1004  1004_30_49      2
# ..                  ...   ...         ...    ...
# 326   997_c12_cp2_62_59   997   997_62_59      3
# 327   998_c12_cp2_37_48   998   998_37_48      2
# 328  999_c11_cp2_102_34   999  999_102_34      3
# 329   999_c11_cp3_37_44   999   999_37_44      0
# 330   999_c14_cp1_53_37   999   999_53_37      1
#
#                             Percentage
# 0                           [[2, 1.0]]
# 1                 [[1, 0.5], [2, 0.5]]
# 2    [[1, 0.71], [2, 0.14], [3, 0.14]]
# 3                           [[2, 1.0]]
# 4                           [[2, 1.0]]
# ..                                 ...
# 326     [[1, 0.1], [2, 0.2], [3, 0.7]]
# 327             [[1, 0.33], [2, 0.67]]
# 328                         [[3, 1.0]]
# 329               [[0, 0.5], [1, 0.5]]
# 330               [[1, 0.5], [2, 0.5]]
#
# [331 rows x 235 columns]

# %%
def calculate_distance(x1, y1, x2, y2):
    delta_x = x2 - x1
    delta_y = y2 - y1
    distance = math.sqrt(delta_x**2 + delta_y**2)
    return distance

# %%
SOM_ROI = {}

data = SOM_test_df.to_numpy()
for item in data:
    part = item[230].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[233]
    percentage = item[234]
    if day in SOM_ROI:
        found_duplicate = False
        for ele in SOM_ROI[day]:
            if x == ele[0] and y == ele[1]:
                found_duplicate = True
                break
        if not found_duplicate:
            SOM_ROI[day].append([x, y, category, percentage])
    else:
        SOM_ROI[day] = [[x, y, category, percentage]]

# %%
One_SOM_ROI = {}
Many_SOM_ROI = {}

for key, value in SOM_ROI.items():
    if len(value) <= 1:
        One_SOM_ROI[key] = value
    else:
        Many_SOM_ROI[key] = value

# %%
Many_SOM = {}
for key, value in Many_SOM_ROI.items():
    Many_SOM[key] = [[value[0]]]
    max_len = 0
    for i in value:
        if i[3] is None:
            continue
        else:
            if max_len < len(i[3]):
                max_len = len(i[3])
    space = max_len * 9 + (max_len - 1) * 6 + 16
    i = 1
    while i < len(value):
        x1 = value[i][0]
        y1 = value[i][1]
        found_smaller = True
        for k in Many_SOM[key]:
            found_smaller = True
            for j in k:
                x2 = j[0]
                y2 = j[1]
                distance = calculate_distance(x1, y1, x2, y2)
                if distance < space:
                    found_smaller = False
                    break
            if found_smaller == True:
                k.append(value[i])
                break
        if found_smaller == False:
            Many_SOM[key].append([value[i]])
        i += 1

# %%
folder_name = "3rd_SOM_Categorical_Pressure_Adding_Location_Season_ROI_Image"
SOM_folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(SOM_folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
default_color = (0, 0, 0)
size = 1
text_color = (148, 91, 10)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in One_SOM_ROI:
        for point in One_SOM_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list.get(point[2], default_color)
            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
            cv2.drawContours(final_image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
            text = ""
            if point[3] is not None:
                text = ", ".join([f"{a}:{b}" for a, b in point[3]])
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.2
            line_thickness = 0
            position = ()
            lines = text.split(",")
            max_len * 12 + (max_len - 1) * 6 + 16
            if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                position = (x + 3, y - 2)
            else:
                position = (x - 11, y + 8)
            for i, line in enumerate(lines):
                line = line.strip()
                position = (position[0], position[1] + 6 * i)
                cv2.putText(final_image, line, position, font, font_scale, text_color, line_thickness)
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", final_image)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    f_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    height, width, _ = f_image.shape
    base_image = np.zeros((height, width, 3), dtype = np.uint8)
    base_image = cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB)

    if number in Many_SOM:
        for part in Many_SOM[number]:
            image = f_image.copy()
            for point in part:
                x = point[0]
                y = point[1]
                color = color_list[point[2]]
                vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
                cv2.drawContours(image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
                text = ""
                if point[3] is not None:
                    text = ", ".join([f"{a}:{b}" for a, b in point[3]])
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.2
                line_thickness = 0
                position = ()
                lines = text.split(",")
                max_len * 12 + (max_len - 1) * 6 + 16
                if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                    position = (x + 3, y - 2)
                else:
                    position = (x - 11, y + 8)
                for i, line in enumerate(lines):
                    line = line.strip()
                    position = (position[0], position[1] + 6 * i)
                    cv2.putText(image, line, position, font, font_scale, text_color, line_thickness)
            base_image = np.concatenate((base_image, image), axis = 1)
        base_image = base_image[:, width:, :]
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", base_image)

# %% [markdown]
# # **CNN**

# %%
#Reshape training and testing data
train_X = X_train.to_numpy().reshape(X_train.shape[0],23,10,1).astype("float32")

train_Y = Y_train.to_numpy()

test_X = np.array(X_test).reshape(X_test.shape[0], 23, 10, 1)

train_Y = tf.keras.utils.to_categorical(train_Y)

# %%
#Define the model architecture
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 3, activation = "relu", input_shape = (23, 10, 1)))
model.add(Conv2D(filters = 32, kernel_size = 3, activation = "relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters = 64, kernel_size = 3, activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2), padding = "SAME"))
model.add(Flatten())
model.add(Dense(64, activation = "relu"))
model.add(Dense(32, activation = "relu"))
model.add(Dense(4, activation = "softmax"))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='loss', patience=30)
tensorboard_callback = TensorBoard(log_dir="./logs")

# Fit the model
model.fit(train_X, train_Y, epochs=1000, batch_size=16, callbacks=[tensorboard_callback, early_stopping])
# Out:
# Epoch 1/1000
# 47/47 [==============================] - 2s 8ms/step - loss: 1.2416 - accuracy: 0.4695
# Epoch 2/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 1.0182 - accuracy: 0.5522
# Epoch 3/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.8736 - accuracy: 0.5875
# Epoch 4/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.9239 - accuracy: 0.5292
# Epoch 5/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.8221 - accuracy: 0.6350
# Epoch 6/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.7806 - accuracy: 0.6255
# Epoch 7/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.8068 - accuracy: 0.6214
# Epoch 8/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.6843 - accuracy: 0.7042
# Epoch 9/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.6995 - accuracy: 0.6852
# Epoch 10/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.5379 - accuracy: 0.8005
# Epoch 11/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.4719 - accuracy: 0.8033
# Epoch 12/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.4443 - accuracy: 0.8141
# Epoch 13/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.4109 - accuracy: 0.8318
# Epoch 14/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3957 - accuracy: 0.8453
# Epoch 15/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.4107 - accuracy: 0.8453
# Epoch 16/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3930 - accuracy: 0.8358
# Epoch 17/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3983 - accuracy: 0.8358
# Epoch 18/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3998 - accuracy: 0.8372
# Epoch 19/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3550 - accuracy: 0.8670
# Epoch 20/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3915 - accuracy: 0.8345
# Epoch 21/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3896 - accuracy: 0.8494
# Epoch 22/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3793 - accuracy: 0.8304
# Epoch 23/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3460 - accuracy: 0.8670
# Epoch 24/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3558 - accuracy: 0.8453
# Epoch 25/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3571 - accuracy: 0.8575
# Epoch 26/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3540 - accuracy: 0.8602
# Epoch 27/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3381 - accuracy: 0.8602
# Epoch 28/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3621 - accuracy: 0.8602
# Epoch 29/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.4572 - accuracy: 0.8033
# Epoch 30/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3513 - accuracy: 0.8670
# Epoch 31/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3838 - accuracy: 0.8372
# Epoch 32/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3528 - accuracy: 0.8711
# Epoch 33/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3710 - accuracy: 0.8426
# Epoch 34/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3360 - accuracy: 0.8575
# Epoch 35/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3356 - accuracy: 0.8616
# Epoch 36/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3249 - accuracy: 0.8630
# Epoch 37/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3258 - accuracy: 0.8589
# Epoch 38/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3429 - accuracy: 0.8657
# Epoch 39/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3538 - accuracy: 0.8575
# Epoch 40/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3395 - accuracy: 0.8575
# Epoch 41/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3345 - accuracy: 0.8589
# Epoch 42/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3262 - accuracy: 0.8630
# Epoch 43/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3460 - accuracy: 0.8535
# Epoch 44/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3157 - accuracy: 0.8752
# Epoch 45/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3156 - accuracy: 0.8697
# Epoch 46/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3117 - accuracy: 0.8779
# Epoch 47/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2993 - accuracy: 0.8887
# Epoch 48/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2984 - accuracy: 0.8901
# Epoch 49/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2937 - accuracy: 0.8901
# Epoch 50/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2996 - accuracy: 0.8887
# Epoch 51/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2980 - accuracy: 0.8806
# Epoch 52/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2840 - accuracy: 0.9009
# Epoch 53/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3164 - accuracy: 0.8657
# Epoch 54/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2950 - accuracy: 0.8847
# Epoch 55/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2924 - accuracy: 0.8833
# Epoch 56/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2886 - accuracy: 0.8942
# Epoch 57/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2785 - accuracy: 0.8955
# Epoch 58/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 0.2924 - accuracy: 0.8697
# Epoch 59/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2797 - accuracy: 0.8928
# Epoch 60/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2728 - accuracy: 0.8915
# Epoch 61/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3210 - accuracy: 0.8792
# Epoch 62/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2848 - accuracy: 0.8887
# Epoch 63/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2878 - accuracy: 0.8874
# Epoch 64/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.3373 - accuracy: 0.8589
# Epoch 65/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2916 - accuracy: 0.8955
# Epoch 66/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2874 - accuracy: 0.8860
# Epoch 67/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3031 - accuracy: 0.8792
# Epoch 68/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2968 - accuracy: 0.8874
# Epoch 69/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2802 - accuracy: 0.8915
# Epoch 70/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2911 - accuracy: 0.8874
# Epoch 71/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2616 - accuracy: 0.9009
# Epoch 72/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2737 - accuracy: 0.8982
# Epoch 73/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2727 - accuracy: 0.8887
# Epoch 74/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2751 - accuracy: 0.8955
# Epoch 75/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2759 - accuracy: 0.8955
# Epoch 76/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2671 - accuracy: 0.8996
# Epoch 77/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2631 - accuracy: 0.8942
# Epoch 78/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2711 - accuracy: 0.8982
# Epoch 79/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3046 - accuracy: 0.8779
# Epoch 80/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2680 - accuracy: 0.9009
# Epoch 81/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2895 - accuracy: 0.8779
# Epoch 82/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2705 - accuracy: 0.9009
# Epoch 83/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2598 - accuracy: 0.8996
# Epoch 84/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2551 - accuracy: 0.9050
# Epoch 85/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2999 - accuracy: 0.8874
# Epoch 86/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2729 - accuracy: 0.8874
# Epoch 87/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2711 - accuracy: 0.8982
# Epoch 88/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2816 - accuracy: 0.8915
# Epoch 89/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2964 - accuracy: 0.8792
# Epoch 90/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2703 - accuracy: 0.8955
# Epoch 91/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2713 - accuracy: 0.8928
# Epoch 92/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2689 - accuracy: 0.9009
# Epoch 93/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2585 - accuracy: 0.9050
# Epoch 94/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2606 - accuracy: 0.8996
# Epoch 95/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2724 - accuracy: 0.8969
# Epoch 96/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2542 - accuracy: 0.9009
# Epoch 97/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2535 - accuracy: 0.9050
# Epoch 98/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.3254 - accuracy: 0.8806
# Epoch 99/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2614 - accuracy: 0.9077
# Epoch 100/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2658 - accuracy: 0.8928
# Epoch 101/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2449 - accuracy: 0.9037
# Epoch 102/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2500 - accuracy: 0.9037
# Epoch 103/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 0.3630 - accuracy: 0.8643
# Epoch 104/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2963 - accuracy: 0.8806
# Epoch 105/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2530 - accuracy: 0.8969
# Epoch 106/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2671 - accuracy: 0.9037
# Epoch 107/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2699 - accuracy: 0.8874
# Epoch 108/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2458 - accuracy: 0.9077
# Epoch 109/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2490 - accuracy: 0.9050
# Epoch 110/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2635 - accuracy: 0.8915
# Epoch 111/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3320 - accuracy: 0.8697
# Epoch 112/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2488 - accuracy: 0.9050
# Epoch 113/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2475 - accuracy: 0.8955
# Epoch 114/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2407 - accuracy: 0.9104
# Epoch 115/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.9023
# Epoch 116/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2546 - accuracy: 0.8915
# Epoch 117/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2487 - accuracy: 0.9009
# Epoch 118/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2377 - accuracy: 0.9118
# Epoch 119/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2351 - accuracy: 0.9064
# Epoch 120/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2338 - accuracy: 0.9077
# Epoch 121/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2430 - accuracy: 0.9091
# Epoch 122/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2604 - accuracy: 0.9023
# Epoch 123/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2449 - accuracy: 0.9064
# Epoch 124/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2400 - accuracy: 0.9037
# Epoch 125/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2306 - accuracy: 0.9159
# Epoch 126/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2231 - accuracy: 0.9104
# Epoch 127/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2314 - accuracy: 0.9118
# Epoch 128/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2228 - accuracy: 0.9159
# Epoch 129/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2330 - accuracy: 0.9172
# Epoch 130/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2293 - accuracy: 0.9091
# Epoch 131/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2323 - accuracy: 0.9118
# Epoch 132/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2437 - accuracy: 0.8996
# Epoch 133/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2297 - accuracy: 0.9077
# Epoch 134/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.4237 - accuracy: 0.8304
# Epoch 135/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2782 - accuracy: 0.8942
# Epoch 136/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2772 - accuracy: 0.8860
# Epoch 137/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2482 - accuracy: 0.9118
# Epoch 138/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2533 - accuracy: 0.9037
# Epoch 139/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2424 - accuracy: 0.9132
# Epoch 140/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2233 - accuracy: 0.9159
# Epoch 141/1000
# 47/47 [==============================] - 0s 11ms/step - loss: 0.2427 - accuracy: 0.9009
# Epoch 142/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2360 - accuracy: 0.9104
# Epoch 143/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3064 - accuracy: 0.8792
# Epoch 144/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2602 - accuracy: 0.9009
# Epoch 145/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2514 - accuracy: 0.9064
# Epoch 146/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2569 - accuracy: 0.8996
# Epoch 147/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2566 - accuracy: 0.8955
# Epoch 148/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2535 - accuracy: 0.8996
# Epoch 149/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2345 - accuracy: 0.9199
# Epoch 150/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2362 - accuracy: 0.9091
# Epoch 151/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2297 - accuracy: 0.9159
# Epoch 152/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2217 - accuracy: 0.9132
# Epoch 153/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2328 - accuracy: 0.9104
# Epoch 154/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2235 - accuracy: 0.9118
# Epoch 155/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2261 - accuracy: 0.9186
# Epoch 156/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2252 - accuracy: 0.9145
# Epoch 157/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2088 - accuracy: 0.9267
# Epoch 158/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2162 - accuracy: 0.9199
# Epoch 159/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2247 - accuracy: 0.9145
# Epoch 160/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2364 - accuracy: 0.9145
# Epoch 161/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2294 - accuracy: 0.9172
# Epoch 162/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2435 - accuracy: 0.9091
# Epoch 163/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2206 - accuracy: 0.9199
# Epoch 164/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 0.2070 - accuracy: 0.9172
# Epoch 165/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 0.2160 - accuracy: 0.9213
# Epoch 166/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 0.2084 - accuracy: 0.9213
# Epoch 167/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2156 - accuracy: 0.9186
# Epoch 168/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2380 - accuracy: 0.8969
# Epoch 169/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2079 - accuracy: 0.9213
# Epoch 170/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2115 - accuracy: 0.9132
# Epoch 171/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2094 - accuracy: 0.9132
# Epoch 172/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2158 - accuracy: 0.9213
# Epoch 173/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2011 - accuracy: 0.9186
# Epoch 174/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2132 - accuracy: 0.9267
# Epoch 175/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1992 - accuracy: 0.9308
# Epoch 176/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1925 - accuracy: 0.9267
# Epoch 177/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1979 - accuracy: 0.9227
# Epoch 178/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2058 - accuracy: 0.9199
# Epoch 179/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2028 - accuracy: 0.9199
# Epoch 180/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1929 - accuracy: 0.9159
# Epoch 181/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1959 - accuracy: 0.9199
# Epoch 182/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2023 - accuracy: 0.9227
# Epoch 183/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1935 - accuracy: 0.9227
# Epoch 184/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2324 - accuracy: 0.9064
# Epoch 185/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1921 - accuracy: 0.9267
# Epoch 186/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2128 - accuracy: 0.9159
# Epoch 187/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1900 - accuracy: 0.9267
# Epoch 188/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3849 - accuracy: 0.8575
# Epoch 189/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.3365 - accuracy: 0.8711
# Epoch 190/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2460 - accuracy: 0.9118
# Epoch 191/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2510 - accuracy: 0.8982
# Epoch 192/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2183 - accuracy: 0.9091
# Epoch 193/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2204 - accuracy: 0.9091
# Epoch 194/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2083 - accuracy: 0.9186
# Epoch 195/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2123 - accuracy: 0.9186
# Epoch 196/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2045 - accuracy: 0.9281
# Epoch 197/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1959 - accuracy: 0.9294
# Epoch 198/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2196 - accuracy: 0.9159
# Epoch 199/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2096 - accuracy: 0.9254
# Epoch 200/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2083 - accuracy: 0.9199
# Epoch 201/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2136 - accuracy: 0.9186
# Epoch 202/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2203 - accuracy: 0.9104
# Epoch 203/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2395 - accuracy: 0.9050
# Epoch 204/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2162 - accuracy: 0.9172
# Epoch 205/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2105 - accuracy: 0.9159
# Epoch 206/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2031 - accuracy: 0.9172
# Epoch 207/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1878 - accuracy: 0.9254
# Epoch 208/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1968 - accuracy: 0.9186
# Epoch 209/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2053 - accuracy: 0.9254
# Epoch 210/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1911 - accuracy: 0.9227
# Epoch 211/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1983 - accuracy: 0.9281
# Epoch 212/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1905 - accuracy: 0.9294
# Epoch 213/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1824 - accuracy: 0.9267
# Epoch 214/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1862 - accuracy: 0.9267
# Epoch 215/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1865 - accuracy: 0.9294
# Epoch 216/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1961 - accuracy: 0.9186
# Epoch 217/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1917 - accuracy: 0.9227
# Epoch 218/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1753 - accuracy: 0.9322
# Epoch 219/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1922 - accuracy: 0.9281
# Epoch 220/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1834 - accuracy: 0.9254
# Epoch 221/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2476 - accuracy: 0.9023
# Epoch 222/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2662 - accuracy: 0.8969
# Epoch 223/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2057 - accuracy: 0.9267
# Epoch 224/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1916 - accuracy: 0.9240
# Epoch 225/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1871 - accuracy: 0.9240
# Epoch 226/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1998 - accuracy: 0.9186
# Epoch 227/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1796 - accuracy: 0.9308
# Epoch 228/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1855 - accuracy: 0.9376
# Epoch 229/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1912 - accuracy: 0.9294
# Epoch 230/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1840 - accuracy: 0.9254
# Epoch 231/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1781 - accuracy: 0.9308
# Epoch 232/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1809 - accuracy: 0.9308
# Epoch 233/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1926 - accuracy: 0.9281
# Epoch 234/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1769 - accuracy: 0.9294
# Epoch 235/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.2293 - accuracy: 0.9037
# Epoch 236/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1872 - accuracy: 0.9267
# Epoch 237/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1707 - accuracy: 0.9322
# Epoch 238/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1741 - accuracy: 0.9362
# Epoch 239/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1755 - accuracy: 0.9308
# Epoch 240/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.3193 - accuracy: 0.8792
# Epoch 241/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2021 - accuracy: 0.9186
# Epoch 242/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2029 - accuracy: 0.9172
# Epoch 243/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2073 - accuracy: 0.9132
# Epoch 244/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1923 - accuracy: 0.9186
# Epoch 245/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.2300 - accuracy: 0.9118
# Epoch 246/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2091 - accuracy: 0.9199
# Epoch 247/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1840 - accuracy: 0.9281
# Epoch 248/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1785 - accuracy: 0.9308
# Epoch 249/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1658 - accuracy: 0.9417
# Epoch 250/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1610 - accuracy: 0.9376
# Epoch 251/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1709 - accuracy: 0.9349
# Epoch 252/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1598 - accuracy: 0.9376
# Epoch 253/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1604 - accuracy: 0.9403
# Epoch 254/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1576 - accuracy: 0.9430
# Epoch 255/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1683 - accuracy: 0.9349
# Epoch 256/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1622 - accuracy: 0.9376
# Epoch 257/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1424 - accuracy: 0.9430
# Epoch 258/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1560 - accuracy: 0.9430
# Epoch 259/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1532 - accuracy: 0.9444
# Epoch 260/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1606 - accuracy: 0.9430
# Epoch 261/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1450 - accuracy: 0.9444
# Epoch 262/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1452 - accuracy: 0.9471
# Epoch 263/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1442 - accuracy: 0.9444
# Epoch 264/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1709 - accuracy: 0.9335
# Epoch 265/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1472 - accuracy: 0.9457
# Epoch 266/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2717 - accuracy: 0.8915
# Epoch 267/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2275 - accuracy: 0.8982
# Epoch 268/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2060 - accuracy: 0.9145
# Epoch 269/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1859 - accuracy: 0.9267
# Epoch 270/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1780 - accuracy: 0.9322
# Epoch 271/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1639 - accuracy: 0.9389
# Epoch 272/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1662 - accuracy: 0.9322
# Epoch 273/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1632 - accuracy: 0.9389
# Epoch 274/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1611 - accuracy: 0.9362
# Epoch 275/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1622 - accuracy: 0.9471
# Epoch 276/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1639 - accuracy: 0.9322
# Epoch 277/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1618 - accuracy: 0.9322
# Epoch 278/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1582 - accuracy: 0.9417
# Epoch 279/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1541 - accuracy: 0.9444
# Epoch 280/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1772 - accuracy: 0.9308
# Epoch 281/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1528 - accuracy: 0.9403
# Epoch 282/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1623 - accuracy: 0.9335
# Epoch 283/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1855 - accuracy: 0.9349
# Epoch 284/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1417 - accuracy: 0.9444
# Epoch 285/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1354 - accuracy: 0.9498
# Epoch 286/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1367 - accuracy: 0.9498
# Epoch 287/1000
# 47/47 [==============================] - 0s 11ms/step - loss: 0.1405 - accuracy: 0.9430
# Epoch 288/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1341 - accuracy: 0.9525
# Epoch 289/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1304 - accuracy: 0.9457
# Epoch 290/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1332 - accuracy: 0.9525
# Epoch 291/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1507 - accuracy: 0.9471
# Epoch 292/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1390 - accuracy: 0.9471
# Epoch 293/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1599 - accuracy: 0.9308
# Epoch 294/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1749 - accuracy: 0.9213
# Epoch 295/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1638 - accuracy: 0.9403
# Epoch 296/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1410 - accuracy: 0.9471
# Epoch 297/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1344 - accuracy: 0.9512
# Epoch 298/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1332 - accuracy: 0.9498
# Epoch 299/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1226 - accuracy: 0.9579
# Epoch 300/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9512
# Epoch 301/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1201 - accuracy: 0.9484
# Epoch 302/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1286 - accuracy: 0.9512
# Epoch 303/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1255 - accuracy: 0.9579
# Epoch 304/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1371 - accuracy: 0.9484
# Epoch 305/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1254 - accuracy: 0.9471
# Epoch 306/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1241 - accuracy: 0.9566
# Epoch 307/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1278 - accuracy: 0.9417
# Epoch 308/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1236 - accuracy: 0.9471
# Epoch 309/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1290 - accuracy: 0.9430
# Epoch 310/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1235 - accuracy: 0.9498
# Epoch 311/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1049 - accuracy: 0.9661
# Epoch 312/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1085 - accuracy: 0.9566
# Epoch 313/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1354 - accuracy: 0.9552
# Epoch 314/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1328 - accuracy: 0.9512
# Epoch 315/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1928 - accuracy: 0.9254
# Epoch 316/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1353 - accuracy: 0.9484
# Epoch 317/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1116 - accuracy: 0.9620
# Epoch 318/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1162 - accuracy: 0.9579
# Epoch 319/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1093 - accuracy: 0.9661
# Epoch 320/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1103 - accuracy: 0.9620
# Epoch 321/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2256 - accuracy: 0.9091
# Epoch 322/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1309 - accuracy: 0.9552
# Epoch 323/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1386 - accuracy: 0.9607
# Epoch 324/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1169 - accuracy: 0.9593
# Epoch 325/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1063 - accuracy: 0.9620
# Epoch 326/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2094 - accuracy: 0.9199
# Epoch 327/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1407 - accuracy: 0.9403
# Epoch 328/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1225 - accuracy: 0.9512
# Epoch 329/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1156 - accuracy: 0.9661
# Epoch 330/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2382 - accuracy: 0.9037
# Epoch 331/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1822 - accuracy: 0.9159
# Epoch 332/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1297 - accuracy: 0.9579
# Epoch 333/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1135 - accuracy: 0.9620
# Epoch 334/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1187 - accuracy: 0.9512
# Epoch 335/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1208 - accuracy: 0.9512
# Epoch 336/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1125 - accuracy: 0.9607
# Epoch 337/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1685 - accuracy: 0.9349
# Epoch 338/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1109 - accuracy: 0.9620
# Epoch 339/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1085 - accuracy: 0.9593
# Epoch 340/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1025 - accuracy: 0.9647
# Epoch 341/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1180 - accuracy: 0.9593
# Epoch 342/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1116 - accuracy: 0.9607
# Epoch 343/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1072 - accuracy: 0.9579
# Epoch 344/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.0936 - accuracy: 0.9661
# Epoch 345/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0902 - accuracy: 0.9674
# Epoch 346/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1206 - accuracy: 0.9417
# Epoch 347/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0971 - accuracy: 0.9661
# Epoch 348/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0858 - accuracy: 0.9742
# Epoch 349/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1188 - accuracy: 0.9539
# Epoch 350/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1058 - accuracy: 0.9579
# Epoch 351/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1107 - accuracy: 0.9634
# Epoch 352/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0928 - accuracy: 0.9620
# Epoch 353/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1097 - accuracy: 0.9566
# Epoch 354/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0850 - accuracy: 0.9688
# Epoch 355/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0831 - accuracy: 0.9742
# Epoch 356/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1075 - accuracy: 0.9593
# Epoch 357/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0968 - accuracy: 0.9688
# Epoch 358/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0842 - accuracy: 0.9715
# Epoch 359/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0786 - accuracy: 0.9742
# Epoch 360/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1277 - accuracy: 0.9512
# Epoch 361/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0971 - accuracy: 0.9634
# Epoch 362/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1114 - accuracy: 0.9729
# Epoch 363/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1206 - accuracy: 0.9593
# Epoch 364/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0848 - accuracy: 0.9701
# Epoch 365/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0881 - accuracy: 0.9647
# Epoch 366/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1050 - accuracy: 0.9661
# Epoch 367/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0882 - accuracy: 0.9688
# Epoch 368/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0892 - accuracy: 0.9701
# Epoch 369/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1214 - accuracy: 0.9552
# Epoch 370/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0811 - accuracy: 0.9688
# Epoch 371/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0851 - accuracy: 0.9688
# Epoch 372/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0695 - accuracy: 0.9783
# Epoch 373/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0745 - accuracy: 0.9769
# Epoch 374/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0723 - accuracy: 0.9783
# Epoch 375/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0869 - accuracy: 0.9674
# Epoch 376/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0793 - accuracy: 0.9742
# Epoch 377/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0945 - accuracy: 0.9647
# Epoch 378/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0892 - accuracy: 0.9661
# Epoch 379/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1185 - accuracy: 0.9661
# Epoch 380/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1199 - accuracy: 0.9525
# Epoch 381/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1006 - accuracy: 0.9593
# Epoch 382/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0907 - accuracy: 0.9688
# Epoch 383/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0727 - accuracy: 0.9742
# Epoch 384/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0640 - accuracy: 0.9810
# Epoch 385/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0680 - accuracy: 0.9810
# Epoch 386/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1472 - accuracy: 0.9512
# Epoch 387/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0891 - accuracy: 0.9647
# Epoch 388/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0813 - accuracy: 0.9715
# Epoch 389/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0648 - accuracy: 0.9796
# Epoch 390/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0733 - accuracy: 0.9783
# Epoch 391/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1044 - accuracy: 0.9566
# Epoch 392/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0843 - accuracy: 0.9661
# Epoch 393/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0695 - accuracy: 0.9769
# Epoch 394/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0764 - accuracy: 0.9715
# Epoch 395/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0974 - accuracy: 0.9634
# Epoch 396/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0834 - accuracy: 0.9674
# Epoch 397/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0670 - accuracy: 0.9796
# Epoch 398/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0654 - accuracy: 0.9810
# Epoch 399/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0708 - accuracy: 0.9688
# Epoch 400/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0659 - accuracy: 0.9837
# Epoch 401/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0612 - accuracy: 0.9769
# Epoch 402/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0653 - accuracy: 0.9796
# Epoch 403/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0550 - accuracy: 0.9851
# Epoch 404/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0601 - accuracy: 0.9810
# Epoch 405/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0599 - accuracy: 0.9796
# Epoch 406/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0589 - accuracy: 0.9783
# Epoch 407/1000
# 47/47 [==============================] - 0s 7ms/step - loss: 0.0674 - accuracy: 0.9756
# Epoch 408/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0662 - accuracy: 0.9783
# Epoch 409/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0803 - accuracy: 0.9715
# Epoch 410/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0615 - accuracy: 0.9783
# Epoch 411/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0551 - accuracy: 0.9824
# Epoch 412/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0706 - accuracy: 0.9742
# Epoch 413/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0576 - accuracy: 0.9756
# Epoch 414/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0766 - accuracy: 0.9661
# Epoch 415/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.2829 - accuracy: 0.9403
# Epoch 416/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1577 - accuracy: 0.9362
# Epoch 417/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0872 - accuracy: 0.9715
# Epoch 418/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0650 - accuracy: 0.9837
# Epoch 419/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1360 - accuracy: 0.9457
# Epoch 420/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0960 - accuracy: 0.9674
# Epoch 421/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0829 - accuracy: 0.9715
# Epoch 422/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0563 - accuracy: 0.9878
# Epoch 423/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1518 - accuracy: 0.9484
# Epoch 424/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1020 - accuracy: 0.9620
# Epoch 425/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0675 - accuracy: 0.9810
# Epoch 426/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0551 - accuracy: 0.9851
# Epoch 427/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0538 - accuracy: 0.9851
# Epoch 428/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0647 - accuracy: 0.9769
# Epoch 429/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0779 - accuracy: 0.9742
# Epoch 430/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0523 - accuracy: 0.9837
# Epoch 431/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0492 - accuracy: 0.9837
# Epoch 432/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0446 - accuracy: 0.9851
# Epoch 433/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0475 - accuracy: 0.9810
# Epoch 434/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0490 - accuracy: 0.9824
# Epoch 435/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0530 - accuracy: 0.9783
# Epoch 436/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0482 - accuracy: 0.9810
# Epoch 437/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0661 - accuracy: 0.9742
# Epoch 438/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0782 - accuracy: 0.9742
# Epoch 439/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0493 - accuracy: 0.9837
# Epoch 440/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0463 - accuracy: 0.9864
# Epoch 441/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0620 - accuracy: 0.9769
# Epoch 442/1000
# 47/47 [==============================] - 0s 11ms/step - loss: 0.0555 - accuracy: 0.9824
# Epoch 443/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0629 - accuracy: 0.9742
# Epoch 444/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0508 - accuracy: 0.9837
# Epoch 445/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0440 - accuracy: 0.9864
# Epoch 446/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0395 - accuracy: 0.9891
# Epoch 447/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0424 - accuracy: 0.9864
# Epoch 448/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0514 - accuracy: 0.9796
# Epoch 449/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0544 - accuracy: 0.9796
# Epoch 450/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0436 - accuracy: 0.9824
# Epoch 451/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0907 - accuracy: 0.9674
# Epoch 452/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0727 - accuracy: 0.9661
# Epoch 453/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0748 - accuracy: 0.9661
# Epoch 454/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0934 - accuracy: 0.9701
# Epoch 455/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0503 - accuracy: 0.9824
# Epoch 456/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0432 - accuracy: 0.9851
# Epoch 457/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0355 - accuracy: 0.9891
# Epoch 458/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0326 - accuracy: 0.9905
# Epoch 459/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0518 - accuracy: 0.9810
# Epoch 460/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0439 - accuracy: 0.9851
# Epoch 461/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0428 - accuracy: 0.9837
# Epoch 462/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0317 - accuracy: 0.9878
# Epoch 463/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0321 - accuracy: 0.9891
# Epoch 464/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0348 - accuracy: 0.9851
# Epoch 465/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0796 - accuracy: 0.9742
# Epoch 466/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0696 - accuracy: 0.9783
# Epoch 467/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0522 - accuracy: 0.9796
# Epoch 468/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0530 - accuracy: 0.9824
# Epoch 469/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0324 - accuracy: 0.9905
# Epoch 470/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0303 - accuracy: 0.9919
# Epoch 471/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0333 - accuracy: 0.9891
# Epoch 472/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0260 - accuracy: 0.9932
# Epoch 473/1000
# 47/47 [==============================] - 1s 13ms/step - loss: 0.0279 - accuracy: 0.9905
# Epoch 474/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0307 - accuracy: 0.9891
# Epoch 475/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0807 - accuracy: 0.9701
# Epoch 476/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0623 - accuracy: 0.9783
# Epoch 477/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0542 - accuracy: 0.9824
# Epoch 478/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1052 - accuracy: 0.9552
# Epoch 479/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0936 - accuracy: 0.9634
# Epoch 480/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0905 - accuracy: 0.9701
# Epoch 481/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0476 - accuracy: 0.9824
# Epoch 482/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0360 - accuracy: 0.9891
# Epoch 483/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0300 - accuracy: 0.9905
# Epoch 484/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.9919
# Epoch 485/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0216 - accuracy: 0.9959
# Epoch 486/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0263 - accuracy: 0.9932
# Epoch 487/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0261 - accuracy: 0.9932
# Epoch 488/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.9973
# Epoch 489/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0230 - accuracy: 0.9919
# Epoch 490/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0189 - accuracy: 0.9946
# Epoch 491/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0189 - accuracy: 0.9959
# Epoch 492/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0186 - accuracy: 0.9959
# Epoch 493/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0257 - accuracy: 0.9919
# Epoch 494/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0258 - accuracy: 0.9946
# Epoch 495/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 0.9905
# Epoch 496/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0410 - accuracy: 0.9878
# Epoch 497/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.9919
# Epoch 498/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0247 - accuracy: 0.9891
# Epoch 499/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0615 - accuracy: 0.9729
# Epoch 500/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1655 - accuracy: 0.9389
# Epoch 501/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0967 - accuracy: 0.9647
# Epoch 502/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0685 - accuracy: 0.9742
# Epoch 503/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0444 - accuracy: 0.9769
# Epoch 504/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0365 - accuracy: 0.9864
# Epoch 505/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0530 - accuracy: 0.9783
# Epoch 506/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0504 - accuracy: 0.9742
# Epoch 507/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0493 - accuracy: 0.9837
# Epoch 508/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0287 - accuracy: 0.9919
# Epoch 509/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0805 - accuracy: 0.9756
# Epoch 510/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0451 - accuracy: 0.9878
# Epoch 511/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0274 - accuracy: 0.9946
# Epoch 512/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0176 - accuracy: 0.9946
# Epoch 513/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0172 - accuracy: 0.9959
# Epoch 514/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0154 - accuracy: 0.9973
# Epoch 515/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0131 - accuracy: 0.9959
# Epoch 516/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0133 - accuracy: 0.9973
# Epoch 517/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0121 - accuracy: 0.9973
# Epoch 518/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0129 - accuracy: 0.9959
# Epoch 519/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0136 - accuracy: 0.9959
# Epoch 520/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0241 - accuracy: 0.9919
# Epoch 521/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0363 - accuracy: 0.9891
# Epoch 522/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0326 - accuracy: 0.9864
# Epoch 523/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0604 - accuracy: 0.9756
# Epoch 524/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1424 - accuracy: 0.9457
# Epoch 525/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0647 - accuracy: 0.9796
# Epoch 526/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0316 - accuracy: 0.9891
# Epoch 527/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0347 - accuracy: 0.9878
# Epoch 528/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0178 - accuracy: 0.9946
# Epoch 529/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0157 - accuracy: 0.9932
# Epoch 530/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0173 - accuracy: 0.9946
# Epoch 531/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0155 - accuracy: 0.9946
# Epoch 532/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0232 - accuracy: 0.9905
# Epoch 533/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0797 - accuracy: 0.9701
# Epoch 534/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0666 - accuracy: 0.9742
# Epoch 535/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0328 - accuracy: 0.9905
# Epoch 536/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.9932
# Epoch 537/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0120 - accuracy: 0.9959
# Epoch 538/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 0.9973
# Epoch 539/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 0.9959
# Epoch 540/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 0.9973
# Epoch 541/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0870 - accuracy: 0.9783
# Epoch 542/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0537 - accuracy: 0.9742
# Epoch 543/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0408 - accuracy: 0.9824
# Epoch 544/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0397 - accuracy: 0.9851
# Epoch 545/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0333 - accuracy: 0.9891
# Epoch 546/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0155 - accuracy: 0.9946
# Epoch 547/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0125 - accuracy: 0.9973
# Epoch 548/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0102 - accuracy: 0.9959
# Epoch 549/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0106 - accuracy: 0.9986
# Epoch 550/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 551/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0089 - accuracy: 0.9973
# Epoch 552/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.0101 - accuracy: 0.9973
# Epoch 553/1000
# 47/47 [==============================] - 1s 12ms/step - loss: 0.0105 - accuracy: 0.9959
# Epoch 554/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1112 - accuracy: 0.9620
# Epoch 555/1000
# 47/47 [==============================] - 1s 11ms/step - loss: 0.4975 - accuracy: 0.8996
# Epoch 556/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2088 - accuracy: 0.9267
# Epoch 557/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1635 - accuracy: 0.9403
# Epoch 558/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1162 - accuracy: 0.9607
# Epoch 559/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0991 - accuracy: 0.9634
# Epoch 560/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0807 - accuracy: 0.9715
# Epoch 561/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0874 - accuracy: 0.9620
# Epoch 562/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0721 - accuracy: 0.9756
# Epoch 563/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0709 - accuracy: 0.9742
# Epoch 564/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0943 - accuracy: 0.9701
# Epoch 565/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0711 - accuracy: 0.9742
# Epoch 566/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0580 - accuracy: 0.9783
# Epoch 567/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0546 - accuracy: 0.9878
# Epoch 568/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0561 - accuracy: 0.9796
# Epoch 569/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0557 - accuracy: 0.9810
# Epoch 570/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0740 - accuracy: 0.9742
# Epoch 571/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0533 - accuracy: 0.9824
# Epoch 572/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0441 - accuracy: 0.9837
# Epoch 573/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0377 - accuracy: 0.9891
# Epoch 574/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0361 - accuracy: 0.9878
# Epoch 575/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0323 - accuracy: 0.9919
# Epoch 576/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0938 - accuracy: 0.9661
# Epoch 577/1000
# 47/47 [==============================] - 0s 8ms/step - loss: 0.0454 - accuracy: 0.9878
# Epoch 578/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0450 - accuracy: 0.9837
# Epoch 579/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0316 - accuracy: 0.9946
# Epoch 580/1000
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0248 - accuracy: 0.9959
# Epoch 581/1000
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0230 - accuracy: 0.9959

# %%
y_pred = model.predict(test_X).argmax(axis=1)
# Out:
# 11/11 [==============================] - 0s 3ms/step

# %%
CNN_acc = accuracy_score(np.array(labels_df["Class"]), y_pred)
print("Accuracy: ", CNN_acc)
# Out:
# Accuracy:  0.6586102719033232

# %%
testing_df = test_data.copy()
testing_df["Class"] = y_pred
testing_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.864588  0.866602  0.869459  0.871832  0.876163  0.879234  0.880788
# 1    0.894788  0.890944  0.886508  0.881579  0.878610  0.873343  0.867980
# 2    0.870434  0.883155  0.895762  0.906920  0.919726  0.929799  0.939409
# 3    0.934730  0.930867  0.926936  0.922027  0.920215  0.916053  0.912315
# 4    0.909888  0.910906  0.911349  0.909357  0.909447  0.907707  0.906404
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.930833  0.935248  0.939601  0.937135  0.942242  0.940599  0.940394
# 327  0.869459  0.873418  0.876279  0.877193  0.879589  0.879725  0.879310
# 328  0.759864  0.772639  0.783731  0.791910  0.800783  0.806087  0.810837
# 329  0.812957  0.820837  0.826595  0.829435  0.835047  0.838979  0.843350
# 330  0.866537  0.870010  0.872869  0.875244  0.879099  0.882671  0.881773
#
#             7         8         9  ...       224  225  226  227  228  Season  \
# 0    0.876719  0.873343  0.870635  ...  0.903958    1    0    1    1       4
# 1    0.857073  0.847324  0.840630  ...  0.880309    1    0    1    0       4
# 2    0.941552  0.944035  0.946877  ...  0.923263    1    0    0    1       4
# 3    0.903242  0.896416  0.892277  ...  0.920849    1    0    1    1       4
# 4    0.899804  0.895434  0.894245  ...  0.910232    1    0    0    1       4
# ..        ...       ...       ...  ...       ...  ...  ...  ...  ...     ...
# 326  0.935167  0.934217  0.936547  ...  0.953185    1    0    1    1       3
# 327  0.874263  0.870889  0.869159  ...  0.919884    1    0    1    1       3
# 328  0.810413  0.810015  0.810133  ...  0.813224    1    1    1    0       3
# 329  0.843320  0.844379  0.848008  ...  0.921332    1    0    1    0       3
# 330  0.877210  0.869907  0.864240  ...  0.893340    1    0    1    0       3
#
#                    Name   Day         ROI  Class
# 0    1001_c12_cp2_63_48  1001  1001_63_48      2
# 1    1002_c11_cp2_41_44  1002  1002_41_44      2
# 2    1002_c15_cp1_20_48  1002  1002_20_48      1
# 3    1003_c11_cp2_38_48  1003  1003_38_48      2
# 4    1004_c10_cp2_30_49  1004  1004_30_49      2
# ..                  ...   ...         ...    ...
# 326   997_c12_cp2_62_59   997   997_62_59      3
# 327   998_c12_cp2_37_48   998   998_37_48      2
# 328  999_c11_cp2_102_34   999  999_102_34      3
# 329   999_c11_cp3_37_44   999   999_37_44      2
# 330   999_c14_cp1_53_37   999   999_53_37      1
#
# [331 rows x 234 columns]

# %%
CNN_ROI = {}
data = testing_df.to_numpy()
for item in data:
    part = item[230].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[233]
    if day in CNN_ROI:
        CNN_ROI[day].append([x, y, category])
    else:
        CNN_ROI[day] = [[x, y, category]]

# %%
folder_name = "3rd_CNN_Categorical_Pressure_Adding_Location_Season_ROI_Image"
folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_img = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in CNN_ROI:
        for point in CNN_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list[point[2]]

            size = 2

            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])

            cv2.drawContours(final_img, [vertices.reshape((-1, 1, 2))], -1, color, thickness = cv2.FILLED)

        cv2.imwrite(folder_path + "/day" + str(number) + ".png", final_img)

# %%
#Accuracy
# SOM Accuracy
print("SOM accuracy: ", SOM_acc)

# SOM Accuracy
print("CNN accuracy: ", CNN_acc)
# Out:
# SOM accuracy:  0.6253776435045317
# CNN accuracy:  0.6586102719033232
