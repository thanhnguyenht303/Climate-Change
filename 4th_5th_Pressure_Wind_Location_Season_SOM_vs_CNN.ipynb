# %%
from google.colab import drive
drive.mount("/content/drive")
import shutil
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
import cv2
import math
import os
import numpy as np
import pandas as pd
from numpy.ma.core import ceil
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors
import matplotlib.colors as colors
from sklearn.decomposition import PCA
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, GlobalMaxPooling2D, Dense, Flatten, Dropout, MaxPooling2D, LSTM, Lambda, Conv1D, GlobalMaxPooling1D
from keras.callbacks import TensorBoard, EarlyStopping
from keras.utils import to_categorical

# %%
data_path = "/content/drive/MyDrive/Location_Season_Data/"

# %%
train_df = pd.read_csv(data_path + "Location_Season_Wind_Pressure_first_3_year_ROI.csv")
train_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.475692  0.459692  0.473846  0.454769  0.471385  0.449846  0.468923
# 1     0.464615  0.488000  0.463385  0.491692  0.462769  0.494769  0.460923
# 2     0.248615  0.569231  0.243692  0.564923  0.240000  0.560615  0.237538
# 3     0.552000  0.515077  0.544000  0.517538  0.536615  0.519385  0.529846
# 4     0.248615  0.552000  0.243692  0.544000  0.240000  0.536615  0.237538
# ...        ...       ...       ...       ...       ...       ...       ...
# 1063  0.930833  0.396694  0.935248  0.409836  0.939601  0.426230  0.937135
# 1064  0.869459  0.438017  0.873418  0.459016  0.876279  0.475410  0.877193
# 1065  0.759864  0.404959  0.772639  0.418033  0.783731  0.434426  0.791910
# 1066  0.812957  0.338843  0.820837  0.336066  0.826595  0.319672  0.829435
# 1067  0.866537  0.330579  0.870010  0.352459  0.872869  0.368852  0.875244
#
#              7         8         9  ...       448       449  450  451  452  \
# 0     0.444923  0.465846  0.440000  ...  0.448598  0.376324    1    1    1
# 1     0.498462  0.460308  0.502769  ...  0.480997  0.514019    1    0    1
# 2     0.556923  0.235692  0.553231  ...  0.267912  0.554517    1    0    0
# 3     0.521846  0.524923  0.523692  ...  0.499065  0.442368    1    1    1
# 4     0.529846  0.235692  0.524923  ...  0.267912  0.499065    1    0    0
# ...        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 1063  0.433333  0.942242  0.434426  ...  0.953185  0.365079    1    0    1
# 1064  0.483333  0.879589  0.483607  ...  0.919884  0.682540    1    0    1
# 1065  0.433333  0.800783  0.418033  ...  0.813224  0.142857    1    1    1
# 1066  0.300000  0.835047  0.278689  ...  0.921332  0.706349    1    0    1
# 1067  0.375000  0.879099  0.377049  ...  0.893340  0.492063    1    0    1
#
#       453  season                Name  Day  Class
# 0       0       2   116_c7_cp2_100_32  116      0
# 1       0       2    125_c3_cp2_49_32  125      0
# 2       0       2    120_c1_cp2_31_29  120      0
# 3       0       2    127_c3_cp3_96_38  127      0
# 4       0       2    120_c2_cp2_31_29  120      0
# ...   ...     ...                 ...  ...    ...
# 1063    1       3   997_c12_cp2_62_59  997      3
# 1064    1       3   998_c12_cp2_37_48  998      2
# 1065    0       3  999_c11_cp2_102_34  999      2
# 1066    0       3   999_c11_cp3_37_44  999      2
# 1067    0       3   999_c14_cp1_53_37  999      1
#
# [1068 rows x 458 columns]

# %%
all_df = pd.read_csv(data_path + "Location_Season_Pressure_Wind_Merging_ROI.csv")
all_df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.904043  0.314050  0.904576  0.327869  0.904043  0.344262  0.900097
# 1     0.854847  0.471074  0.857352  0.475410  0.859717  0.483607  0.859649
# 2     0.886995  0.305785  0.881207  0.311475  0.876766  0.327869  0.872807
# 3     0.861179  0.454545  0.864167  0.475410  0.866050  0.500000  0.867446
# 4     0.915246  0.247934  0.914800  0.270492  0.915246  0.295082  0.915205
# ...        ...       ...       ...       ...       ...       ...       ...
# 3647  0.672187  0.355372  0.668452  0.360656  0.665855  0.377049  0.662768
# 3648  0.950804  0.404959  0.950341  0.418033  0.953726  0.434426  0.954191
# 3649  0.918169  0.471074  0.925998  0.500000  0.932294  0.532787  0.938596
# 3650  0.621042  0.264463  0.622201  0.270492  0.623965  0.286885  0.625731
# 3651  0.905991  0.438017  0.906524  0.459016  0.906965  0.483607  0.905458
#
#              7         8         9  ...       447       448       449  450  \
# 0     0.341667  0.896721  0.344262  ...  0.281250  0.925676  0.285714    1
# 1     0.491667  0.861968  0.483607  ...  0.312500  0.874035  0.317460    1
# 2     0.333333  0.872736  0.336066  ...  0.304688  0.926641  0.301587    1
# 3     0.508333  0.871268  0.516393  ...  0.328125  0.889479  0.333333    1
# 4     0.316667  0.919236  0.327869  ...  0.296875  0.952220  0.293651    1
# ...        ...       ...       ...  ...       ...       ...       ...  ...
# 3647  0.375000  0.662261  0.377049  ...  0.562500  0.747587  0.555556    1
# 3648  0.441667  0.957416  0.442623  ...  0.273438  0.946911  0.261905    1
# 3649  0.550000  0.945179  0.549180  ...  0.437500  0.937741  0.428571    1
# 3650  0.291667  0.628977  0.295082  ...  0.546875  0.707529  0.523810    1
# 3651  0.500000  0.906510  0.516393  ...  0.414062  0.935811  0.420635    1
#
#       451  452  453  season                Name   Day
# 0       0    0    1       2   3449_c9_cp2_29_58  3449
# 1       1    1    1       2   3450_c8_cp2_98_50  3450
# 2       0    1    1       2   3450_c8_cp3_59_56  3450
# 3       1    1    1       2   3451_c8_cp2_99_50  3451
# 4       0    1    1       2   3452_c8_cp3_55_59  3452
# ...   ...  ...  ...     ...                 ...   ...
# 3647    0    0    0       3   1648_c3_cp2_15_28  1648
# 3648    0    1    1       3   1648_c9_cp3_65_62  1648
# 3649    0    1    1       3  1649_c11_cp1_61_51  1649
# 3650    0    0    0       3   1649_c3_cp2_16_25  1649
# 3651    0    0    1       3   1649_c8_cp2_34_50  1649
#
# [3652 rows x 457 columns]

# %%
test_df = all_df[(all_df["Day"] >= 1096) & (all_df["Day"] <= 1825)]
test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
test_df = test_df.drop_duplicates(subset = "ROI")
test_df = test_df.sort_values(by = "Name")
test_df.reset_index(drop = True, inplace = True)
test_df
# Out:
# <ipython-input-6-eeb1e0cc003e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["ROI"] = test_df["Name"].apply(lambda x: x.split("_")[0] + "_" + x.split("_")[3] + "_" + x.split("_")[4])
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.760331  0.333496  0.762295  0.334632  0.762295  0.336745
# 1    0.148076  0.322314  0.148004  0.344262  0.148563  0.368852  0.148635
# 2    0.550901  0.280992  0.551120  0.295082  0.550414  0.311475  0.549220
# 3    0.077935  0.305785  0.074489  0.319672  0.071603  0.344262  0.068713
# 4    0.087189  0.413223  0.083252  0.434426  0.078909  0.467213  0.074561
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.421488  0.176241  0.418033  0.175353  0.418033  0.173489
# 675  0.145153  0.603306  0.142648  0.598361  0.140283  0.590164  0.137914
# 676  0.143205  0.586777  0.144109  0.590164  0.145641  0.590164  0.146686
# 677  0.191914  0.454545  0.188413  0.450820  0.185095  0.459016  0.182261
# 678  0.154895  0.421488  0.149464  0.426230  0.145153  0.442623  0.141326
#
#             7         8         9  ...       448       449  450  451  452  \
# 0    0.750000  0.339697  0.721311  ...  0.433398  0.761905    1    0    1
# 1    0.391667  0.148801  0.409836  ...  0.075290  0.500000    0    1    1
# 2    0.325000  0.549682  0.344262  ...  0.653475  0.261905    1    0    1
# 3    0.358333  0.066079  0.368852  ...  0.118726  0.396825    0    0    1
# 4    0.483333  0.070485  0.491803  ...  0.076737  0.587302    0    1    1
# ..        ...       ...       ...  ...       ...       ...  ...  ...  ...
# 674  0.408333  0.172296  0.401639  ...  0.225869  0.595238    0    0    1
# 675  0.583333  0.134606  0.565574  ...  0.152510  0.753968    0    0    1
# 676  0.583333  0.148311  0.573770  ...  0.169884  0.912698    0    1    1
# 677  0.450000  0.180127  0.442623  ...  0.168919  0.920635    0    1    1
# 678  0.441667  0.138522  0.426230  ...  0.162162  0.873016    0    1    1
#
#      453  season                Name   Day          ROI
# 0      0       1   1099_c8_cp2_53_25  1099   1099_53_25
# 1      0       1  1106_c2_cp2_100_11  1106  1106_100_11
# 2      0       1  1111_c10_cp2_53_37  1111   1111_53_37
# 3      0       1   1121_c1_cp1_72_15  1121   1121_72_15
# 4      0       1   1123_c1_cp1_76_16  1123   1123_76_16
# ..   ...     ...                 ...   ...          ...
# 674    0       4   1815_c1_cp1_71_15  1815   1815_71_15
# 675    0       4   1816_c1_cp1_69_19  1816   1816_69_19
# 676    0       4   1817_c1_cp1_82_23  1817   1817_82_23
# 677    0       4   1818_c1_cp1_89_22  1818   1818_89_22
# 678    0       4   1819_c1_cp1_92_21  1819   1819_92_21
#
# [679 rows x 458 columns]

# %%
X_train = train_df.drop(columns = ["Name", "Day", "Class"])
Y_train = train_df["Class"]

X_test = test_df.drop(columns = ["Name", "Day", "ROI"])

# %% [markdown]
# # **SOM**

# %%
#Normalization
def minmax_scaler(data):
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(data)
    return scaled
#Euclidean distance
def e_distance(x, y):
    return distance.euclidean(x, y)

#Manhanttan distance
def m_distance(x, y):
    return distance.cityblock(x, y)

#Best Matching Unit search
def winning_neuron(data, t, som, num_rows, num_cols):
  winner = [0,0]
  shortest_distance = np.sqrt(data.shape[1]) # initialise with max distance
  input_data = data[t]
  for row in range(num_rows):
    for col in range(num_cols):
      distance = e_distance(som[row][col], data[t])
      if distance < shortest_distance:
        shortest_distance = distance
        winner = [row,col]
  return winner

#Learning rate and neighbourhood range calculation
def decay(step, max_steps,max_learning_rate,max_m_dsitance):
  coefficient = 1.0 - (np.float64(step)/max_steps)
  learning_rate = coefficient*max_learning_rate
  neighbourhood_range = ceil(coefficient * max_m_dsitance)
  return learning_rate, neighbourhood_range

# %%
num_rows = 33
num_cols = 33
max_m_dsitance = 7
max_learning_rate = 0.75
max_steps = 150000

# %%
#main function

train_x_norm = minmax_scaler(X_train) # normalisation
# initialising self-organising map
num_dims = train_x_norm.shape[1] # numnber of dimensions in the input data
#np.random.seed(40)
som = np.random.random_sample(size=(num_rows, num_cols, num_dims)) # map construction

# start training iterations
for step in range(max_steps):
  if (step+1) % 1000 == 0:
    print("Iteration: ", step+1) # print out the current iteration for every 1k
  learning_rate, neighbourhood_range = decay(step, max_steps,max_learning_rate,max_m_dsitance)

  t = np.random.randint(0,high=train_x_norm.shape[0]) # random index of traing data
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  for row in range(num_rows):
    for col in range(num_cols):
      if m_distance([row,col],winner) <= neighbourhood_range:
        som[row][col] += learning_rate*(train_x_norm[t]-som[row][col]) #update neighbour's weight

print("SOM training completed")
# Out:
# Iteration:  1000
# Iteration:  2000
# Iteration:  3000
# Iteration:  4000
# Iteration:  5000
# Iteration:  6000
# Iteration:  7000
# Iteration:  8000
# Iteration:  9000
# Iteration:  10000
# Iteration:  11000
# Iteration:  12000
# Iteration:  13000
# Iteration:  14000
# Iteration:  15000
# Iteration:  16000
# Iteration:  17000
# Iteration:  18000
# Iteration:  19000
# Iteration:  20000
# Iteration:  21000
# Iteration:  22000
# Iteration:  23000
# Iteration:  24000
# Iteration:  25000
# Iteration:  26000
# Iteration:  27000
# Iteration:  28000
# Iteration:  29000
# Iteration:  30000
# Iteration:  31000
# Iteration:  32000
# Iteration:  33000
# Iteration:  34000
# Iteration:  35000
# Iteration:  36000
# Iteration:  37000
# Iteration:  38000
# Iteration:  39000
# Iteration:  40000
# Iteration:  41000
# Iteration:  42000
# Iteration:  43000
# Iteration:  44000
# Iteration:  45000
# Iteration:  46000
# Iteration:  47000
# Iteration:  48000
# Iteration:  49000
# Iteration:  50000
# Iteration:  51000
# Iteration:  52000
# Iteration:  53000
# Iteration:  54000
# Iteration:  55000
# Iteration:  56000
# Iteration:  57000
# Iteration:  58000
# Iteration:  59000
# Iteration:  60000
# Iteration:  61000
# Iteration:  62000
# Iteration:  63000
# Iteration:  64000
# Iteration:  65000
# Iteration:  66000
# Iteration:  67000
# Iteration:  68000
# Iteration:  69000
# Iteration:  70000
# Iteration:  71000
# Iteration:  72000
# Iteration:  73000
# Iteration:  74000
# Iteration:  75000
# Iteration:  76000
# Iteration:  77000
# Iteration:  78000
# Iteration:  79000
# Iteration:  80000
# Iteration:  81000
# Iteration:  82000
# Iteration:  83000
# Iteration:  84000
# Iteration:  85000
# Iteration:  86000
# Iteration:  87000
# Iteration:  88000
# Iteration:  89000
# Iteration:  90000
# Iteration:  91000
# Iteration:  92000
# Iteration:  93000
# Iteration:  94000
# Iteration:  95000
# Iteration:  96000
# Iteration:  97000
# Iteration:  98000
# Iteration:  99000
# Iteration:  100000
# Iteration:  101000
# Iteration:  102000
# Iteration:  103000
# Iteration:  104000
# Iteration:  105000
# Iteration:  106000
# Iteration:  107000
# Iteration:  108000
# Iteration:  109000
# Iteration:  110000
# Iteration:  111000
# Iteration:  112000
# Iteration:  113000
# Iteration:  114000
# Iteration:  115000
# Iteration:  116000
# Iteration:  117000
# Iteration:  118000
# Iteration:  119000
# Iteration:  120000
# Iteration:  121000
# Iteration:  122000
# Iteration:  123000
# Iteration:  124000
# Iteration:  125000
# Iteration:  126000
# Iteration:  127000
# Iteration:  128000
# Iteration:  129000
# Iteration:  130000
# Iteration:  131000
# Iteration:  132000
# Iteration:  133000
# Iteration:  134000
# Iteration:  135000
# Iteration:  136000
# Iteration:  137000
# Iteration:  138000
# Iteration:  139000
# Iteration:  140000
# Iteration:  141000
# Iteration:  142000
# Iteration:  143000
# Iteration:  144000
# Iteration:  145000
# Iteration:  146000
# Iteration:  147000
# Iteration:  148000
# Iteration:  149000
# Iteration:  150000
# SOM training completed

# %%
label_data = np.array(Y_train)
map = np.empty(shape=(num_rows, num_cols), dtype=object)

for row in range(num_rows):
  for col in range(num_cols):
    map[row][col] = [] # empty list to store the label

for t in range(train_x_norm.shape[0]):
  if (t+1) % 1000 == 0:
    print("sample data: ", t+1)
  winner = winning_neuron(train_x_norm, t, som, num_rows, num_cols)
  map[winner[0]][winner[1]].append(label_data[t]) # label of winning neuron
# Out:
# sample data:  1000

# %%
map_table = {}
for i in range(len(map)):
    for j in range(len(map[0])):
        if len(map[i][j]) == 0:
            map_table[i, j] = [None]
        else:
            hash_table = {}
            for k in map[i][j]:
                if k in hash_table:
                    hash_table[k] += 1
                else:
                    hash_table[k] = 1
            for key, value in hash_table.items():
                percentage = [key, round((value / len(map[i][j])), 2)]
                if (i, j) not in map_table:
                    map_table[i, j] = []
                map_table[i, j].append(percentage)

# %%
# construct label map
label_map = np.zeros(shape=(num_rows, num_cols),dtype=np.int64)
for row in range(num_rows):
  for col in range(num_cols):
    label_list = map[row][col]
    if len(label_list)==0:
      label = 3
    else:
      label = max(label_list, key=label_list.count)
    label_map[row][col] = label

title = ('Iteration ' + str(max_steps))
cmap = colors.ListedColormap(['tab:green', 'tab:red', 'tab:orange', 'tab:blue'])
plt.imshow(label_map, cmap=cmap)
plt.colorbar()
plt.title(title)
plt.show()

# %%
# test data

# using the trained som, search the winning node of corresponding to the test data
# get the label of the winning node

data_frame = minmax_scaler(X_test) # normalisation

winner_labels = []
pre_labels = []

for t in range(data_frame.shape[0]):
  winner = winning_neuron(data_frame, t, som, num_rows, num_cols)
  row = winner[0]
  col = winner[1]
  pred = map_table[row, col]
  predicted = label_map[row][col]
  pre_labels.append(pred)
  winner_labels.append(predicted)

# %%
SOM_test_df = test_df.copy()
SOM_test_df["Class"] = winner_labels
SOM_test_df["Percentage"] = pre_labels

# Assuming your DataFrame is named "SOM_test_df"
SOM_test_df['Percentage'] = SOM_test_df['Percentage'].apply(lambda x: [] if x == [None] else x)

# Print the updated DataFrame
SOM_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.760331  0.333496  0.762295  0.334632  0.762295  0.336745
# 1    0.148076  0.322314  0.148004  0.344262  0.148563  0.368852  0.148635
# 2    0.550901  0.280992  0.551120  0.295082  0.550414  0.311475  0.549220
# 3    0.077935  0.305785  0.074489  0.319672  0.071603  0.344262  0.068713
# 4    0.087189  0.413223  0.083252  0.434426  0.078909  0.467213  0.074561
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.421488  0.176241  0.418033  0.175353  0.418033  0.173489
# 675  0.145153  0.603306  0.142648  0.598361  0.140283  0.590164  0.137914
# 676  0.143205  0.586777  0.144109  0.590164  0.145641  0.590164  0.146686
# 677  0.191914  0.454545  0.188413  0.450820  0.185095  0.459016  0.182261
# 678  0.154895  0.421488  0.149464  0.426230  0.145153  0.442623  0.141326
#
#             7         8         9  ...  450  451  452  453  season  \
# 0    0.750000  0.339697  0.721311  ...    1    0    1    0       1
# 1    0.391667  0.148801  0.409836  ...    0    1    1    0       1
# 2    0.325000  0.549682  0.344262  ...    1    0    1    0       1
# 3    0.358333  0.066079  0.368852  ...    0    0    1    0       1
# 4    0.483333  0.070485  0.491803  ...    0    1    1    0       1
# ..        ...       ...       ...  ...  ...  ...  ...  ...     ...
# 674  0.408333  0.172296  0.401639  ...    0    0    1    0       4
# 675  0.583333  0.134606  0.565574  ...    0    0    1    0       4
# 676  0.583333  0.148311  0.573770  ...    0    1    1    0       4
# 677  0.450000  0.180127  0.442623  ...    0    1    1    0       4
# 678  0.441667  0.138522  0.426230  ...    0    1    1    0       4
#
#                    Name   Day          ROI  Class            Percentage
# 0     1099_c8_cp2_53_25  1099   1099_53_25      0  [[0, 0.5], [2, 0.5]]
# 1    1106_c2_cp2_100_11  1106  1106_100_11      3                    []
# 2    1111_c10_cp2_53_37  1111   1111_53_37      2            [[2, 1.0]]
# 3     1121_c1_cp1_72_15  1121   1121_72_15      0            [[0, 1.0]]
# 4     1123_c1_cp1_76_16  1123   1123_76_16      0            [[0, 1.0]]
# ..                  ...   ...          ...    ...                   ...
# 674   1815_c1_cp1_71_15  1815   1815_71_15      3                    []
# 675   1816_c1_cp1_69_19  1816   1816_69_19      3                    []
# 676   1817_c1_cp1_82_23  1817   1817_82_23      0            [[0, 1.0]]
# 677   1818_c1_cp1_89_22  1818   1818_89_22      0            [[0, 1.0]]
# 678   1819_c1_cp1_92_21  1819   1819_92_21      0            [[0, 1.0]]
#
# [679 rows x 460 columns]

# %%
def calculate_distance(x1, y1, x2, y2):
    delta_x = x2 - x1
    delta_y = y2 - y1
    distance = math.sqrt(delta_x**2 + delta_y**2)
    return distance

# %%
SOM_ROI = {}

data = SOM_test_df.to_numpy()
for item in data:
    part = item[455].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[458]
    percentage = item[459]
    if day in SOM_ROI:
        found_duplicate = False
        for ele in SOM_ROI[day]:
            if x == ele[0] and y == ele[1]:
                found_duplicate = True
                break
        if not found_duplicate:
            SOM_ROI[day].append([x, y, category, percentage])
    else:
        SOM_ROI[day] = [[x, y, category, percentage]]

# %%
One_SOM_ROI = {}
Many_SOM_ROI = {}

for key, value in SOM_ROI.items():
    if len(value) <= 1:
        One_SOM_ROI[key] = value
    else:
        Many_SOM_ROI[key] = value

# %%
Many_SOM = {}
for key, value in Many_SOM_ROI.items():
    Many_SOM[key] = [[value[0]]]
    max_len = 0
    for i in value:
        if i[3] is None:
            continue
        else:
            if max_len < len(i[3]):
                max_len = len(i[3])
    space = max_len * 9 + (max_len - 1) * 6 + 16
    i = 1
    while i < len(value):
        x1 = value[i][0]
        y1 = value[i][1]
        found_smaller = True
        for k in Many_SOM[key]:
            found_smaller = True
            for j in k:
                x2 = j[0]
                y2 = j[1]
                distance = calculate_distance(x1, y1, x2, y2)
                if distance < space:
                    found_smaller = False
                    break
            if found_smaller == True:
                k.append(value[i])
                break
        if found_smaller == False:
            Many_SOM[key].append([value[i]])
        i += 1

# %%
folder_name = "4th_5th_SOM_Categorical_Wind_Pressure_Location_Season_ROI_Image"
SOM_folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(SOM_folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
default_color = (0, 0, 0)
size = 1
text_color = (148, 91, 10)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in One_SOM_ROI:
        for point in One_SOM_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list.get(point[2], default_color)
            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
            cv2.drawContours(final_image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
            text = ""
            if point[3] is not None:
                text = ", ".join([f"{a}:{b}" for a, b in point[3]])
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.2
            line_thickness = 0
            position = ()
            lines = text.split(",")
            max_len * 12 + (max_len - 1) * 6 + 16
            if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                position = (x + 3, y - 2)
            else:
                position = (x - 11, y + 8)
            for i, line in enumerate(lines):
                line = line.strip()
                position = (position[0], position[1] + 6 * i)
                cv2.putText(final_image, line, position, font, font_scale, text_color, line_thickness)
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", final_image)

# %%
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    f_image = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    height, width, _ = f_image.shape
    base_image = np.zeros((height, width, 3), dtype = np.uint8)
    base_image = cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB)

    if number in Many_SOM:
        for part in Many_SOM[number]:
            image = f_image.copy()
            for point in part:
                x = point[0]
                y = point[1]
                color = color_list[point[2]]
                vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])
                cv2.drawContours(image, [vertices.reshape((-1, 1, 2))], -1, color, thickness=cv2.FILLED)
                text = ""
                if point[3] is not None:
                    text = ", ".join([f"{a}:{b}" for a, b in point[3]])
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.2
                line_thickness = 0
                position = ()
                lines = text.split(",")
                max_len * 12 + (max_len - 1) * 6 + 16
                if x < len(lines) * 12 + (len(lines) - 1) * 6 + 16:
                    position = (x + 3, y - 2)
                else:
                    position = (x - 11, y + 8)
                for i, line in enumerate(lines):
                    line = line.strip()
                    position = (position[0], position[1] + 6 * i)
                    cv2.putText(image, line, position, font, font_scale, text_color, line_thickness)
            base_image = np.concatenate((base_image, image), axis = 1)
        base_image = base_image[:, width:, :]
        cv2.imwrite(SOM_folder_path + "/day" + str(number) + ".png", base_image)

# %% [markdown]
# # **CNN**

# %%
#Reshape training and testing data
train_X = X_train.to_numpy().reshape(X_train.shape[0],35,13,1).astype("float32")

train_Y = Y_train.to_numpy()

test_X = np.array(X_test).reshape(X_test.shape[0], 35, 13, 1)

train_Y = tf.keras.utils.to_categorical(train_Y)

# %%
#Define the model architecture
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 3, activation = "relu", input_shape = (35, 13, 1)))
model.add(Conv2D(filters = 32, kernel_size = 3, activation = "relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters = 64, kernel_size = 3, activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2), padding = "SAME"))
model.add(Flatten())
model.add(Dense(64, activation = "relu"))
model.add(Dense(32, activation = "relu"))
model.add(Dense(4, activation = "softmax"))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='loss', patience=30)
tensorboard_callback = TensorBoard(log_dir="./logs")

# Fit the model
model.fit(train_X, train_Y, epochs=1000, batch_size=16, callbacks=[tensorboard_callback, early_stopping])
# Out:
# Epoch 1/1000
# 67/67 [==============================] - 3s 14ms/step - loss: 1.3004 - accuracy: 0.4260
# Epoch 2/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.9621 - accuracy: 0.5805
# Epoch 3/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.8886 - accuracy: 0.6030
# Epoch 4/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.8722 - accuracy: 0.6133
# Epoch 5/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.7742 - accuracy: 0.6676
# Epoch 6/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.7293 - accuracy: 0.6742
# Epoch 7/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.6674 - accuracy: 0.7107
# Epoch 8/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.6221 - accuracy: 0.7313
# Epoch 9/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.6113 - accuracy: 0.7378
# Epoch 10/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.5545 - accuracy: 0.7697
# Epoch 11/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.5303 - accuracy: 0.7837
# Epoch 12/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.4860 - accuracy: 0.8015
# Epoch 13/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.4734 - accuracy: 0.8099
# Epoch 14/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.4536 - accuracy: 0.8249
# Epoch 15/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4329 - accuracy: 0.8324
# Epoch 16/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3920 - accuracy: 0.8474
# Epoch 17/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4010 - accuracy: 0.8390
# Epoch 18/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3718 - accuracy: 0.8483
# Epoch 19/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3705 - accuracy: 0.8418
# Epoch 20/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3608 - accuracy: 0.8605
# Epoch 21/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3685 - accuracy: 0.8502
# Epoch 22/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3391 - accuracy: 0.8745
# Epoch 23/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3340 - accuracy: 0.8699
# Epoch 24/1000
# 67/67 [==============================] - 1s 16ms/step - loss: 0.3498 - accuracy: 0.8539
# Epoch 25/1000
# 67/67 [==============================] - 2s 26ms/step - loss: 0.3255 - accuracy: 0.8708
# Epoch 26/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.3284 - accuracy: 0.8661
# Epoch 27/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.3277 - accuracy: 0.8699
# Epoch 28/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3142 - accuracy: 0.8717
# Epoch 29/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.2986 - accuracy: 0.8764
# Epoch 30/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3322 - accuracy: 0.8577
# Epoch 31/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3077 - accuracy: 0.8773
# Epoch 32/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2970 - accuracy: 0.8727
# Epoch 33/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2844 - accuracy: 0.8895
# Epoch 34/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2804 - accuracy: 0.8895
# Epoch 35/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.3031 - accuracy: 0.8764
# Epoch 36/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2831 - accuracy: 0.8745
# Epoch 37/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2766 - accuracy: 0.8914
# Epoch 38/1000
# 67/67 [==============================] - 1s 20ms/step - loss: 0.2573 - accuracy: 0.8961
# Epoch 39/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.2862 - accuracy: 0.8895
# Epoch 40/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.2855 - accuracy: 0.8839
# Epoch 41/1000
# 67/67 [==============================] - 1s 21ms/step - loss: 0.2605 - accuracy: 0.8951
# Epoch 42/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2681 - accuracy: 0.8979
# Epoch 43/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2605 - accuracy: 0.8876
# Epoch 44/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2658 - accuracy: 0.8895
# Epoch 45/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2422 - accuracy: 0.9054
# Epoch 46/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2724 - accuracy: 0.8820
# Epoch 47/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2519 - accuracy: 0.8895
# Epoch 48/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2377 - accuracy: 0.8979
# Epoch 49/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2527 - accuracy: 0.8998
# Epoch 50/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2348 - accuracy: 0.8989
# Epoch 51/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2247 - accuracy: 0.9148
# Epoch 52/1000
# 67/67 [==============================] - 1s 20ms/step - loss: 0.2519 - accuracy: 0.8839
# Epoch 53/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.2288 - accuracy: 0.8998
# Epoch 54/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.2212 - accuracy: 0.9045
# Epoch 55/1000
# 67/67 [==============================] - 1s 20ms/step - loss: 0.2248 - accuracy: 0.9017
# Epoch 56/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2277 - accuracy: 0.9082
# Epoch 57/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2153 - accuracy: 0.9129
# Epoch 58/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2073 - accuracy: 0.9092
# Epoch 59/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2126 - accuracy: 0.9167
# Epoch 60/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2135 - accuracy: 0.9064
# Epoch 61/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2340 - accuracy: 0.9129
# Epoch 62/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2075 - accuracy: 0.9110
# Epoch 63/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2141 - accuracy: 0.9129
# Epoch 64/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2293 - accuracy: 0.9082
# Epoch 65/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1949 - accuracy: 0.9213
# Epoch 66/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.1989 - accuracy: 0.9232
# Epoch 67/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.1909 - accuracy: 0.9185
# Epoch 68/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.1783 - accuracy: 0.9279
# Epoch 69/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.2197 - accuracy: 0.9054
# Epoch 70/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1830 - accuracy: 0.9242
# Epoch 71/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1893 - accuracy: 0.9157
# Epoch 72/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1765 - accuracy: 0.9270
# Epoch 73/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1825 - accuracy: 0.9298
# Epoch 74/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1846 - accuracy: 0.9176
# Epoch 75/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1817 - accuracy: 0.9185
# Epoch 76/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1745 - accuracy: 0.9232
# Epoch 77/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1675 - accuracy: 0.9204
# Epoch 78/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1907 - accuracy: 0.9260
# Epoch 79/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.1756 - accuracy: 0.9270
# Epoch 80/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.1661 - accuracy: 0.9307
# Epoch 81/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.1571 - accuracy: 0.9288
# Epoch 82/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.1778 - accuracy: 0.9204
# Epoch 83/1000
# 67/67 [==============================] - 1s 16ms/step - loss: 0.1542 - accuracy: 0.9270
# Epoch 84/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1457 - accuracy: 0.9401
# Epoch 85/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1651 - accuracy: 0.9223
# Epoch 86/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1789 - accuracy: 0.9204
# Epoch 87/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1597 - accuracy: 0.9288
# Epoch 88/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1486 - accuracy: 0.9335
# Epoch 89/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1394 - accuracy: 0.9457
# Epoch 90/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1289 - accuracy: 0.9429
# Epoch 91/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1388 - accuracy: 0.9391
# Epoch 92/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1316 - accuracy: 0.9448
# Epoch 93/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.1236 - accuracy: 0.9466
# Epoch 94/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.1305 - accuracy: 0.9382
# Epoch 95/1000
# 67/67 [==============================] - 2s 25ms/step - loss: 0.1483 - accuracy: 0.9354
# Epoch 96/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.1428 - accuracy: 0.9429
# Epoch 97/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1385 - accuracy: 0.9466
# Epoch 98/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1340 - accuracy: 0.9373
# Epoch 99/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1387 - accuracy: 0.9448
# Epoch 100/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1193 - accuracy: 0.9513
# Epoch 101/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1262 - accuracy: 0.9448
# Epoch 102/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1417 - accuracy: 0.9429
# Epoch 103/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1258 - accuracy: 0.9485
# Epoch 104/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1228 - accuracy: 0.9457
# Epoch 105/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1077 - accuracy: 0.9466
# Epoch 106/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1145 - accuracy: 0.9494
# Epoch 107/1000
# 67/67 [==============================] - 1s 20ms/step - loss: 0.1075 - accuracy: 0.9494
# Epoch 108/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.1214 - accuracy: 0.9541
# Epoch 109/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.1167 - accuracy: 0.9485
# Epoch 110/1000
# 67/67 [==============================] - 1s 21ms/step - loss: 0.1081 - accuracy: 0.9597
# Epoch 111/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0930 - accuracy: 0.9597
# Epoch 112/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1204 - accuracy: 0.9466
# Epoch 113/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1217 - accuracy: 0.9513
# Epoch 114/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1090 - accuracy: 0.9551
# Epoch 115/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0928 - accuracy: 0.9579
# Epoch 116/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0987 - accuracy: 0.9597
# Epoch 117/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1036 - accuracy: 0.9466
# Epoch 118/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1002 - accuracy: 0.9588
# Epoch 119/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1261 - accuracy: 0.9401
# Epoch 120/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0855 - accuracy: 0.9635
# Epoch 121/1000
# 67/67 [==============================] - 1s 22ms/step - loss: 0.1060 - accuracy: 0.9569
# Epoch 122/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0932 - accuracy: 0.9579
# Epoch 123/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.1255 - accuracy: 0.9419
# Epoch 124/1000
# 67/67 [==============================] - 1s 19ms/step - loss: 0.1033 - accuracy: 0.9588
# Epoch 125/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0955 - accuracy: 0.9551
# Epoch 126/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0706 - accuracy: 0.9663
# Epoch 127/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0728 - accuracy: 0.9719
# Epoch 128/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0761 - accuracy: 0.9672
# Epoch 129/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0663 - accuracy: 0.9738
# Epoch 130/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0718 - accuracy: 0.9691
# Epoch 131/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0619 - accuracy: 0.9738
# Epoch 132/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0616 - accuracy: 0.9757
# Epoch 133/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0953 - accuracy: 0.9588
# Epoch 134/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0900 - accuracy: 0.9607
# Epoch 135/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0708 - accuracy: 0.9738
# Epoch 136/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0785 - accuracy: 0.9644
# Epoch 137/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0735 - accuracy: 0.9738
# Epoch 138/1000
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0972 - accuracy: 0.9654
# Epoch 139/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1199 - accuracy: 0.9560
# Epoch 140/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0992 - accuracy: 0.9616
# Epoch 141/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0934 - accuracy: 0.9597
# Epoch 142/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0664 - accuracy: 0.9747
# Epoch 143/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0603 - accuracy: 0.9803
# Epoch 144/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0544 - accuracy: 0.9775
# Epoch 145/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0602 - accuracy: 0.9785
# Epoch 146/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0544 - accuracy: 0.9803
# Epoch 147/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0662 - accuracy: 0.9719
# Epoch 148/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0476 - accuracy: 0.9803
# Epoch 149/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0416 - accuracy: 0.9831
# Epoch 150/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0444 - accuracy: 0.9813
# Epoch 151/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.1262 - accuracy: 0.9513
# Epoch 152/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0823 - accuracy: 0.9663
# Epoch 153/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0633 - accuracy: 0.9747
# Epoch 154/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1186 - accuracy: 0.9522
# Epoch 155/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0609 - accuracy: 0.9766
# Epoch 156/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0715 - accuracy: 0.9738
# Epoch 157/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0578 - accuracy: 0.9766
# Epoch 158/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0547 - accuracy: 0.9757
# Epoch 159/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0425 - accuracy: 0.9860
# Epoch 160/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0462 - accuracy: 0.9803
# Epoch 161/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0447 - accuracy: 0.9831
# Epoch 162/1000
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0464 - accuracy: 0.9803
# Epoch 163/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0451 - accuracy: 0.9850
# Epoch 164/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0339 - accuracy: 0.9916
# Epoch 165/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0306 - accuracy: 0.9897
# Epoch 166/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0325 - accuracy: 0.9869
# Epoch 167/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0314 - accuracy: 0.9878
# Epoch 168/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0443 - accuracy: 0.9850
# Epoch 169/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1060 - accuracy: 0.9569
# Epoch 170/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1581 - accuracy: 0.9354
# Epoch 171/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0942 - accuracy: 0.9588
# Epoch 172/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1192 - accuracy: 0.9607
# Epoch 173/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1024 - accuracy: 0.9672
# Epoch 174/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0738 - accuracy: 0.9785
# Epoch 175/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0552 - accuracy: 0.9813
# Epoch 176/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0348 - accuracy: 0.9888
# Epoch 177/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0321 - accuracy: 0.9897
# Epoch 178/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0327 - accuracy: 0.9906
# Epoch 179/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0242 - accuracy: 0.9925
# Epoch 180/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0483 - accuracy: 0.9766
# Epoch 181/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0636 - accuracy: 0.9822
# Epoch 182/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1624 - accuracy: 0.9466
# Epoch 183/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0562 - accuracy: 0.9757
# Epoch 184/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0396 - accuracy: 0.9897
# Epoch 185/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0311 - accuracy: 0.9906
# Epoch 186/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0294 - accuracy: 0.9925
# Epoch 187/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0244 - accuracy: 0.9906
# Epoch 188/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0237 - accuracy: 0.9934
# Epoch 189/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0259 - accuracy: 0.9916
# Epoch 190/1000
# 67/67 [==============================] - 1s 22ms/step - loss: 0.0284 - accuracy: 0.9878
# Epoch 191/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0447 - accuracy: 0.9822
# Epoch 192/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0362 - accuracy: 0.9878
# Epoch 193/1000
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0417 - accuracy: 0.9822
# Epoch 194/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0473 - accuracy: 0.9831
# Epoch 195/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1577 - accuracy: 0.9401
# Epoch 196/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1533 - accuracy: 0.9504
# Epoch 197/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0731 - accuracy: 0.9691
# Epoch 198/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0395 - accuracy: 0.9878
# Epoch 199/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0298 - accuracy: 0.9916
# Epoch 200/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0299 - accuracy: 0.9878
# Epoch 201/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0199 - accuracy: 0.9963
# Epoch 202/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0348 - accuracy: 0.9878
# Epoch 203/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0196 - accuracy: 0.9916
# Epoch 204/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0344 - accuracy: 0.9831
# Epoch 205/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0247 - accuracy: 0.9925
# Epoch 206/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0305 - accuracy: 0.9888
# Epoch 207/1000
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0215 - accuracy: 0.9916
# Epoch 208/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0187 - accuracy: 0.9934
# Epoch 209/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0195 - accuracy: 0.9944
# Epoch 210/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0254 - accuracy: 0.9888
# Epoch 211/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0498 - accuracy: 0.9822
# Epoch 212/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0262 - accuracy: 0.9906
# Epoch 213/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0165 - accuracy: 0.9963
# Epoch 214/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0168 - accuracy: 0.9944
# Epoch 215/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0176 - accuracy: 0.9925
# Epoch 216/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0166 - accuracy: 0.9963
# Epoch 217/1000
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0216 - accuracy: 0.9916
# Epoch 218/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0129 - accuracy: 0.9953
# Epoch 219/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0179 - accuracy: 0.9963
# Epoch 220/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0412 - accuracy: 0.9822
# Epoch 221/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0817 - accuracy: 0.9625
# Epoch 222/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1502 - accuracy: 0.9448
# Epoch 223/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1378 - accuracy: 0.9541
# Epoch 224/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1191 - accuracy: 0.9569
# Epoch 225/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0417 - accuracy: 0.9860
# Epoch 226/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0267 - accuracy: 0.9916
# Epoch 227/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0190 - accuracy: 0.9944
# Epoch 228/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0143 - accuracy: 0.9972
# Epoch 229/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0128 - accuracy: 0.9981
# Epoch 230/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0141 - accuracy: 0.9963
# Epoch 231/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0127 - accuracy: 0.9981
# Epoch 232/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0123 - accuracy: 0.9963
# Epoch 233/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0182 - accuracy: 0.9944
# Epoch 234/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0116 - accuracy: 0.9972
# Epoch 235/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0379 - accuracy: 0.9850
# Epoch 236/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0118 - accuracy: 0.9972
# Epoch 237/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1027 - accuracy: 0.9597
# Epoch 238/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0947 - accuracy: 0.9654
# Epoch 239/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0828 - accuracy: 0.9682
# Epoch 240/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0745 - accuracy: 0.9710
# Epoch 241/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0405 - accuracy: 0.9841
# Epoch 242/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0487 - accuracy: 0.9850
# Epoch 243/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0409 - accuracy: 0.9850
# Epoch 244/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0394 - accuracy: 0.9860
# Epoch 245/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0200 - accuracy: 0.9944
# Epoch 246/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0144 - accuracy: 0.9981
# Epoch 247/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0128 - accuracy: 0.9953
# Epoch 248/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0332 - accuracy: 0.9869
# Epoch 249/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0151 - accuracy: 0.9934
# Epoch 250/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0099 - accuracy: 0.9981
# Epoch 251/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0132 - accuracy: 0.9972
# Epoch 252/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0165 - accuracy: 0.9944
# Epoch 253/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0266 - accuracy: 0.9916
# Epoch 254/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0239 - accuracy: 0.9897
# Epoch 255/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0092 - accuracy: 0.9981
# Epoch 256/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0108 - accuracy: 0.9963
# Epoch 257/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0096 - accuracy: 0.9963
# Epoch 258/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0114 - accuracy: 0.9963
# Epoch 259/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0086 - accuracy: 0.9981
# Epoch 260/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0067 - accuracy: 0.9991
# Epoch 261/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0052 - accuracy: 0.9991
# Epoch 262/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 263/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0079 - accuracy: 0.9972
# Epoch 264/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0143 - accuracy: 0.9944
# Epoch 265/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1667 - accuracy: 0.9476
# Epoch 266/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1362 - accuracy: 0.9560
# Epoch 267/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0663 - accuracy: 0.9738
# Epoch 268/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0314 - accuracy: 0.9897
# Epoch 269/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0156 - accuracy: 0.9953
# Epoch 270/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0098 - accuracy: 0.9981
# Epoch 271/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0084 - accuracy: 0.9981
# Epoch 272/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0223 - accuracy: 0.9888
# Epoch 273/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0119 - accuracy: 0.9963
# Epoch 274/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0085 - accuracy: 0.9963
# Epoch 275/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0071 - accuracy: 0.9981
# Epoch 276/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0059 - accuracy: 0.9981
# Epoch 277/1000
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 278/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0042 - accuracy: 0.9991
# Epoch 279/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 280/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 281/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0127 - accuracy: 0.9953
# Epoch 282/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0237 - accuracy: 0.9897
# Epoch 283/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0714 - accuracy: 0.9766
# Epoch 284/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.1681 - accuracy: 0.9569
# Epoch 285/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1297 - accuracy: 0.9448
# Epoch 286/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0616 - accuracy: 0.9785
# Epoch 287/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0217 - accuracy: 0.9934
# Epoch 288/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0109 - accuracy: 0.9972
# Epoch 289/1000
# 67/67 [==============================] - 2s 25ms/step - loss: 0.0075 - accuracy: 0.9991
# Epoch 290/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 291/1000
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0167 - accuracy: 0.9944
# Epoch 292/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0116 - accuracy: 0.9963
# Epoch 293/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0067 - accuracy: 0.9981
# Epoch 294/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 295/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 296/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0035 - accuracy: 0.9981
# Epoch 297/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 298/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 299/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 300/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 301/1000
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0036 - accuracy: 0.9991
# Epoch 302/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 303/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 304/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 305/1000
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 306/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 307/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 308/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 309/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 8.9747e-04 - accuracy: 1.0000
# Epoch 310/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 311/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 9.9914e-04 - accuracy: 1.0000
# Epoch 312/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 7.2573e-04 - accuracy: 1.0000
# Epoch 313/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 6.8165e-04 - accuracy: 1.0000
# Epoch 314/1000
# 67/67 [==============================] - 1s 18ms/step - loss: 5.8584e-04 - accuracy: 1.0000
# Epoch 315/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 6.9958e-04 - accuracy: 1.0000
# Epoch 316/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 5.4238e-04 - accuracy: 1.0000
# Epoch 317/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 5.7730e-04 - accuracy: 1.0000
# Epoch 318/1000
# 67/67 [==============================] - 1s 16ms/step - loss: 5.0720e-04 - accuracy: 1.0000
# Epoch 319/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 4.8855e-04 - accuracy: 1.0000
# Epoch 320/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 4.1814e-04 - accuracy: 1.0000
# Epoch 321/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 4.3755e-04 - accuracy: 1.0000
# Epoch 322/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 4.0766e-04 - accuracy: 1.0000
# Epoch 323/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 8.3975e-04 - accuracy: 1.0000
# Epoch 324/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 325/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2002 - accuracy: 0.9532
# Epoch 326/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2204 - accuracy: 0.9213
# Epoch 327/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1463 - accuracy: 0.9429
# Epoch 328/1000
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0960 - accuracy: 0.9597
# Epoch 329/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0374 - accuracy: 0.9878
# Epoch 330/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0378 - accuracy: 0.9841
# Epoch 331/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0425 - accuracy: 0.9841
# Epoch 332/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0238 - accuracy: 0.9897
# Epoch 333/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0172 - accuracy: 0.9953
# Epoch 334/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0190 - accuracy: 0.9916
# Epoch 335/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 0.0333 - accuracy: 0.9916
# Epoch 336/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0119 - accuracy: 0.9963
# Epoch 337/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0107 - accuracy: 0.9981
# Epoch 338/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 339/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 340/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 341/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 342/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 343/1000
# 67/67 [==============================] - 2s 24ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 344/1000
# 67/67 [==============================] - 2s 23ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 345/1000
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 346/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 347/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 348/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 9.8997e-04 - accuracy: 1.0000
# Epoch 349/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 9.3490e-04 - accuracy: 1.0000
# Epoch 350/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 8.3636e-04 - accuracy: 1.0000
# Epoch 351/1000
# 67/67 [==============================] - 1s 14ms/step - loss: 7.4635e-04 - accuracy: 1.0000
# Epoch 352/1000
# 67/67 [==============================] - 1s 15ms/step - loss: 7.5292e-04 - accuracy: 1.0000

# %%
y_pred = model.predict(test_X).argmax(axis=1)
# Out:
# 22/22 [==============================] - 0s 7ms/step

# %%
cnn_test_df = test_df.copy()
cnn_test_df["Class"] = y_pred
cnn_test_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.332684  0.760331  0.333496  0.762295  0.334632  0.762295  0.336745
# 1    0.148076  0.322314  0.148004  0.344262  0.148563  0.368852  0.148635
# 2    0.550901  0.280992  0.551120  0.295082  0.550414  0.311475  0.549220
# 3    0.077935  0.305785  0.074489  0.319672  0.071603  0.344262  0.068713
# 4    0.087189  0.413223  0.083252  0.434426  0.078909  0.467213  0.074561
# ..        ...       ...       ...       ...       ...       ...       ...
# 674  0.177789  0.421488  0.176241  0.418033  0.175353  0.418033  0.173489
# 675  0.145153  0.603306  0.142648  0.598361  0.140283  0.590164  0.137914
# 676  0.143205  0.586777  0.144109  0.590164  0.145641  0.590164  0.146686
# 677  0.191914  0.454545  0.188413  0.450820  0.185095  0.459016  0.182261
# 678  0.154895  0.421488  0.149464  0.426230  0.145153  0.442623  0.141326
#
#             7         8         9  ...       449  450  451  452  453  season  \
# 0    0.750000  0.339697  0.721311  ...  0.761905    1    0    1    0       1
# 1    0.391667  0.148801  0.409836  ...  0.500000    0    1    1    0       1
# 2    0.325000  0.549682  0.344262  ...  0.261905    1    0    1    0       1
# 3    0.358333  0.066079  0.368852  ...  0.396825    0    0    1    0       1
# 4    0.483333  0.070485  0.491803  ...  0.587302    0    1    1    0       1
# ..        ...       ...       ...  ...       ...  ...  ...  ...  ...     ...
# 674  0.408333  0.172296  0.401639  ...  0.595238    0    0    1    0       4
# 675  0.583333  0.134606  0.565574  ...  0.753968    0    0    1    0       4
# 676  0.583333  0.148311  0.573770  ...  0.912698    0    1    1    0       4
# 677  0.450000  0.180127  0.442623  ...  0.920635    0    1    1    0       4
# 678  0.441667  0.138522  0.426230  ...  0.873016    0    1    1    0       4
#
#                    Name   Day          ROI  Class
# 0     1099_c8_cp2_53_25  1099   1099_53_25      1
# 1    1106_c2_cp2_100_11  1106  1106_100_11      0
# 2    1111_c10_cp2_53_37  1111   1111_53_37      2
# 3     1121_c1_cp1_72_15  1121   1121_72_15      0
# 4     1123_c1_cp1_76_16  1123   1123_76_16      0
# ..                  ...   ...          ...    ...
# 674   1815_c1_cp1_71_15  1815   1815_71_15      0
# 675   1816_c1_cp1_69_19  1816   1816_69_19      0
# 676   1817_c1_cp1_82_23  1817   1817_82_23      0
# 677   1818_c1_cp1_89_22  1818   1818_89_22      0
# 678   1819_c1_cp1_92_21  1819   1819_92_21      0
#
# [679 rows x 459 columns]

# %%
CNN_ROI = {}
data = cnn_test_df.to_numpy()
for item in data:
    part = item[455].split("_")
    day = int(part[0])
    x = int(part[3])
    y = int(part[4])
    category = item[458]
    if day in CNN_ROI:
        CNN_ROI[day].append([x, y, category])
    else:
        CNN_ROI[day] = [[x, y, category]]

# %%
folder_name = "4th_5th_CNN_Categorical_Wind_Pressure_Location_Season_ROI_Image"
folder_path = "/content/drive/MyDrive/" + folder_name

os.makedirs(folder_path)

# %%
image_path = "/content/drive/MyDrive/Pressure_raw_Image"
color_list = {0: (0, 255, 0), 1: (0, 0, 255), 2: (0, 255, 255), 3: (255, 0, 0)}
for file in os.listdir(image_path):
    file_path = os.path.join(image_path, file)
    final_img = cv2.imread(file_path)

    file_name = os.path.splitext(file)[0]
    number = int(file_name[3:])

    if number in CNN_ROI:
        for point in CNN_ROI[number]:
            x = point[0]
            y = point[1]
            color = color_list[point[2]]

            size = 2

            vertices = np.array([(x, y - size), (x - size, y), (x, y + size), (x + size, y)])

            cv2.drawContours(final_img, [vertices.reshape((-1, 1, 2))], -1, color, thickness = cv2.FILLED)

        cv2.imwrite(folder_path + "/day" + str(number) + ".png", final_img)
